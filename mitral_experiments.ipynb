# %% [markdown]
# <a href="https://colab.research.google.com/github/bhushan1729/olfaction-inspired-ner/blob/main/mitral_experiments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Universal Olfactory NER Experiments
#
# This notebook allows running Olfaction-inspired NER experiments across different datasets (CoNLL-2003, WikiANN, etc.) and languages using a unified framework.
#
# **Architecture:**
# - **Receptor Layer:** Specialized feature detectors inspired by olfactory receptors.
# - **Glomerular Layer:** Aggregates receptor activations.
# - **BiLSTM-CRF:** Standard backbone for NER.

# %%
import os
import sys
import shutil
import zipfile

try:
    from google.colab import drive
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

# Mount Drive if requested
MOUNT_DRIVE = True # USER INPUTS
if MOUNT_DRIVE and IN_COLAB:
    try:
        # force_remount=True fixes 'Mountpoint must not already contain files' error
        drive.mount('/content/drive', force_remount=True)
        BASE_SAVE_DIR = '/content/drive/My Drive/olfaction_inspired_ner_mitral'
    except Exception as e:
        print(f"Warning: Failed to mount Drive ({e}). Using local storage.")
        BASE_SAVE_DIR = './results'
elif MOUNT_DRIVE and not IN_COLAB:
    print("Info: MOUNT_DRIVE=True but running locally. Using local storage.")
    BASE_SAVE_DIR = './results'
else:
    BASE_SAVE_DIR = './results'

print(f"Results will be saved to: {BASE_SAVE_DIR}")

# Git Setup
# Extract ZIP format from Drive (Workaround for GitHub limits)
if IN_COLAB:
    zip_path = '/content/drive/My Drive/olfaction-inspired-ner-mitral.zip'
    extract_dir = '/content/olfaction-inspired-ner'

    # Define a characteristic file that should exist if the project is extracted
    project_root_indicator_file = os.path.join(extract_dir, 'src', 'train_universal.py')

    # Check if the project is already extracted into the correct location
    if not os.path.exists(project_root_indicator_file):
        print(f'Extracting {zip_path} to {extract_dir}...')
        # Optional: Clean up previous extraction if it exists to avoid conflicts
        if os.path.exists(extract_dir):
            shutil.rmtree(extract_dir)
        os.makedirs(extract_dir, exist_ok=True)

        with zipfile.ZipFile(zip_path, 'r') as zip_ref:
            zip_ref.extractall(extract_dir)
        print("Extraction complete.")
    else:
        print(f"Project files already found in {extract_dir}, skipping extraction.")

    # Change directory to the actual project root after extraction
    os.chdir(extract_dir)

# Check if we are already in the project root (e.g. local execution)
if os.path.exists('src/train_universal.py') and os.path.exists('config/mitral_config.yaml'):
    print("Already in project root.")
elif os.path.exists('olfaction-inspired-ner'): # This check might be redundant after chdir(extract_dir)
    # !git pull
else:
    # Clone using token
    print("Please provide your GitHub Personal Access Token to clone the private repository.")

# Install dependencies
# !pip install datasets pyyaml seqeval

# Add src to path
sys.path.append(os.getcwd())
# Out:
# Mounted at /content/drive
# Results will be saved to: /content/drive/My Drive/olfaction_inspired_ner_mitral
# Project files already found in /content/olfaction-inspired-ner, skipping extraction.
# Already in project root.
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (6.0.3)
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 4.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets) (3.24.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets) (4.67.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (1.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets) (26.0)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.12/dist-packages (from seqeval) (1.6.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.13.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (0.28.1)
# Requirement already satisfied: shellingham in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (1.5.4)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (0.24.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2026.1.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.21.3->seqeval) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.24.0->datasets) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.24.0->datasets) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.24.0->datasets) (0.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: typer>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from typer-slim->huggingface-hub>=0.24.0->datasets) (0.24.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer>=0.24.0->typer-slim->huggingface-hub>=0.24.0->datasets) (8.3.1)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.24.0->typer-slim->huggingface-hub>=0.24.0->datasets) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer>=0.24.0->typer-slim->huggingface-hub>=0.24.0->datasets) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface-hub>=0.24.0->datasets) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface-hub>=0.24.0->datasets) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface-hub>=0.24.0->datasets) (0.1.2)
# Building wheels for collected packages: seqeval
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16162 sha256=e89d5ef645fb6cbfa3d055f8539124b28c8700941223a31a2e56134ba80cfce6
#   Stored in directory: /root/.cache/pip/wheels/5f/b8/73/0b2c1a76b701a677653dd79ece07cfabd7457989dbfbdcd8d7
# Successfully built seqeval
# Installing collected packages: seqeval
# Successfully installed seqeval-1.2.2

# %%
    # Get your token securely (won't be visible in output)

    # Clone using token

# %%
# Patch src/train_universal.py to remove 'verbose=True'
fn = 'src/train_universal.py'
with open(fn, 'r') as f:
    content = f.read()

if 'verbose=True' in content:
    print(f"Patching {fn}...")
    content = content.replace(', verbose=True', '')
    with open(fn, 'w') as f:
        f.write(content)
    print("Success: Removed verbose=True argument.")
else:
    print(f"{fn} already patched or 'verbose=True' not found.")
# Out:
# src/train_universal.py already patched or 'verbose=True' not found.

# %%
# @title Run ALL Experiments (All Languages)
import os
import yaml

CONFIG_PATH = 'config/mitral_config.yaml'
BASE_SAVE_DIR = '/content/drive/My Drive/olfaction_inspired_ner_mitral' if os.path.exists('/content/drive') else './results'

# 1. Load Config to get all experiments
with open(CONFIG_PATH, 'r') as f:
    full_config = yaml.safe_load(f)

# Get all experiment keys
all_experiments = list(full_config['experiments'].keys())

# Define Datasets
DATASETS = ['conll_en', 'wikiann_hi', 'wikiann_mr', 'wikiann_ta', 'wikiann_bn', 'wikiann_te']

print(f"Running on Datasets: {DATASETS}")
print(f"Running Experiments: {all_experiments}")

for dataset_key in DATASETS:
    print(f"\n{'#'*80}")
    print(f"PROCESSING DATASET: {dataset_key}")
    print(f"{'#'*80}")

    for exp in all_experiments:
        print(f"\n>>> Running Experiment: {exp} on {dataset_key} <<<")

        # !python src/train_universal.py \
            --config {CONFIG_PATH} \
            --dataset_key {dataset_key} \
            --experiment {exp} \
            --save_dir "{BASE_SAVE_DIR}"

        print(f"✓ Completed {exp} on {dataset_key}")
# Out:
# Streaming output truncated to the last 5000 lines.
#
# Epoch 27/30
# Training: 100% 157/157 [00:03<00:00, 43.32it/s, loss=0.0995]
# Train Loss: 0.0806
# Evaluating: 100% 32/32 [00:00<00:00, 109.45it/s]
# Valid F1: 0.8195
# No improvement for 1 epochs
#
# Epoch 28/30
# Training: 100% 157/157 [00:04<00:00, 33.84it/s, loss=0.00304]
# Train Loss: 0.0808
# Evaluating: 100% 32/32 [00:00<00:00, 77.34it/s]
# Valid F1: 0.8215
# ✓ Saved new best model
#
# Epoch 29/30
# Training: 100% 157/157 [00:04<00:00, 38.90it/s, loss=0.0664]
# Train Loss: 0.0797
# Evaluating: 100% 32/32 [00:00<00:00, 109.02it/s]
# Valid F1: 0.8156
# No improvement for 1 epochs
#
# Epoch 30/30
# Training: 100% 157/157 [00:03<00:00, 43.00it/s, loss=0.0256]
# Train Loss: 0.0749
# Evaluating: 100% 32/32 [00:00<00:00, 110.98it/s]
# Valid F1: 0.8202
# No improvement for 2 epochs
#
# Training completed in 0:02:17.289303
#
# Evaluating on test set...
# Evaluating: 100% 32/32 [00:00<00:00, 94.77it/s]
# ✓ Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/hi/baseline
# Test F1: 0.8367
# ✓ Completed baseline on wikiann_hi
#
# >>> Running Experiment: olfactory_base on wikiann_hi <<<
# Using device: cuda
# ================================================================================
# Experiment: olfactory_base
# Dataset: wikiann_hi
# ================================================================================
# Results will be saved to: /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/hi/olfactory_base
# Loading wikiann dataset from HuggingFace (unimelb-nlp/wikiann)...
# Configuration: hi
#
# Data splits available: ['validation', 'test', 'train']
# Number of labels: 7
# Label names: ['O', 'B-PER', 'I-PER', 'B-ORG', 'I-ORG', 'B-LOC', 'I-LOC']
#
# Data splits:
#   Train: 5000 sentences
#   Valid: 1000 sentences
#   Test: 1000 sentences
#
# Building vocabularies...
# Vocabulary size: 2844
# Number of labels: 7
#
# Starting training...
#
# Epoch 1/30
# Training: 100% 157/157 [00:04<00:00, 35.82it/s, loss=4.79]
# Train Loss: 8.2793
# Evaluating: 100% 32/32 [00:00<00:00, 73.14it/s]
# Valid F1: 0.2866
# ✓ Saved new best model
#
# Epoch 2/30
# Training: 100% 157/157 [00:04<00:00, 33.26it/s, loss=2.82]
# Train Loss: 3.9181
# Evaluating: 100% 32/32 [00:00<00:00, 107.46it/s]
# Valid F1: 0.4860
# ✓ Saved new best model
#
# Epoch 3/30
# Training: 100% 157/157 [00:03<00:00, 40.94it/s, loss=1.34]
# Train Loss: 2.6552
# Evaluating: 100% 32/32 [00:00<00:00, 106.36it/s]
# Valid F1: 0.5677
# ✓ Saved new best model
#
# Epoch 4/30
# Training: 100% 157/157 [00:04<00:00, 36.73it/s, loss=2.5]
# Train Loss: 2.0122
# Evaluating: 100% 32/32 [00:00<00:00, 76.28it/s]
# Valid F1: 0.6153
# ✓ Saved new best model
#
# Epoch 5/30
# Training: 100% 157/157 [00:04<00:00, 35.70it/s, loss=1.88]
# Train Loss: 1.6742
# Evaluating: 100% 32/32 [00:00<00:00, 106.60it/s]
# Valid F1: 0.6334
# ✓ Saved new best model
#
# Epoch 6/30
# Training: 100% 157/157 [00:04<00:00, 38.60it/s, loss=1.16]
# Train Loss: 1.4245
# Evaluating: 100% 32/32 [00:00<00:00, 108.26it/s]
# Valid F1: 0.6282
# No improvement for 1 epochs
#
# Epoch 7/30
# Training: 100% 157/157 [00:04<00:00, 31.94it/s, loss=0.373]
# Train Loss: 1.2241
# Evaluating: 100% 32/32 [00:00<00:00, 66.39it/s]
# Valid F1: 0.6903
# ✓ Saved new best model
#
# Epoch 8/30
# Training: 100% 157/157 [00:04<00:00, 38.90it/s, loss=0.734]
# Train Loss: 1.0698
# Evaluating: 100% 32/32 [00:00<00:00, 106.72it/s]
# Valid F1: 0.7185
# ✓ Saved new best model
#
# Epoch 9/30
# Training: 100% 157/157 [00:03<00:00, 39.54it/s, loss=0.723]
# Train Loss: 0.9857
# Evaluating: 100% 32/32 [00:00<00:00, 106.61it/s]
# Valid F1: 0.6998
# No improvement for 1 epochs
#
# Epoch 10/30
# Training: 100% 157/157 [00:05<00:00, 29.31it/s, loss=2.37]
# Train Loss: 0.8838
# Evaluating: 100% 32/32 [00:00<00:00, 101.24it/s]
# Valid F1: 0.7232
# ✓ Saved new best model
#
# Epoch 11/30
# Training: 100% 157/157 [00:04<00:00, 39.21it/s, loss=0.373]
# Train Loss: 0.7740
# Evaluating: 100% 32/32 [00:00<00:00, 106.52it/s]
# Valid F1: 0.7466
# ✓ Saved new best model
#
# Epoch 12/30
# Training: 100% 157/157 [00:03<00:00, 39.43it/s, loss=1.22]
# Train Loss: 0.6811
# Evaluating: 100% 32/32 [00:00<00:00, 108.26it/s]
# Valid F1: 0.7149
# No improvement for 1 epochs
#
# Epoch 13/30
# Training: 100% 157/157 [00:05<00:00, 28.95it/s, loss=0.857]
# Train Loss: 0.6457
# Evaluating: 100% 32/32 [00:00<00:00, 102.38it/s]
# Valid F1: 0.7382
# No improvement for 2 epochs
#
# Epoch 14/30
# Training: 100% 157/157 [00:03<00:00, 40.17it/s, loss=0.126]
# Train Loss: 0.5963
# Evaluating: 100% 32/32 [00:00<00:00, 107.19it/s]
# Valid F1: 0.7284
# No improvement for 3 epochs
#
# Epoch 15/30
# Training: 100% 157/157 [00:04<00:00, 34.90it/s, loss=0.0323]
# Train Loss: 0.4774
# Evaluating: 100% 32/32 [00:00<00:00, 73.24it/s]
# Valid F1: 0.7570
# ✓ Saved new best model
#
# Epoch 16/30
# Training: 100% 157/157 [00:04<00:00, 34.87it/s, loss=0.0307]
# Train Loss: 0.4311
# Evaluating: 100% 32/32 [00:00<00:00, 102.23it/s]
# Valid F1: 0.7476
# No improvement for 1 epochs
#
# Epoch 17/30
# Training: 100% 157/157 [00:03<00:00, 39.60it/s, loss=0.234]
# Train Loss: 0.4136
# Evaluating: 100% 32/32 [00:00<00:00, 102.74it/s]
# Valid F1: 0.7522
# No improvement for 2 epochs
#
# Epoch 18/30
# Training: 100% 157/157 [00:04<00:00, 32.94it/s, loss=0.94]
# Train Loss: 0.3991
# Evaluating: 100% 32/32 [00:00<00:00, 80.65it/s]
# Valid F1: 0.7413
# No improvement for 3 epochs
#
# Epoch 19/30
# Training: 100% 157/157 [00:04<00:00, 38.07it/s, loss=0.147]
# Train Loss: 0.3485
# Evaluating: 100% 32/32 [00:00<00:00, 108.67it/s]
# Valid F1: 0.7639
# ✓ Saved new best model
#
# Epoch 20/30
# Training: 100% 157/157 [00:03<00:00, 39.58it/s, loss=0.789]
# Train Loss: 0.3268
# Evaluating: 100% 32/32 [00:00<00:00, 104.09it/s]
# Valid F1: 0.7640
# ✓ Saved new best model
#
# Epoch 21/30
# Training: 100% 157/157 [00:04<00:00, 31.91it/s, loss=0.247]
# Train Loss: 0.3124
# Evaluating: 100% 32/32 [00:00<00:00, 102.04it/s]
# Valid F1: 0.7632
# No improvement for 1 epochs
#
# Epoch 22/30
# Training: 100% 157/157 [00:04<00:00, 37.89it/s, loss=0.667]
# Train Loss: 0.3077
# Evaluating: 100% 32/32 [00:00<00:00, 108.76it/s]
# Valid F1: 0.7641
# ✓ Saved new best model
#
# Epoch 23/30
# Training: 100% 157/157 [00:04<00:00, 38.79it/s, loss=0.426]
# Train Loss: 0.3010
# Evaluating: 100% 32/32 [00:00<00:00, 107.34it/s]
# Valid F1: 0.7542
# No improvement for 1 epochs
#
# Epoch 24/30
# Training: 100% 157/157 [00:04<00:00, 31.58it/s, loss=0.0486]
# Train Loss: 0.2874
# Evaluating: 100% 32/32 [00:00<00:00, 103.20it/s]
# Valid F1: 0.7563
# No improvement for 2 epochs
#
# Epoch 25/30
# Training: 100% 157/157 [00:04<00:00, 37.61it/s, loss=0.0809]
# Train Loss: 0.2689
# Evaluating: 100% 32/32 [00:00<00:00, 104.93it/s]
# Valid F1: 0.7586
# No improvement for 3 epochs
#
# Epoch 26/30
# Training: 100% 157/157 [00:03<00:00, 40.55it/s, loss=0.0622]
# Train Loss: 0.2686
# Evaluating: 100% 32/32 [00:00<00:00, 79.84it/s]
# Valid F1: 0.7639
# No improvement for 4 epochs
#
# Epoch 27/30
# Training: 100% 157/157 [00:05<00:00, 31.22it/s, loss=0.148]
# Train Loss: 0.2591
# Evaluating: 100% 32/32 [00:00<00:00, 100.86it/s]
# Valid F1: 0.7655
# ✓ Saved new best model
#
# Epoch 28/30
# Training: 100% 157/157 [00:04<00:00, 37.92it/s, loss=0.384]
# Train Loss: 0.2528
# Evaluating: 100% 32/32 [00:00<00:00, 108.72it/s]
# Valid F1: 0.7615
# No improvement for 1 epochs
#
# Epoch 29/30
# Training: 100% 157/157 [00:04<00:00, 35.59it/s, loss=0.0368]
# Train Loss: 0.2434
# Evaluating: 100% 32/32 [00:00<00:00, 71.54it/s]
# Valid F1: 0.7679
# ✓ Saved new best model
#
# Epoch 30/30
# Training: 100% 157/157 [00:04<00:00, 36.30it/s, loss=0.341]
# Train Loss: 0.2369
# Evaluating: 100% 32/32 [00:00<00:00, 108.25it/s]
# Valid F1: 0.7663
# No improvement for 1 epochs
#
# Training completed in 0:02:26.087504
#
# Evaluating on test set...
# Evaluating: 100% 32/32 [00:00<00:00, 84.97it/s]
# ✓ Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/hi/olfactory_base
# Test F1: 0.7959
# ✓ Completed olfactory_base on wikiann_hi
#
# >>> Running Experiment: olfactory_mitral_base on wikiann_hi <<<
# Using device: cuda
# ================================================================================
# Experiment: olfactory_mitral_base
# Dataset: wikiann_hi
# ================================================================================
# Results will be saved to: /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/hi/olfactory_mitral_base
# Loading wikiann dataset from HuggingFace (unimelb-nlp/wikiann)...
# Configuration: hi
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#
# Data splits available: ['validation', 'test', 'train']
# Number of labels: 7
# Label names: ['O', 'B-PER', 'I-PER', 'B-ORG', 'I-ORG', 'B-LOC', 'I-LOC']
#
# Data splits:
#   Train: 5000 sentences
#   Valid: 1000 sentences
#   Test: 1000 sentences
#
# Building vocabularies...
# Vocabulary size: 2844
# Number of labels: 7
#
# Starting training...
#
# Epoch 1/30
# Training: 100% 157/157 [00:04<00:00, 34.38it/s, loss=3.8]
# Train Loss: 8.7292
# Evaluating: 100% 32/32 [00:00<00:00, 99.86it/s]
# Valid F1: 0.2039
# ✓ Saved new best model
#
# Epoch 2/30
# Training: 100% 157/157 [00:04<00:00, 34.26it/s, loss=7.79]
# Train Loss: 5.1046
# Evaluating: 100% 32/32 [00:00<00:00, 73.54it/s]
# Valid F1: 0.3401
# ✓ Saved new best model
#
# Epoch 3/30
# Training: 100% 157/157 [00:04<00:00, 36.35it/s, loss=1.15]
# Train Loss: 3.7649
# Evaluating: 100% 32/32 [00:00<00:00, 98.44it/s]
# Valid F1: 0.5086
# ✓ Saved new best model
#
# Epoch 4/30
# Training: 100% 157/157 [00:04<00:00, 37.62it/s, loss=3.34]
# Train Loss: 2.9595
# Evaluating: 100% 32/32 [00:00<00:00, 104.32it/s]
# Valid F1: 0.6005
# ✓ Saved new best model
#
# Epoch 5/30
# Training: 100% 157/157 [00:05<00:00, 30.42it/s, loss=3.27]
# Train Loss: 2.5150
# Evaluating: 100% 32/32 [00:00<00:00, 98.84it/s]
# Valid F1: 0.6387
# ✓ Saved new best model
#
# Epoch 6/30
# Training: 100% 157/157 [00:04<00:00, 39.13it/s, loss=1.92]
# Train Loss: 2.1934
# Evaluating: 100% 32/32 [00:00<00:00, 103.02it/s]
# Valid F1: 0.6735
# ✓ Saved new best model
#
# Epoch 7/30
# Training: 100% 157/157 [00:04<00:00, 38.83it/s, loss=1.41]
# Train Loss: 1.8913
# Evaluating: 100% 32/32 [00:00<00:00, 103.42it/s]
# Valid F1: 0.7026
# ✓ Saved new best model
#
# Epoch 8/30
# Training: 100% 157/157 [00:05<00:00, 30.64it/s, loss=0.417]
# Train Loss: 1.7550
# Evaluating: 100% 32/32 [00:00<00:00, 100.02it/s]
# Valid F1: 0.7071
# ✓ Saved new best model
#
# Epoch 9/30
# Training: 100% 157/157 [00:04<00:00, 38.20it/s, loss=0.922]
# Train Loss: 1.5557
# Evaluating: 100% 32/32 [00:00<00:00, 107.01it/s]
# Valid F1: 0.7373
# ✓ Saved new best model
#
# Epoch 10/30
# Training: 100% 157/157 [00:04<00:00, 36.11it/s, loss=1.1]
# Train Loss: 1.4482
# Evaluating: 100% 32/32 [00:00<00:00, 72.77it/s]
# Valid F1: 0.7482
# ✓ Saved new best model
#
# Epoch 11/30
# Training: 100% 157/157 [00:04<00:00, 31.74it/s, loss=1.22]
# Train Loss: 1.3731
# Evaluating: 100% 32/32 [00:00<00:00, 105.92it/s]
# Valid F1: 0.7656
# ✓ Saved new best model
#
# Epoch 12/30
# Training: 100% 157/157 [00:04<00:00, 38.82it/s, loss=0.346]
# Train Loss: 1.2522
# Evaluating: 100% 32/32 [00:00<00:00, 106.27it/s]
# Valid F1: 0.7707
# ✓ Saved new best model
#
# Epoch 13/30
# Training: 100% 157/157 [00:04<00:00, 32.60it/s, loss=0.511]
# Train Loss: 1.1905
# Evaluating: 100% 32/32 [00:00<00:00, 74.12it/s]
# Valid F1: 0.7613
# No improvement for 1 epochs
#
# Epoch 14/30
# Training: 100% 157/157 [00:04<00:00, 35.41it/s, loss=0.702]
# Train Loss: 1.1012
# Evaluating: 100% 32/32 [00:00<00:00, 104.69it/s]
# Valid F1: 0.7826
# ✓ Saved new best model
#
# Epoch 15/30
# Training: 100% 157/157 [00:04<00:00, 38.87it/s, loss=2.13]
# Train Loss: 1.0348
# Evaluating: 100% 32/32 [00:00<00:00, 99.96it/s]
# Valid F1: 0.7795
# No improvement for 1 epochs
#
# Epoch 16/30
# Training: 100% 157/157 [00:05<00:00, 30.63it/s, loss=0.722]
# Train Loss: 0.9462
# Evaluating: 100% 32/32 [00:00<00:00, 100.83it/s]
# Valid F1: 0.7878
# ✓ Saved new best model
#
# Epoch 17/30
# Training: 100% 157/157 [00:04<00:00, 37.96it/s, loss=0.731]
# Train Loss: 0.9472
# Evaluating: 100% 32/32 [00:00<00:00, 98.82it/s]
# Valid F1: 0.8052
# ✓ Saved new best model
#
# Epoch 18/30
# Training: 100% 157/157 [00:04<00:00, 38.34it/s, loss=2.51]
# Train Loss: 0.8508
# Evaluating: 100% 32/32 [00:00<00:00, 79.03it/s]
# Valid F1: 0.7990
# No improvement for 1 epochs
#
# Epoch 19/30
# Training: 100% 157/157 [00:05<00:00, 29.52it/s, loss=0.118]
# Train Loss: 0.8253
# Evaluating: 100% 32/32 [00:00<00:00, 105.17it/s]
# Valid F1: 0.7975
# No improvement for 2 epochs
#
# Epoch 20/30
# Training: 100% 157/157 [00:04<00:00, 37.37it/s, loss=0.401]
# Train Loss: 0.7578
# Evaluating: 100% 32/32 [00:00<00:00, 101.22it/s]
# Valid F1: 0.8131
# ✓ Saved new best model
#
# Epoch 21/30
# Training: 100% 157/157 [00:04<00:00, 34.54it/s, loss=1.15]
# Train Loss: 0.7270
# Evaluating: 100% 32/32 [00:00<00:00, 73.54it/s]
# Valid F1: 0.7970
# No improvement for 1 epochs
#
# Epoch 22/30
# Training: 100% 157/157 [00:04<00:00, 35.52it/s, loss=0.674]
# Train Loss: 0.7265
# Evaluating: 100% 32/32 [00:00<00:00, 103.55it/s]
# Valid F1: 0.8097
# No improvement for 2 epochs
#
# Epoch 23/30
# Training: 100% 157/157 [00:04<00:00, 36.32it/s, loss=0.623]
# Train Loss: 0.6572
# Evaluating: 100% 32/32 [00:00<00:00, 103.57it/s]
# Valid F1: 0.8079
# No improvement for 3 epochs
#
# Epoch 24/30
# Training: 100% 157/157 [00:05<00:00, 30.48it/s, loss=0.796]
# Train Loss: 0.6110
# Evaluating: 100% 32/32 [00:00<00:00, 106.48it/s]
# Valid F1: 0.8202
# ✓ Saved new best model
#
# Epoch 25/30
# Training: 100% 157/157 [00:04<00:00, 38.29it/s, loss=0.362]
# Train Loss: 0.5597
# Evaluating: 100% 32/32 [00:00<00:00, 99.93it/s]
# Valid F1: 0.8195
# No improvement for 1 epochs
#
# Epoch 26/30
# Training: 100% 157/157 [00:04<00:00, 38.66it/s, loss=0.094]
# Train Loss: 0.5298
# Evaluating: 100% 32/32 [00:00<00:00, 100.69it/s]
# Valid F1: 0.8240
# ✓ Saved new best model
#
# Epoch 27/30
# Training: 100% 157/157 [00:05<00:00, 30.96it/s, loss=0.208]
# Train Loss: 0.5285
# Evaluating: 100% 32/32 [00:00<00:00, 101.21it/s]
# Valid F1: 0.8203
# No improvement for 1 epochs
#
# Epoch 28/30
# Training: 100% 157/157 [00:04<00:00, 36.38it/s, loss=0.46]
# Train Loss: 0.4988
# Evaluating: 100% 32/32 [00:00<00:00, 97.99it/s]
# Valid F1: 0.8067
# No improvement for 2 epochs
#
# Epoch 29/30
# Training: 100% 157/157 [00:04<00:00, 36.38it/s, loss=0.217]
# Train Loss: 0.4947
# Evaluating: 100% 32/32 [00:00<00:00, 81.06it/s]
# Valid F1: 0.8103
# No improvement for 3 epochs
#
# Epoch 30/30
# Training: 100% 157/157 [00:04<00:00, 33.73it/s, loss=0.776]
# Train Loss: 0.4691
# Evaluating: 100% 32/32 [00:00<00:00, 104.21it/s]
# Valid F1: 0.8111
# No improvement for 4 epochs
#
# Training completed in 0:02:29.535982
#
# Evaluating on test set...
# Evaluating: 100% 32/32 [00:00<00:00, 91.64it/s]
# ✓ Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/hi/olfactory_mitral_base
# Test F1: 0.8043
# ✓ Completed olfactory_mitral_base on wikiann_hi
#
# >>> Running Experiment: olfactory_more on wikiann_hi <<<
# Using device: cuda
# ================================================================================
# Experiment: olfactory_more
# Dataset: wikiann_hi
# ================================================================================
# Results will be saved to: /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/hi/olfactory_more
# Loading wikiann dataset from HuggingFace (unimelb-nlp/wikiann)...
# Configuration: hi
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#
# Data splits available: ['validation', 'test', 'train']
# Number of labels: 7
# Label names: ['O', 'B-PER', 'I-PER', 'B-ORG', 'I-ORG', 'B-LOC', 'I-LOC']
#
# Data splits:
#   Train: 5000 sentences
#   Valid: 1000 sentences
#   Test: 1000 sentences
#
# Building vocabularies...
# Vocabulary size: 2844
# Number of labels: 7
#
# Starting training...
#
# Epoch 1/30
# Training: 100% 157/157 [00:04<00:00, 35.20it/s, loss=3.27]
# Train Loss: 7.2022
# Evaluating: 100% 32/32 [00:00<00:00, 97.04it/s]
# Valid F1: 0.4525
# ✓ Saved new best model
#
# Epoch 2/30
# Training: 100% 157/157 [00:04<00:00, 37.19it/s, loss=3.49]
# Train Loss: 3.2268
# Evaluating: 100% 32/32 [00:00<00:00, 73.10it/s]
# Valid F1: 0.6334
# ✓ Saved new best model
#
# Epoch 3/30
# Training: 100% 157/157 [00:04<00:00, 33.57it/s, loss=1.41]
# Train Loss: 2.2088
# Evaluating: 100% 32/32 [00:00<00:00, 100.81it/s]
# Valid F1: 0.6925
# ✓ Saved new best model
#
# Epoch 4/30
# Training: 100% 157/157 [00:04<00:00, 38.50it/s, loss=0.458]
# Train Loss: 1.6407
# Evaluating: 100% 32/32 [00:00<00:00, 104.71it/s]
# Valid F1: 0.7241
# ✓ Saved new best model
#
# Epoch 5/30
# Training: 100% 157/157 [00:04<00:00, 32.39it/s, loss=5.86]
# Train Loss: 1.3636
# Evaluating: 100% 32/32 [00:00<00:00, 72.77it/s]
# Valid F1: 0.7468
# ✓ Saved new best model
#
# Epoch 6/30
# Training: 100% 157/157 [00:04<00:00, 37.17it/s, loss=1.74]
# Train Loss: 1.1011
# Evaluating: 100% 32/32 [00:00<00:00, 101.86it/s]
# Valid F1: 0.7672
# ✓ Saved new best model
#
# Epoch 7/30
# Training: 100% 157/157 [00:03<00:00, 39.38it/s, loss=1.83]
# Train Loss: 0.9394
# Evaluating: 100% 32/32 [00:00<00:00, 100.02it/s]
# Valid F1: 0.7808
# ✓ Saved new best model
#
# Epoch 8/30
# Training: 100% 157/157 [00:05<00:00, 30.89it/s, loss=0.312]
# Train Loss: 0.8185
# Evaluating: 100% 32/32 [00:00<00:00, 105.58it/s]
# Valid F1: 0.7978
# ✓ Saved new best model
#
# Epoch 9/30
# Training: 100% 157/157 [00:04<00:00, 38.52it/s, loss=0.325]
# Train Loss: 0.6954
# Evaluating: 100% 32/32 [00:00<00:00, 108.46it/s]
# Valid F1: 0.8205
# ✓ Saved new best model
#
# Epoch 10/30
# Training: 100% 157/157 [00:03<00:00, 39.37it/s, loss=0.036]
# Train Loss: 0.6024
# Evaluating: 100% 32/32 [00:00<00:00, 101.67it/s]
# Valid F1: 0.8261
# ✓ Saved new best model
#
# Epoch 11/30
# Training: 100% 157/157 [00:05<00:00, 30.80it/s, loss=0.313]
# Train Loss: 0.5115
# Evaluating: 100% 32/32 [00:00<00:00, 107.68it/s]
# Valid F1: 0.8157
# No improvement for 1 epochs
#
# Epoch 12/30
# Training: 100% 157/157 [00:04<00:00, 38.03it/s, loss=0.671]
# Train Loss: 0.4643
# Evaluating: 100% 32/32 [00:00<00:00, 100.04it/s]
# Valid F1: 0.8268
# ✓ Saved new best model
#
# Epoch 13/30
# Training: 100% 157/157 [00:04<00:00, 36.06it/s, loss=0.839]
# Train Loss: 0.4339
# Evaluating: 100% 32/32 [00:00<00:00, 76.25it/s]
# Valid F1: 0.8212
# No improvement for 1 epochs
#
# Epoch 14/30
# Training: 100% 157/157 [00:04<00:00, 33.98it/s, loss=0.345]
# Train Loss: 0.3709
# Evaluating: 100% 32/32 [00:00<00:00, 100.87it/s]
# Valid F1: 0.8224
# No improvement for 2 epochs
#
# Epoch 15/30
# Training: 100% 157/157 [00:04<00:00, 36.32it/s, loss=0.171]
# Train Loss: 0.3327
# Evaluating: 100% 32/32 [00:00<00:00, 94.97it/s]
# Valid F1: 0.8346
# ✓ Saved new best model
#
# Epoch 16/30
# Training: 100% 157/157 [00:05<00:00, 31.17it/s, loss=1.65]
# Train Loss: 0.3032
# Evaluating: 100% 32/32 [00:00<00:00, 79.06it/s]
# Valid F1: 0.8360
# ✓ Saved new best model
#
# Epoch 17/30
# Training: 100% 157/157 [00:04<00:00, 37.68it/s, loss=0.0609]
# Train Loss: 0.2736
# Evaluating: 100% 32/32 [00:00<00:00, 100.97it/s]
# Valid F1: 0.8438
# ✓ Saved new best model
#
# Epoch 18/30
# Training: 100% 157/157 [00:04<00:00, 37.04it/s, loss=0.067]
# Train Loss: 0.2444
# Evaluating: 100% 32/32 [00:00<00:00, 103.23it/s]
# Valid F1: 0.8252
# No improvement for 1 epochs
#
# Epoch 19/30
# Training: 100% 157/157 [00:05<00:00, 30.97it/s, loss=0.125]
# Train Loss: 0.2255
# Evaluating: 100% 32/32 [00:00<00:00, 103.34it/s]
# Valid F1: 0.8337
# No improvement for 2 epochs
#
# Epoch 20/30
# Training: 100% 157/157 [00:04<00:00, 35.60it/s, loss=0.267]
# Train Loss: 0.2023
# Evaluating: 100% 32/32 [00:00<00:00, 100.24it/s]
# Valid F1: 0.8484
# ✓ Saved new best model
#
# Epoch 21/30
# Training: 100% 157/157 [00:04<00:00, 37.11it/s, loss=0.0389]
# Train Loss: 0.2013
# Evaluating: 100% 32/32 [00:00<00:00, 78.31it/s]
# Valid F1: 0.8273
# No improvement for 1 epochs
#
# Epoch 22/30
# Training: 100% 157/157 [00:04<00:00, 33.08it/s, loss=0.00817]
# Train Loss: 0.1890
# Evaluating: 100% 32/32 [00:00<00:00, 109.05it/s]
# Valid F1: 0.8453
# No improvement for 2 epochs
#
# Epoch 23/30
# Training: 100% 157/157 [00:04<00:00, 36.11it/s, loss=0.0778]
# Train Loss: 0.1907
# Evaluating: 100% 32/32 [00:00<00:00, 105.75it/s]
# Valid F1: 0.8337
# No improvement for 3 epochs
#
# Epoch 24/30
# Training: 100% 157/157 [00:04<00:00, 32.22it/s, loss=0.00693]
# Train Loss: 0.1435
# Evaluating: 100% 32/32 [00:00<00:00, 74.75it/s]
# Valid F1: 0.8461
# No improvement for 4 epochs
#
# Epoch 25/30
# Training: 100% 157/157 [00:04<00:00, 37.77it/s, loss=0.51]
# Train Loss: 0.1198
# Evaluating: 100% 32/32 [00:00<00:00, 108.85it/s]
# Valid F1: 0.8397
# No improvement for 5 epochs
# Early stopping triggered
#
# Training completed in 0:02:04.235809
#
# Evaluating on test set...
# Evaluating: 100% 32/32 [00:00<00:00, 95.11it/s]
# ✓ Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/hi/olfactory_more
# Test F1: 0.8437
# ✓ Completed olfactory_more on wikiann_hi
#
# >>> Running Experiment: olfactory_mitral_more on wikiann_hi <<<
# Using device: cuda
# ================================================================================
# Experiment: olfactory_mitral_more
# Dataset: wikiann_hi
# ================================================================================
# Results will be saved to: /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/hi/olfactory_mitral_more
# Loading wikiann dataset from HuggingFace (unimelb-nlp/wikiann)...
# Configuration: hi
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#
# Data splits available: ['validation', 'test', 'train']
# Number of labels: 7
# Label names: ['O', 'B-PER', 'I-PER', 'B-ORG', 'I-ORG', 'B-LOC', 'I-LOC']
#
# Data splits:
#   Train: 5000 sentences
#   Valid: 1000 sentences
#   Test: 1000 sentences
#
# Building vocabularies...
# Vocabulary size: 2844
# Number of labels: 7
#
# Starting training...
#
# Epoch 1/30
# Training: 100% 157/157 [00:04<00:00, 34.04it/s, loss=3.46]
# Train Loss: 6.2084
# Evaluating: 100% 32/32 [00:00<00:00, 87.53it/s]
# Valid F1: 0.3066
# ✓ Saved new best model
#
# Epoch 2/30
# Training: 100% 157/157 [00:04<00:00, 32.75it/s, loss=1.87]
# Train Loss: 2.7230
# Evaluating: 100% 32/32 [00:00<00:00, 67.52it/s]
# Valid F1: 0.5129
# ✓ Saved new best model
#
# Epoch 3/30
# Training: 100% 157/157 [00:04<00:00, 38.30it/s, loss=1.3]
# Train Loss: 1.9092
# Evaluating: 100% 32/32 [00:00<00:00, 101.55it/s]
# Valid F1: 0.5573
# ✓ Saved new best model
#
# Epoch 4/30
# Training: 100% 157/157 [00:04<00:00, 38.16it/s, loss=1.63]
# Train Loss: 1.5111
# Evaluating: 100% 32/32 [00:00<00:00, 104.18it/s]
# Valid F1: 0.6317
# ✓ Saved new best model
#
# Epoch 5/30
# Training: 100% 157/157 [00:05<00:00, 29.93it/s, loss=1.69]
# Train Loss: 1.2613
# Evaluating: 100% 32/32 [00:00<00:00, 100.58it/s]
# Valid F1: 0.6120
# No improvement for 1 epochs
#
# Epoch 6/30
# Training: 100% 157/157 [00:04<00:00, 37.58it/s, loss=1.54]
# Train Loss: 1.0617
# Evaluating: 100% 32/32 [00:00<00:00, 96.89it/s]
# Valid F1: 0.6548
# ✓ Saved new best model
#
# Epoch 7/30
# Training: 100% 157/157 [00:04<00:00, 38.91it/s, loss=1.93]
# Train Loss: 0.9404
# Evaluating: 100% 32/32 [00:00<00:00, 73.35it/s]
# Valid F1: 0.6957
# ✓ Saved new best model
#
# Epoch 8/30
# Training: 100% 157/157 [00:05<00:00, 31.29it/s, loss=0.759]
# Train Loss: 0.8279
# Evaluating: 100% 32/32 [00:00<00:00, 99.49it/s]
# Valid F1: 0.6818
# No improvement for 1 epochs
#
# Epoch 9/30
# Training: 100% 157/157 [00:04<00:00, 35.74it/s, loss=0.902]
# Train Loss: 0.7606
# Evaluating: 100% 32/32 [00:00<00:00, 101.90it/s]
# Valid F1: 0.7128
# ✓ Saved new best model
#
# Epoch 10/30
# Training: 100% 157/157 [00:04<00:00, 32.96it/s, loss=0.173]
# Train Loss: 0.6913
# Evaluating: 100% 32/32 [00:00<00:00, 77.35it/s]
# Valid F1: 0.7136
# ✓ Saved new best model
#
# Epoch 11/30
# Training: 100% 157/157 [00:04<00:00, 35.99it/s, loss=0.0705]
# Train Loss: 0.6167
# Evaluating: 100% 32/32 [00:00<00:00, 103.49it/s]
# Valid F1: 0.7516
# ✓ Saved new best model
#
# Epoch 12/30
# Training: 100% 157/157 [00:04<00:00, 39.12it/s, loss=0.165]
# Train Loss: 0.5684
# Evaluating: 100% 32/32 [00:00<00:00, 101.68it/s]
# Valid F1: 0.7570
# ✓ Saved new best model
#
# Epoch 13/30
# Training: 100% 157/157 [00:05<00:00, 30.86it/s, loss=0.777]
# Train Loss: 0.5143
# Evaluating: 100% 32/32 [00:00<00:00, 96.45it/s]
# Valid F1: 0.7319
# No improvement for 1 epochs
#
# Epoch 14/30
# Training: 100% 157/157 [00:04<00:00, 36.50it/s, loss=0.937]
# Train Loss: 0.4885
# Evaluating: 100% 32/32 [00:00<00:00, 103.95it/s]
# Valid F1: 0.7105
# No improvement for 2 epochs
#
# Epoch 15/30
# Training: 100% 157/157 [00:04<00:00, 38.38it/s, loss=0.0903]
# Train Loss: 0.4312
# Evaluating: 100% 32/32 [00:00<00:00, 97.64it/s]
# Valid F1: 0.7583
# ✓ Saved new best model
#
# Epoch 16/30
# Training: 100% 157/157 [00:04<00:00, 31.71it/s, loss=0.132]
# Train Loss: 0.3936
# Evaluating: 100% 32/32 [00:00<00:00, 105.18it/s]
# Valid F1: 0.7567
# No improvement for 1 epochs
#
# Epoch 17/30
# Training: 100% 157/157 [00:04<00:00, 38.95it/s, loss=0.519]
# Train Loss: 0.3643
# Evaluating: 100% 32/32 [00:00<00:00, 103.52it/s]
# Valid F1: 0.7695
# ✓ Saved new best model
#
# Epoch 18/30
# Training: 100% 157/157 [00:04<00:00, 35.35it/s, loss=0.243]
# Train Loss: 0.3376
# Evaluating: 100% 32/32 [00:00<00:00, 71.22it/s]
# Valid F1: 0.7604
# No improvement for 1 epochs
#
# Epoch 19/30
# Training: 100% 157/157 [00:04<00:00, 32.19it/s, loss=0.0271]
# Train Loss: 0.3280
# Evaluating: 100% 32/32 [00:00<00:00, 102.42it/s]
# Valid F1: 0.7627
# No improvement for 2 epochs
#
# Epoch 20/30
# Training: 100% 157/157 [00:04<00:00, 38.18it/s, loss=0.0315]
# Train Loss: 0.2950
# Evaluating: 100% 32/32 [00:00<00:00, 99.56it/s]
# Valid F1: 0.7896
# ✓ Saved new best model
#
# Epoch 21/30
# Training: 100% 157/157 [00:04<00:00, 32.31it/s, loss=0.524]
# Train Loss: 0.2831
# Evaluating: 100% 32/32 [00:00<00:00, 66.91it/s]
# Valid F1: 0.7708
# No improvement for 1 epochs
#
# Epoch 22/30
# Training: 100% 157/157 [00:04<00:00, 39.04it/s, loss=0.0511]
# Train Loss: 0.2417
# Evaluating: 100% 32/32 [00:00<00:00, 102.60it/s]
# Valid F1: 0.7776
# No improvement for 2 epochs
#
# Epoch 23/30
# Training: 100% 157/157 [00:04<00:00, 36.57it/s, loss=0.0354]
# Train Loss: 0.2308
# Evaluating: 100% 32/32 [00:00<00:00, 98.44it/s]
# Valid F1: 0.7784
# No improvement for 3 epochs
#
# Epoch 24/30
# Training: 100% 157/157 [00:05<00:00, 30.35it/s, loss=0.0357]
# Train Loss: 0.1875
# Evaluating: 100% 32/32 [00:00<00:00, 99.49it/s]
# Valid F1: 0.7891
# No improvement for 4 epochs
#
# Epoch 25/30
# Training: 100% 157/157 [00:04<00:00, 38.97it/s, loss=0.0419]
# Train Loss: 0.1537
# Evaluating: 100% 32/32 [00:00<00:00, 102.73it/s]
# Valid F1: 0.7955
# ✓ Saved new best model
#
# Epoch 26/30
# Training: 100% 157/157 [00:04<00:00, 37.41it/s, loss=0.245]
# Train Loss: 0.1516
# Evaluating: 100% 32/32 [00:00<00:00, 71.84it/s]
# Valid F1: 0.7882
# No improvement for 1 epochs
#
# Epoch 27/30
# Training: 100% 157/157 [00:04<00:00, 31.84it/s, loss=0.0243]
# Train Loss: 0.1421
# Evaluating: 100% 32/32 [00:00<00:00, 98.69it/s]
# Valid F1: 0.7941
# No improvement for 2 epochs
#
# Epoch 28/30
# Training: 100% 157/157 [00:04<00:00, 36.29it/s, loss=0.0371]
# Train Loss: 0.1339
# Evaluating: 100% 32/32 [00:00<00:00, 99.11it/s]
# Valid F1: 0.7816
# No improvement for 3 epochs
#
# Epoch 29/30
# Training: 100% 157/157 [00:04<00:00, 32.95it/s, loss=0.176]
# Train Loss: 0.1141
# Evaluating: 100% 32/32 [00:00<00:00, 75.06it/s]
# Valid F1: 0.7997
# ✓ Saved new best model
#
# Epoch 30/30
# Training: 100% 157/157 [00:04<00:00, 37.80it/s, loss=0.522]
# Train Loss: 0.1078
# Evaluating: 100% 32/32 [00:00<00:00, 102.94it/s]
# Valid F1: 0.7751
# No improvement for 1 epochs
#
# Training completed in 0:02:29.789521
#
# Evaluating on test set...
# Evaluating: 100% 32/32 [00:00<00:00, 89.34it/s]
# ✓ Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/hi/olfactory_mitral_more
# Test F1: 0.8194
# ✓ Completed olfactory_mitral_more on wikiann_hi
#
# ################################################################################
# PROCESSING DATASET: wikiann_mr
# ################################################################################
#
# >>> Running Experiment: baseline on wikiann_mr <<<
# Using device: cuda
# ================================================================================
# Experiment: baseline
# Dataset: wikiann_mr
# ================================================================================
# Results will be saved to: /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/mr/baseline
# Loading wikiann dataset from HuggingFace (unimelb-nlp/wikiann)...
# Configuration: mr
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# mr/validation-00000-of-00001.parquet: 100% 75.0k/75.0k [00:02<00:00, 30.6kB/s]
# mr/test-00000-of-00001.parquet: 100% 75.9k/75.9k [00:02<00:00, 35.6kB/s]
# mr/train-00000-of-00001.parquet: 100% 373k/373k [00:00<00:00, 543kB/s]
# Generating validation split: 100% 1000/1000 [00:00<00:00, 158670.80 examples/s]
# Generating test split: 100% 1000/1000 [00:00<00:00, 284109.19 examples/s]
# Generating train split: 100% 5000/5000 [00:00<00:00, 555698.88 examples/s]
#
# Data splits available: ['validation', 'test', 'train']
# Number of labels: 7
# Label names: ['O', 'B-PER', 'I-PER', 'B-ORG', 'I-ORG', 'B-LOC', 'I-LOC']
#
# Data splits:
#   Train: 5000 sentences
#   Valid: 1000 sentences
#   Test: 1000 sentences
#
# Building vocabularies...
# Vocabulary size: 3208
# Number of labels: 7
#
# Starting training...
#
# Epoch 1/30
# Training: 100% 157/157 [00:05<00:00, 30.50it/s, loss=1.16]
# Train Loss: 6.7950
# Evaluating: 100% 32/32 [00:00<00:00, 99.03it/s]
# Valid F1: 0.4621
# ✓ Saved new best model
#
# Epoch 2/30
# Training: 100% 157/157 [00:03<00:00, 42.99it/s, loss=1.5]
# Train Loss: 3.2453
# Evaluating: 100% 32/32 [00:00<00:00, 101.88it/s]
# Valid F1: 0.6148
# ✓ Saved new best model
#
# Epoch 3/30
# Training: 100% 157/157 [00:03<00:00, 42.34it/s, loss=1.66]
# Train Loss: 2.1803
# Evaluating: 100% 32/32 [00:00<00:00, 102.86it/s]
# Valid F1: 0.6888
# ✓ Saved new best model
#
# Epoch 4/30
# Training: 100% 157/157 [00:04<00:00, 32.42it/s, loss=3.29]
# Train Loss: 1.5986
# Evaluating: 100% 32/32 [00:00<00:00, 101.80it/s]
# Valid F1: 0.7092
# ✓ Saved new best model
#
# Epoch 5/30
# Training: 100% 157/157 [00:03<00:00, 41.86it/s, loss=2.16]
# Train Loss: 1.2485
# Evaluating: 100% 32/32 [00:00<00:00, 91.47it/s]
# Valid F1: 0.7327
# ✓ Saved new best model
#
# Epoch 6/30
# Training: 100% 157/157 [00:03<00:00, 41.75it/s, loss=0.536]
# Train Loss: 0.9864
# Evaluating: 100% 32/32 [00:00<00:00, 97.17it/s]
# Valid F1: 0.7346
# ✓ Saved new best model
#
# Epoch 7/30
# Training: 100% 157/157 [00:04<00:00, 31.89it/s, loss=0.273]
# Train Loss: 0.8218
# Evaluating: 100% 32/32 [00:00<00:00, 97.55it/s]
# Valid F1: 0.7408
# ✓ Saved new best model
#
# Epoch 8/30
# Training: 100% 157/157 [00:03<00:00, 42.71it/s, loss=0.38]
# Train Loss: 0.7026
# Evaluating: 100% 32/32 [00:00<00:00, 102.13it/s]
# Valid F1: 0.7596
# ✓ Saved new best model
#
# Epoch 9/30
# Training: 100% 157/157 [00:03<00:00, 42.90it/s, loss=0.707]
# Train Loss: 0.5958
# Evaluating: 100% 32/32 [00:00<00:00, 102.36it/s]
# Valid F1: 0.7513
# No improvement for 1 epochs
#
# Epoch 10/30
# Training: 100% 157/157 [00:04<00:00, 32.51it/s, loss=0.532]
# Train Loss: 0.5063
# Evaluating: 100% 32/32 [00:00<00:00, 99.44it/s]
# Valid F1: 0.7645
# ✓ Saved new best model
#
# Epoch 11/30
# Training: 100% 157/157 [00:03<00:00, 42.90it/s, loss=0.538]
# Train Loss: 0.4323
# Evaluating: 100% 32/32 [00:00<00:00, 98.64it/s]
# Valid F1: 0.7608
# No improvement for 1 epochs
#
# Epoch 12/30
# Training: 100% 157/157 [00:03<00:00, 42.53it/s, loss=0.0209]
# Train Loss: 0.3931
# Evaluating: 100% 32/32 [00:00<00:00, 101.58it/s]
# Valid F1: 0.7403
# No improvement for 2 epochs
#
# Epoch 13/30
# Training: 100% 157/157 [00:05<00:00, 30.65it/s, loss=0.324]
# Train Loss: 0.3560
# Evaluating: 100% 32/32 [00:00<00:00, 101.19it/s]
# Valid F1: 0.7655
# ✓ Saved new best model
#
# Epoch 14/30
# Training: 100% 157/157 [00:03<00:00, 43.17it/s, loss=0.121]
# Train Loss: 0.3103
# Evaluating: 100% 32/32 [00:00<00:00, 101.23it/s]
# Valid F1: 0.7705
# ✓ Saved new best model
#
# Epoch 15/30
# Training: 100% 157/157 [00:03<00:00, 42.37it/s, loss=3.46]
# Train Loss: 0.2973
# Evaluating: 100% 32/32 [00:00<00:00, 101.99it/s]
# Valid F1: 0.7758
# ✓ Saved new best model
#
# Epoch 16/30
# Training: 100% 157/157 [00:04<00:00, 34.45it/s, loss=0.126]
# Train Loss: 0.2605
# Evaluating: 100% 32/32 [00:00<00:00, 103.18it/s]
# Valid F1: 0.7699
# No improvement for 1 epochs
#
# Epoch 17/30
# Training: 100% 157/157 [00:03<00:00, 39.69it/s, loss=0.182]
# Train Loss: 0.2523
# Evaluating: 100% 32/32 [00:00<00:00, 90.77it/s]
# Valid F1: 0.7644
# No improvement for 2 epochs
#
# Epoch 18/30
# Training: 100% 157/157 [00:03<00:00, 43.14it/s, loss=0.489]
# Train Loss: 0.2116
# Evaluating: 100% 32/32 [00:00<00:00, 81.10it/s]
# Valid F1: 0.7667
# No improvement for 3 epochs
#
# Epoch 19/30
# Training: 100% 157/157 [00:04<00:00, 34.21it/s, loss=0.0291]
# Train Loss: 0.1808
# Evaluating: 100% 32/32 [00:00<00:00, 101.96it/s]
# Valid F1: 0.7801
# ✓ Saved new best model
#
# Epoch 20/30
# Training: 100% 157/157 [00:03<00:00, 41.82it/s, loss=0.0258]
# Train Loss: 0.1599
# Evaluating: 100% 32/32 [00:00<00:00, 103.48it/s]
# Valid F1: 0.7732
# No improvement for 1 epochs
#
# Epoch 21/30
# Training: 100% 157/157 [00:03<00:00, 42.62it/s, loss=0.00214]
# Train Loss: 0.1450
# Evaluating: 100% 32/32 [00:00<00:00, 70.10it/s]
# Valid F1: 0.7734
# No improvement for 2 epochs
#
# Epoch 22/30
# Training: 100% 157/157 [00:04<00:00, 31.70it/s, loss=0.398]
# Train Loss: 0.1456
# Evaluating: 100% 32/32 [00:00<00:00, 98.53it/s]
# Valid F1: 0.7654
# No improvement for 3 epochs
#
# Epoch 23/30
# Training: 100% 157/157 [00:03<00:00, 43.66it/s, loss=0.0113]
# Train Loss: 0.1290
# Evaluating: 100% 32/32 [00:00<00:00, 98.69it/s]
# Valid F1: 0.7721
# No improvement for 4 epochs
#
# Epoch 24/30
# Training: 100% 157/157 [00:03<00:00, 43.40it/s, loss=0.00811]
# Train Loss: 0.1178
# Evaluating: 100% 32/32 [00:00<00:00, 67.39it/s]
# Valid F1: 0.7761
# No improvement for 5 epochs
# Early stopping triggered
#
# Training completed in 0:01:50.560214
#
# Evaluating on test set...
# Evaluating: 100% 32/32 [00:00<00:00, 72.84it/s]
# ✓ Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/mr/baseline
# Test F1: 0.7881
# ✓ Completed baseline on wikiann_mr
#
# >>> Running Experiment: olfactory_base on wikiann_mr <<<
# Using device: cuda
# ================================================================================
# Experiment: olfactory_base
# Dataset: wikiann_mr
# ================================================================================
# Results will be saved to: /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/mr/olfactory_base
# Loading wikiann dataset from HuggingFace (unimelb-nlp/wikiann)...
# Configuration: mr
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#
# Data splits available: ['validation', 'test', 'train']
# Number of labels: 7
# Label names: ['O', 'B-PER', 'I-PER', 'B-ORG', 'I-ORG', 'B-LOC', 'I-LOC']
#
# Data splits:
#   Train: 5000 sentences
#   Valid: 1000 sentences
#   Test: 1000 sentences
#
# Building vocabularies...
# Vocabulary size: 3208
# Number of labels: 7
#
# Starting training...
#
# Epoch 1/30
# Training: 100% 157/157 [00:05<00:00, 28.36it/s, loss=2.96]
# Train Loss: 7.5951
# Evaluating: 100% 32/32 [00:00<00:00, 94.24it/s]
# Valid F1: 0.2932
# ✓ Saved new best model
#
# Epoch 2/30
# Training: 100% 157/157 [00:04<00:00, 38.01it/s, loss=1.92]
# Train Loss: 3.8436
# Evaluating: 100% 32/32 [00:00<00:00, 96.21it/s]
# Valid F1: 0.5105
# ✓ Saved new best model
#
# Epoch 3/30
# Training: 100% 157/157 [00:04<00:00, 37.64it/s, loss=3.09]
# Train Loss: 2.7654
# Evaluating: 100% 32/32 [00:00<00:00, 73.51it/s]
# Valid F1: 0.5960
# ✓ Saved new best model
#
# Epoch 4/30
# Training: 100% 157/157 [00:04<00:00, 32.14it/s, loss=3.29]
# Train Loss: 2.1698
# Evaluating: 100% 32/32 [00:00<00:00, 92.85it/s]
# Valid F1: 0.6376
# ✓ Saved new best model
#
# Epoch 5/30
# Training: 100% 157/157 [00:04<00:00, 37.83it/s, loss=0.425]
# Train Loss: 1.8070
# Evaluating: 100% 32/32 [00:00<00:00, 87.71it/s]
# Valid F1: 0.6979
# ✓ Saved new best model
#
# Epoch 6/30
# Training: 100% 157/157 [00:04<00:00, 32.72it/s, loss=1.71]
# Train Loss: 1.5524
# Evaluating: 100% 32/32 [00:00<00:00, 72.70it/s]
# Valid F1: 0.7164
# ✓ Saved new best model
#
# Epoch 7/30
# Training: 100% 157/157 [00:04<00:00, 37.00it/s, loss=1.22]
# Train Loss: 1.3511
# Evaluating: 100% 32/32 [00:00<00:00, 98.11it/s]
# Valid F1: 0.7195
# ✓ Saved new best model
#
# Epoch 8/30
# Training: 100% 157/157 [00:04<00:00, 38.50it/s, loss=2.34]
# Train Loss: 1.2273
# Evaluating: 100% 32/32 [00:00<00:00, 100.19it/s]
# Valid F1: 0.7467
# ✓ Saved new best model
#
# Epoch 9/30
# Training: 100% 157/157 [00:05<00:00, 31.13it/s, loss=1.46]
# Train Loss: 1.1275
# Evaluating: 100% 32/32 [00:00<00:00, 86.30it/s]
# Valid F1: 0.7542
# ✓ Saved new best model
#
# Epoch 10/30
# Training: 100% 157/157 [00:04<00:00, 38.68it/s, loss=0.634]
# Train Loss: 1.0145
# Evaluating: 100% 32/32 [00:00<00:00, 96.81it/s]
# Valid F1: 0.7525
# No improvement for 1 epochs
#
# Epoch 11/30
# Training: 100% 157/157 [00:04<00:00, 37.51it/s, loss=0.983]
# Train Loss: 0.9704
# Evaluating: 100% 32/32 [00:00<00:00, 58.25it/s]
# Valid F1: 0.7510
# No improvement for 2 epochs
#
# Epoch 12/30
# Training: 100% 157/157 [00:05<00:00, 30.94it/s, loss=0.367]
# Train Loss: 0.8626
# Evaluating: 100% 32/32 [00:00<00:00, 98.67it/s]
# Valid F1: 0.7732
# ✓ Saved new best model
#
# Epoch 13/30
# Training: 100% 157/157 [00:04<00:00, 38.95it/s, loss=0.0238]
# Train Loss: 0.8245
# Evaluating: 100% 32/32 [00:00<00:00, 98.18it/s]
# Valid F1: 0.7795
# ✓ Saved new best model
#
# Epoch 14/30
# Training: 100% 157/157 [00:04<00:00, 32.47it/s, loss=0.409]
# Train Loss: 0.7960
# Evaluating: 100% 32/32 [00:00<00:00, 70.43it/s]
# Valid F1: 0.7821
# ✓ Saved new best model
#
# Epoch 15/30
# Training: 100% 157/157 [00:04<00:00, 36.62it/s, loss=1.52]
# Train Loss: 0.7358
# Evaluating: 100% 32/32 [00:00<00:00, 93.82it/s]
# Valid F1: 0.7700
# No improvement for 1 epochs
#
# Epoch 16/30
# Training: 100% 157/157 [00:04<00:00, 35.67it/s, loss=0.721]
# Train Loss: 0.6879
# Evaluating: 100% 32/32 [00:00<00:00, 96.04it/s]
# Valid F1: 0.7756
# No improvement for 2 epochs
#
# Epoch 17/30
# Training: 100% 157/157 [00:05<00:00, 30.58it/s, loss=1.32]
# Train Loss: 0.6282
# Evaluating: 100% 32/32 [00:00<00:00, 99.86it/s]
# Valid F1: 0.7888
# ✓ Saved new best model
#
# Epoch 18/30
# Training: 100% 157/157 [00:04<00:00, 38.02it/s, loss=2.13]
# Train Loss: 0.6178
# Evaluating: 100% 32/32 [00:00<00:00, 93.55it/s]
# Valid F1: 0.7647
# No improvement for 1 epochs
#
# Epoch 19/30
# Training: 100% 157/157 [00:04<00:00, 38.66it/s, loss=0.186]
# Train Loss: 0.5538
# Evaluating: 100% 32/32 [00:00<00:00, 80.20it/s]
# Valid F1: 0.7882
# No improvement for 2 epochs
#
# Epoch 20/30
# Training: 100% 157/157 [00:05<00:00, 29.40it/s, loss=1.25]
# Train Loss: 0.5457
# Evaluating: 100% 32/32 [00:00<00:00, 94.78it/s]
# Valid F1: 0.7775
# No improvement for 3 epochs
#
# Epoch 21/30
# Training: 100% 157/157 [00:04<00:00, 38.80it/s, loss=0.152]
# Train Loss: 0.4518
# Evaluating: 100% 32/32 [00:00<00:00, 98.96it/s]
# Valid F1: 0.7744
# No improvement for 4 epochs
#
# Epoch 22/30
# Training: 100% 157/157 [00:04<00:00, 35.42it/s, loss=0.0659]
# Train Loss: 0.4206
# Evaluating: 100% 32/32 [00:00<00:00, 70.24it/s]
# Valid F1: 0.7829
# No improvement for 5 epochs
# Early stopping triggered
#
# Training completed in 0:01:51.322021
#
# Evaluating on test set...
# Evaluating: 100% 32/32 [00:00<00:00, 65.59it/s]
# ✓ Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/mr/olfactory_base
# Test F1: 0.7891
# ✓ Completed olfactory_base on wikiann_mr
#
# >>> Running Experiment: olfactory_mitral_base on wikiann_mr <<<
# Using device: cuda
# ================================================================================
# Experiment: olfactory_mitral_base
# Dataset: wikiann_mr
# ================================================================================
# Results will be saved to: /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/mr/olfactory_mitral_base
# Loading wikiann dataset from HuggingFace (unimelb-nlp/wikiann)...
# Configuration: mr
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#
# Data splits available: ['validation', 'test', 'train']
# Number of labels: 7
# Label names: ['O', 'B-PER', 'I-PER', 'B-ORG', 'I-ORG', 'B-LOC', 'I-LOC']
#
# Data splits:
#   Train: 5000 sentences
#   Valid: 1000 sentences
#   Test: 1000 sentences
#
# Building vocabularies...
# Vocabulary size: 3208
# Number of labels: 7
#
# Starting training...
#
# Epoch 1/30
# Training: 100% 157/157 [00:05<00:00, 28.13it/s, loss=8.14]
# Train Loss: 8.9581
# Evaluating: 100% 32/32 [00:00<00:00, 95.12it/s]
# Valid F1: 0.2463
# ✓ Saved new best model
#
# Epoch 2/30
# Training: 100% 157/157 [00:03<00:00, 40.02it/s, loss=2.58]
# Train Loss: 4.8957
# Evaluating: 100% 32/32 [00:00<00:00, 94.74it/s]
# Valid F1: 0.4802
# ✓ Saved new best model
#
# Epoch 3/30
# Training: 100% 157/157 [00:04<00:00, 36.51it/s, loss=3.29]
# Train Loss: 3.4692
# Evaluating: 100% 32/32 [00:00<00:00, 72.87it/s]
# Valid F1: 0.5696
# ✓ Saved new best model
#
# Epoch 4/30
# Training: 100% 157/157 [00:04<00:00, 34.61it/s, loss=3.84]
# Train Loss: 2.7570
# Evaluating: 100% 32/32 [00:00<00:00, 99.97it/s]
# Valid F1: 0.6139
# ✓ Saved new best model
#
# Epoch 5/30
# Training: 100% 157/157 [00:04<00:00, 38.94it/s, loss=1.05]
# Train Loss: 2.3110
# Evaluating: 100% 32/32 [00:00<00:00, 94.79it/s]
# Valid F1: 0.6432
# ✓ Saved new best model
#
# Epoch 6/30
# Training: 100% 157/157 [00:04<00:00, 32.36it/s, loss=0.744]
# Train Loss: 2.0006
# Evaluating: 100% 32/32 [00:00<00:00, 63.09it/s]
# Valid F1: 0.6648
# ✓ Saved new best model
#
# Epoch 7/30
# Training: 100% 157/157 [00:03<00:00, 39.28it/s, loss=0.494]
# Train Loss: 1.8478
# Evaluating: 100% 32/32 [00:00<00:00, 96.54it/s]
# Valid F1: 0.6858
# ✓ Saved new best model
#
# Epoch 8/30
# Training: 100% 157/157 [00:04<00:00, 39.13it/s, loss=2.9]
# Train Loss: 1.6984
# Evaluating: 100% 32/32 [00:00<00:00, 95.68it/s]
# Valid F1: 0.7002
# ✓ Saved new best model
#
# Epoch 9/30
# Training: 100% 157/157 [00:05<00:00, 30.97it/s, loss=1.6]
# Train Loss: 1.5878
# Evaluating: 100% 32/32 [00:00<00:00, 99.65it/s]
# Valid F1: 0.7057
# ✓ Saved new best model
#
# Epoch 10/30
# Training: 100% 157/157 [00:03<00:00, 39.32it/s, loss=1.19]
# Train Loss: 1.4737
# Evaluating: 100% 32/32 [00:00<00:00, 101.64it/s]
# Valid F1: 0.7178
# ✓ Saved new best model
#
# Epoch 11/30
# Training: 100% 157/157 [00:03<00:00, 40.19it/s, loss=0.597]
# Train Loss: 1.4341
# Evaluating: 100% 32/32 [00:00<00:00, 101.45it/s]
# Valid F1: 0.7273
# ✓ Saved new best model
#
# Epoch 12/30
# Training: 100% 157/157 [00:04<00:00, 31.93it/s, loss=0.552]
# Train Loss: 1.3078
# Evaluating: 100% 32/32 [00:00<00:00, 95.61it/s]
# Valid F1: 0.7223
# No improvement for 1 epochs
#
# Epoch 13/30
# Training: 100% 157/157 [00:04<00:00, 38.88it/s, loss=3.57]
# Train Loss: 1.2824
# Evaluating: 100% 32/32 [00:00<00:00, 100.06it/s]
# Valid F1: 0.7273
# No improvement for 2 epochs
#
# Epoch 14/30
# Training: 100% 157/157 [00:04<00:00, 35.82it/s, loss=0.565]
# Train Loss: 1.2211
# Evaluating: 100% 32/32 [00:00<00:00, 65.35it/s]
# Valid F1: 0.7222
# No improvement for 3 epochs
#
# Epoch 15/30
# Training: 100% 157/157 [00:04<00:00, 35.39it/s, loss=1.18]
# Train Loss: 1.0999
# Evaluating: 100% 32/32 [00:00<00:00, 91.54it/s]
# Valid F1: 0.7315
# ✓ Saved new best model
#
# Epoch 16/30
# Training: 100% 157/157 [00:03<00:00, 39.45it/s, loss=0.997]
# Train Loss: 1.0743
# Evaluating: 100% 32/32 [00:00<00:00, 99.86it/s]
# Valid F1: 0.7261
# No improvement for 1 epochs
#
# Epoch 17/30
# Training: 100% 157/157 [00:04<00:00, 33.76it/s, loss=0.963]
# Train Loss: 1.0231
# Evaluating: 100% 32/32 [00:00<00:00, 69.13it/s]
# Valid F1: 0.7393
# ✓ Saved new best model
#
# Epoch 18/30
# Training: 100% 157/157 [00:04<00:00, 38.21it/s, loss=1.04]
# Train Loss: 1.0091
# Evaluating: 100% 32/32 [00:00<00:00, 99.88it/s]
# Valid F1: 0.7402
# ✓ Saved new best model
#
# Epoch 19/30
# Training: 100% 157/157 [00:04<00:00, 38.06it/s, loss=0.982]
# Train Loss: 1.0058
# Evaluating: 100% 32/32 [00:00<00:00, 87.20it/s]
# Valid F1: 0.7383
# No improvement for 1 epochs
#
# Epoch 20/30
# Training: 100% 157/157 [00:05<00:00, 28.36it/s, loss=0.507]
# Train Loss: 0.9577
# Evaluating: 100% 32/32 [00:00<00:00, 89.84it/s]
# Valid F1: 0.7368
# No improvement for 2 epochs
#
# Epoch 21/30
# Training: 100% 157/157 [00:04<00:00, 37.64it/s, loss=0.589]
# Train Loss: 0.9477
# Evaluating: 100% 32/32 [00:00<00:00, 93.48it/s]
# Valid F1: 0.7314
# No improvement for 3 epochs
#
# Epoch 22/30
# Training: 100% 157/157 [00:04<00:00, 38.52it/s, loss=0.135]
# Train Loss: 0.8870
# Evaluating: 100% 32/32 [00:00<00:00, 72.71it/s]
# Valid F1: 0.7454
# ✓ Saved new best model
#
# Epoch 23/30
# Training: 100% 157/157 [00:05<00:00, 31.39it/s, loss=2.46]
# Train Loss: 0.8773
# Evaluating: 100% 32/32 [00:00<00:00, 94.67it/s]
# Valid F1: 0.7496
# ✓ Saved new best model
#
# Epoch 24/30
# Training: 100% 157/157 [00:04<00:00, 38.70it/s, loss=0.57]
# Train Loss: 0.8352
# Evaluating: 100% 32/32 [00:00<00:00, 100.70it/s]
# Valid F1: 0.7453
# No improvement for 1 epochs
#
# Epoch 25/30
# Training: 100% 157/157 [00:04<00:00, 35.56it/s, loss=1.31]
# Train Loss: 0.8465
# Evaluating: 100% 32/32 [00:00<00:00, 68.10it/s]
# Valid F1: 0.7394
# No improvement for 2 epochs
#
# Epoch 26/30
# Training: 100% 157/157 [00:04<00:00, 32.12it/s, loss=0.468]
# Train Loss: 0.8161
# Evaluating: 100% 32/32 [00:00<00:00, 93.71it/s]
# Valid F1: 0.7534
# ✓ Saved new best model
#
# Epoch 27/30
# Training: 100% 157/157 [00:04<00:00, 38.89it/s, loss=0.751]
# Train Loss: 0.8094
# Evaluating: 100% 32/32 [00:00<00:00, 86.86it/s]
# Valid F1: 0.7454
# No improvement for 1 epochs
#
# Epoch 28/30
# Training: 100% 157/157 [00:05<00:00, 30.63it/s, loss=0.614]
# Train Loss: 0.8233
# Evaluating: 100% 32/32 [00:00<00:00, 61.99it/s]
# Valid F1: 0.7497
# No improvement for 2 epochs
#
# Epoch 29/30
# Training: 100% 157/157 [00:04<00:00, 36.09it/s, loss=1.29]
# Train Loss: 0.7909
# Evaluating: 100% 32/32 [00:00<00:00, 93.35it/s]
# Valid F1: 0.7554
# ✓ Saved new best model
#
# Epoch 30/30
# Training: 100% 157/157 [00:03<00:00, 39.27it/s, loss=0.902]
# Train Loss: 0.7887
# Evaluating: 100% 32/32 [00:00<00:00, 100.08it/s]
# Valid F1: 0.7530
# No improvement for 1 epochs
#
# Training completed in 0:02:29.012041
#
# Evaluating on test set...
# Evaluating: 100% 32/32 [00:00<00:00, 91.13it/s]
# ✓ Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/mr/olfactory_mitral_base
# Test F1: 0.7632
# ✓ Completed olfactory_mitral_base on wikiann_mr
#
# >>> Running Experiment: olfactory_more on wikiann_mr <<<
# Using device: cuda
# ================================================================================
# Experiment: olfactory_more
# Dataset: wikiann_mr
# ================================================================================
# Results will be saved to: /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/mr/olfactory_more
# Loading wikiann dataset from HuggingFace (unimelb-nlp/wikiann)...
# Configuration: mr
#
# Data splits available: ['validation', 'test', 'train']
# Number of labels: 7
# Label names: ['O', 'B-PER', 'I-PER', 'B-ORG', 'I-ORG', 'B-LOC', 'I-LOC']
#
# Data splits:
#   Train: 5000 sentences
#   Valid: 1000 sentences
#   Test: 1000 sentences
#
# Building vocabularies...
# Vocabulary size: 3208
# Number of labels: 7
#
# Starting training...
#
# Epoch 1/30
# Training: 100% 157/157 [00:05<00:00, 28.86it/s, loss=3.61]
# Train Loss: 6.1005
# Evaluating: 100% 32/32 [00:00<00:00, 60.24it/s]
# Valid F1: 0.3989
# ✓ Saved new best model
#
# Epoch 2/30
# Training: 100% 157/157 [00:04<00:00, 39.01it/s, loss=2.4]
# Train Loss: 2.8987
# Evaluating: 100% 32/32 [00:00<00:00, 96.39it/s]
# Valid F1: 0.5524
# ✓ Saved new best model
#
# Epoch 3/30
# Training: 100% 157/157 [00:04<00:00, 38.50it/s, loss=2.19]
# Train Loss: 2.0321
# Evaluating: 100% 32/32 [00:00<00:00, 95.65it/s]
# Valid F1: 0.6548
# ✓ Saved new best model
#
# Epoch 4/30
# Training: 100% 157/157 [00:05<00:00, 30.70it/s, loss=1.38]
# Train Loss: 1.5635
# Evaluating: 100% 32/32 [00:00<00:00, 100.03it/s]
# Valid F1: 0.6417
# No improvement for 1 epochs
#
# Epoch 5/30
# Training: 100% 157/157 [00:04<00:00, 37.38it/s, loss=1.96]
# Train Loss: 1.2795
# Evaluating: 100% 32/32 [00:00<00:00, 100.48it/s]
# Valid F1: 0.6637
# ✓ Saved new best model
#
# Epoch 6/30
# Training: 100% 157/157 [00:04<00:00, 38.94it/s, loss=3.7]
# Train Loss: 1.1552
# Evaluating: 100% 32/32 [00:00<00:00, 69.39it/s]
# Valid F1: 0.6981
# ✓ Saved new best model
#
# Epoch 7/30
# Training: 100% 157/157 [00:04<00:00, 32.05it/s, loss=0.452]
# Train Loss: 0.9963
# Evaluating: 100% 32/32 [00:00<00:00, 96.59it/s]
# Valid F1: 0.7095
# ✓ Saved new best model
#
# Epoch 8/30
# Training: 100% 157/157 [00:04<00:00, 39.16it/s, loss=0.473]
# Train Loss: 0.8608
# Evaluating: 100% 32/32 [00:00<00:00, 95.15it/s]
# Valid F1: 0.7368
# ✓ Saved new best model
#
# Epoch 9/30
# Training: 100% 157/157 [00:04<00:00, 35.03it/s, loss=1.37]
# Train Loss: 0.7867
# Evaluating: 100% 32/32 [00:00<00:00, 70.42it/s]
# Valid F1: 0.7151
# No improvement for 1 epochs
#
# Epoch 10/30
# Training: 100% 157/157 [00:04<00:00, 31.89it/s, loss=0.0976]
# Train Loss: 0.6978
# Evaluating: 100% 32/32 [00:00<00:00, 92.99it/s]
# Valid F1: 0.7488
# ✓ Saved new best model
#
# Epoch 11/30
# Training: 100% 157/157 [00:03<00:00, 39.46it/s, loss=0.886]
# Train Loss: 0.6452
# Evaluating: 100% 32/32 [00:00<00:00, 98.62it/s]
# Valid F1: 0.7348
# No improvement for 1 epochs
#
# Epoch 12/30
# Training: 100% 157/157 [00:05<00:00, 30.67it/s, loss=0.553]
# Train Loss: 0.5982
# Evaluating: 100% 32/32 [00:00<00:00, 99.33it/s]
# Valid F1: 0.7391
# No improvement for 2 epochs
#
# Epoch 13/30
# Training: 100% 157/157 [00:04<00:00, 35.86it/s, loss=0.234]
# ...
# Valid F1: 0.5771
# No improvement for 2 epochs
#
# Epoch 22/30
# Training: 100% 32/32 [00:00<00:00, 36.76it/s, loss=1.65]
# Train Loss: 1.4520
# Evaluating: 100% 32/32 [00:00<00:00, 90.49it/s]
# Valid F1: 0.5749
# No improvement for 3 epochs
#
# Epoch 23/30
# Training: 100% 32/32 [00:01<00:00, 27.16it/s, loss=0.865]
# Train Loss: 1.2781
# Evaluating: 100% 32/32 [00:00<00:00, 57.84it/s]
# Valid F1: 0.5870
# No improvement for 4 epochs
#
# Epoch 24/30
# Training: 100% 32/32 [00:01<00:00, 23.87it/s, loss=1.84]
# Train Loss: 1.2508
# Evaluating: 100% 32/32 [00:00<00:00, 68.04it/s]
# Valid F1: 0.5725
# No improvement for 5 epochs
# Early stopping triggered
#
# Training completed in 0:00:37.963757
#
# Evaluating on test set...
# Evaluating: 100% 32/32 [00:00<00:00, 84.03it/s]
# ✓ Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/te/olfactory_base
# Test F1: 0.5721
# ✓ Completed olfactory_base on wikiann_te
#
# >>> Running Experiment: olfactory_mitral_base on wikiann_te <<<
# Using device: cuda
# ================================================================================
# Experiment: olfactory_mitral_base
# Dataset: wikiann_te
# ================================================================================
# Results will be saved to: /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/te/olfactory_mitral_base
# Loading wikiann dataset from HuggingFace (unimelb-nlp/wikiann)...
# Configuration: te
#
# Data splits available: ['validation', 'test', 'train']
# Number of labels: 7
# Label names: ['O', 'B-PER', 'I-PER', 'B-ORG', 'I-ORG', 'B-LOC', 'I-LOC']
#
# Data splits:
#   Train: 1000 sentences
#   Valid: 1000 sentences
#   Test: 1000 sentences
#
# Building vocabularies...
# Vocabulary size: 833
# Number of labels: 7
#
# Starting training...
#
# Epoch 1/30
# Training: 100% 32/32 [00:01<00:00, 17.54it/s, loss=14.1]
# Train Loss: 17.8767
# Evaluating: 100% 32/32 [00:00<00:00, 56.60it/s]
# Valid F1: 0.0221
# ✓ Saved new best model
#
# Epoch 2/30
# Training: 100% 32/32 [00:00<00:00, 33.88it/s, loss=11]
# Train Loss: 11.6388
# Evaluating: 100% 32/32 [00:00<00:00, 83.39it/s]
# Valid F1: 0.0021
# No improvement for 1 epochs
#
# Epoch 3/30
# Training: 100% 32/32 [00:00<00:00, 35.38it/s, loss=8.15]
# Train Loss: 10.3245
# Evaluating: 100% 32/32 [00:00<00:00, 81.67it/s]
# Valid F1: 0.0042
# No improvement for 2 epochs
#
# Epoch 4/30
# Training: 100% 32/32 [00:00<00:00, 37.24it/s, loss=7.47]
# Train Loss: 8.8550
# Evaluating: 100% 32/32 [00:00<00:00, 86.27it/s]
# Valid F1: 0.0524
# ✓ Saved new best model
#
# Epoch 5/30
# Training: 100% 32/32 [00:00<00:00, 35.49it/s, loss=5.88]
# Train Loss: 7.1674
# Evaluating: 100% 32/32 [00:00<00:00, 84.63it/s]
# Valid F1: 0.1714
# ✓ Saved new best model
#
# Epoch 6/30
# Training: 100% 32/32 [00:00<00:00, 34.58it/s, loss=5.98]
# Train Loss: 6.1818
# Evaluating: 100% 32/32 [00:00<00:00, 85.94it/s]
# Valid F1: 0.2408
# ✓ Saved new best model
#
# Epoch 7/30
# Training: 100% 32/32 [00:00<00:00, 33.84it/s, loss=4.76]
# Train Loss: 5.5468
# Evaluating: 100% 32/32 [00:00<00:00, 87.09it/s]
# Valid F1: 0.2578
# ✓ Saved new best model
#
# Epoch 8/30
# Training: 100% 32/32 [00:00<00:00, 35.37it/s, loss=6.15]
# Train Loss: 5.0806
# Evaluating: 100% 32/32 [00:00<00:00, 81.00it/s]
# Valid F1: 0.3621
# ✓ Saved new best model
#
# Epoch 9/30
# Training: 100% 32/32 [00:01<00:00, 25.63it/s, loss=4.9]
# Train Loss: 4.7887
# Evaluating: 100% 32/32 [00:00<00:00, 63.66it/s]
# Valid F1: 0.3407
# No improvement for 1 epochs
#
# Epoch 10/30
# Training: 100% 32/32 [00:01<00:00, 24.60it/s, loss=3.26]
# Train Loss: 4.4541
# Evaluating: 100% 32/32 [00:00<00:00, 84.38it/s]
# Valid F1: 0.3612
# No improvement for 2 epochs
#
# Epoch 11/30
# Training: 100% 32/32 [00:00<00:00, 35.80it/s, loss=5.68]
# Train Loss: 4.2664
# Evaluating: 100% 32/32 [00:00<00:00, 80.66it/s]
# Valid F1: 0.3754
# ✓ Saved new best model
#
# Epoch 12/30
# Training: 100% 32/32 [00:00<00:00, 36.01it/s, loss=3.8]
# Train Loss: 4.1451
# Evaluating: 100% 32/32 [00:00<00:00, 83.70it/s]
# Valid F1: 0.3930
# ✓ Saved new best model
#
# Epoch 13/30
# Training: 100% 32/32 [00:00<00:00, 33.12it/s, loss=2.7]
# Train Loss: 3.9189
# Evaluating: 100% 32/32 [00:00<00:00, 83.55it/s]
# Valid F1: 0.3959
# ✓ Saved new best model
#
# Epoch 14/30
# Training: 100% 32/32 [00:00<00:00, 35.49it/s, loss=3.51]
# Train Loss: 3.7375
# Evaluating: 100% 32/32 [00:00<00:00, 82.45it/s]
# Valid F1: 0.4143
# ✓ Saved new best model
#
# Epoch 15/30
# Training: 100% 32/32 [00:00<00:00, 33.94it/s, loss=4.01]
# Train Loss: 3.5479
# Evaluating: 100% 32/32 [00:00<00:00, 85.40it/s]
# Valid F1: 0.4394
# ✓ Saved new best model
#
# Epoch 16/30
# Training: 100% 32/32 [00:00<00:00, 32.84it/s, loss=1.61]
# Train Loss: 3.4430
# Evaluating: 100% 32/32 [00:00<00:00, 78.13it/s]
# Valid F1: 0.4490
# ✓ Saved new best model
#
# Epoch 17/30
# Training: 100% 32/32 [00:01<00:00, 29.75it/s, loss=2.48]
# Train Loss: 3.3687
# Evaluating: 100% 32/32 [00:00<00:00, 60.68it/s]
# Valid F1: 0.4427
# No improvement for 1 epochs
#
# Epoch 18/30
# Training: 100% 32/32 [00:01<00:00, 23.51it/s, loss=1.81]
# Train Loss: 3.2344
# Evaluating: 100% 32/32 [00:00<00:00, 63.21it/s]
# Valid F1: 0.4655
# ✓ Saved new best model
#
# Epoch 19/30
# Training: 100% 32/32 [00:01<00:00, 30.64it/s, loss=7.71]
# Train Loss: 3.2541
# Evaluating: 100% 32/32 [00:00<00:00, 82.79it/s]
# Valid F1: 0.4568
# No improvement for 1 epochs
#
# Epoch 20/30
# Training: 100% 32/32 [00:01<00:00, 31.41it/s, loss=1.71]
# Train Loss: 3.0455
# Evaluating: 100% 32/32 [00:00<00:00, 82.63it/s]
# Valid F1: 0.4730
# ✓ Saved new best model
#
# Epoch 21/30
# Training: 100% 32/32 [00:00<00:00, 36.66it/s, loss=3.37]
# Train Loss: 3.0313
# Evaluating: 100% 32/32 [00:00<00:00, 86.82it/s]
# Valid F1: 0.4660
# No improvement for 1 epochs
#
# Epoch 22/30
# Training: 100% 32/32 [00:00<00:00, 33.06it/s, loss=2.49]
# Train Loss: 2.9629
# Evaluating: 100% 32/32 [00:00<00:00, 85.15it/s]
# Valid F1: 0.4651
# No improvement for 2 epochs
#
# Epoch 23/30
# Training: 100% 32/32 [00:01<00:00, 31.78it/s, loss=3.7]
# Train Loss: 2.8066
# Evaluating: 100% 32/32 [00:00<00:00, 80.86it/s]
# Valid F1: 0.4696
# No improvement for 3 epochs
#
# Epoch 24/30
# Training: 100% 32/32 [00:00<00:00, 33.54it/s, loss=2.9]
# Train Loss: 2.6594
# Evaluating: 100% 32/32 [00:00<00:00, 81.04it/s]
# Valid F1: 0.4809
# ✓ Saved new best model
#
# Epoch 25/30
# Training: 100% 32/32 [00:00<00:00, 34.45it/s, loss=0.851]
# Train Loss: 2.5641
# Evaluating: 100% 32/32 [00:00<00:00, 68.70it/s]
# Valid F1: 0.4823
# ✓ Saved new best model
#
# Epoch 26/30
# Training: 100% 32/32 [00:01<00:00, 24.48it/s, loss=2.96]
# Train Loss: 2.5674
# Evaluating: 100% 32/32 [00:00<00:00, 58.57it/s]
# Valid F1: 0.5015
# ✓ Saved new best model
#
# Epoch 27/30
# Training: 100% 32/32 [00:01<00:00, 24.97it/s, loss=2.71]
# Train Loss: 2.5298
# Evaluating: 100% 32/32 [00:00<00:00, 84.11it/s]
# Valid F1: 0.4890
# No improvement for 1 epochs
#
# Epoch 28/30
# Training: 100% 32/32 [00:00<00:00, 36.02it/s, loss=2.12]
# Train Loss: 2.4591
# Evaluating: 100% 32/32 [00:00<00:00, 84.36it/s]
# Valid F1: 0.5037
# ✓ Saved new best model
#
# Epoch 29/30
# Training: 100% 32/32 [00:00<00:00, 33.64it/s, loss=2.51]
# Train Loss: 2.3920
# Evaluating: 100% 32/32 [00:00<00:00, 83.09it/s]
# Valid F1: 0.4809
# No improvement for 1 epochs
#
# Epoch 30/30
# Training: 100% 32/32 [00:00<00:00, 35.29it/s, loss=2.85]
# Train Loss: 2.4017
# Evaluating: 100% 32/32 [00:00<00:00, 85.47it/s]
# Valid F1: 0.4905
# No improvement for 2 epochs
#
# Training completed in 0:00:48.696455
#
# Evaluating on test set...
# Evaluating: 100% 32/32 [00:00<00:00, 84.29it/s]
# ✓ Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/te/olfactory_mitral_base
# Test F1: 0.4777
# ✓ Completed olfactory_mitral_base on wikiann_te
#
# >>> Running Experiment: olfactory_more on wikiann_te <<<
# Using device: cuda
# ================================================================================
# Experiment: olfactory_more
# Dataset: wikiann_te
# ================================================================================
# Results will be saved to: /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/te/olfactory_more
# Loading wikiann dataset from HuggingFace (unimelb-nlp/wikiann)...
# Configuration: te
#
# Data splits available: ['validation', 'test', 'train']
# Number of labels: 7
# Label names: ['O', 'B-PER', 'I-PER', 'B-ORG', 'I-ORG', 'B-LOC', 'I-LOC']
#
# Data splits:
#   Train: 1000 sentences
#   Valid: 1000 sentences
#   Test: 1000 sentences
#
# Building vocabularies...
# Vocabulary size: 833
# Number of labels: 7
#
# Starting training...
#
# Epoch 1/30
# Training: 100% 32/32 [00:01<00:00, 23.29it/s, loss=8.24]
# Train Loss: 9.5288
# Evaluating: 100% 32/32 [00:00<00:00, 82.97it/s]
# Valid F1: 0.0000
# No improvement for 1 epochs
#
# Epoch 2/30
# Training: 100% 32/32 [00:00<00:00, 34.50it/s, loss=6.42]
# Train Loss: 7.1786
# Evaluating: 100% 32/32 [00:00<00:00, 79.56it/s]
# Valid F1: 0.1947
# ✓ Saved new best model
#
# Epoch 3/30
# Training: 100% 32/32 [00:00<00:00, 35.61it/s, loss=3.08]
# Train Loss: 5.1948
# Evaluating: 100% 32/32 [00:00<00:00, 84.85it/s]
# Valid F1: 0.3422
# ✓ Saved new best model
#
# Epoch 4/30
# Training: 100% 32/32 [00:00<00:00, 34.48it/s, loss=2.07]
# Train Loss: 4.0588
# Evaluating: 100% 32/32 [00:00<00:00, 84.14it/s]
# Valid F1: 0.4331
# ✓ Saved new best model
#
# Epoch 5/30
# Training: 100% 32/32 [00:01<00:00, 26.58it/s, loss=2.75]
# Train Loss: 3.3743
# Evaluating: 100% 32/32 [00:00<00:00, 66.26it/s]
# Valid F1: 0.4909
# ✓ Saved new best model
#
# Epoch 6/30
# Training: 100% 32/32 [00:01<00:00, 25.88it/s, loss=2.82]
# Train Loss: 2.8003
# Evaluating: 100% 32/32 [00:00<00:00, 59.19it/s]
# Valid F1: 0.4605
# No improvement for 1 epochs
#
# Epoch 7/30
# Training: 100% 32/32 [00:00<00:00, 35.97it/s, loss=1.92]
# Train Loss: 2.5263
# Evaluating: 100% 32/32 [00:00<00:00, 86.12it/s]
# Valid F1: 0.5397
# ✓ Saved new best model
#
# Epoch 8/30
# Training: 100% 32/32 [00:00<00:00, 35.44it/s, loss=1.79]
# Train Loss: 2.2593
# Evaluating: 100% 32/32 [00:00<00:00, 87.24it/s]
# Valid F1: 0.5168
# No improvement for 1 epochs
#
# Epoch 9/30
# Training: 100% 32/32 [00:00<00:00, 35.62it/s, loss=2.46]
# Train Loss: 2.0187
# Evaluating: 100% 32/32 [00:00<00:00, 87.92it/s]
# Valid F1: 0.5565
# ✓ Saved new best model
#
# Epoch 10/30
# Training: 100% 32/32 [00:00<00:00, 33.47it/s, loss=1.6]
# Train Loss: 1.8046
# Evaluating: 100% 32/32 [00:00<00:00, 86.82it/s]
# Valid F1: 0.5515
# No improvement for 1 epochs
#
# Epoch 11/30
# Training: 100% 32/32 [00:00<00:00, 35.12it/s, loss=0.891]
# Train Loss: 1.6474
# Evaluating: 100% 32/32 [00:00<00:00, 86.39it/s]
# Valid F1: 0.5640
# ✓ Saved new best model
#
# Epoch 12/30
# Training: 100% 32/32 [00:00<00:00, 35.80it/s, loss=1.82]
# Train Loss: 1.6398
# Evaluating: 100% 32/32 [00:00<00:00, 82.57it/s]
# Valid F1: 0.5866
# ✓ Saved new best model
#
# Epoch 13/30
# Training: 100% 32/32 [00:00<00:00, 34.36it/s, loss=1.24]
# Train Loss: 1.4552
# Evaluating: 100% 32/32 [00:00<00:00, 67.21it/s]
# Valid F1: 0.5638
# No improvement for 1 epochs
#
# Epoch 14/30
# Training: 100% 32/32 [00:01<00:00, 26.01it/s, loss=1.48]
# Train Loss: 1.3377
# Evaluating: 100% 32/32 [00:00<00:00, 58.88it/s]
# Valid F1: 0.5921
# ✓ Saved new best model
#
# Epoch 15/30
# Training: 100% 32/32 [00:01<00:00, 24.58it/s, loss=1.9]
# Train Loss: 1.2828
# Evaluating: 100% 32/32 [00:00<00:00, 86.83it/s]
# Valid F1: 0.5607
# No improvement for 1 epochs
#
# Epoch 16/30
# Training: 100% 32/32 [00:00<00:00, 34.86it/s, loss=0.703]
# Train Loss: 1.1224
# Evaluating: 100% 32/32 [00:00<00:00, 82.18it/s]
# Valid F1: 0.5659
# No improvement for 2 epochs
#
# Epoch 17/30
# Training: 100% 32/32 [00:00<00:00, 34.81it/s, loss=1.63]
# Train Loss: 1.1030
# Evaluating: 100% 32/32 [00:00<00:00, 84.78it/s]
# Valid F1: 0.6117
# ✓ Saved new best model
#
# Epoch 18/30
# Training: 100% 32/32 [00:00<00:00, 33.10it/s, loss=1.56]
# Train Loss: 1.0033
# Evaluating: 100% 32/32 [00:00<00:00, 88.60it/s]
# Valid F1: 0.5718
# No improvement for 1 epochs
#
# Epoch 19/30
# Training: 100% 32/32 [00:00<00:00, 37.15it/s, loss=1.33]
# Train Loss: 0.9964
# Evaluating: 100% 32/32 [00:00<00:00, 83.66it/s]
# Valid F1: 0.5492
# No improvement for 2 epochs
#
# Epoch 20/30
# Training: 100% 32/32 [00:00<00:00, 32.17it/s, loss=0.256]
# Train Loss: 0.9189
# Evaluating: 100% 32/32 [00:00<00:00, 84.26it/s]
# Valid F1: 0.6088
# No improvement for 3 epochs
#
# Epoch 21/30
# Training: 100% 32/32 [00:00<00:00, 33.54it/s, loss=0.27]
# Train Loss: 0.8019
# Evaluating: 100% 32/32 [00:00<00:00, 80.80it/s]
# Valid F1: 0.5880
# No improvement for 4 epochs
#
# Epoch 22/30
# Training: 100% 32/32 [00:01<00:00, 30.20it/s, loss=1.27]
# Train Loss: 0.7337
# Evaluating: 100% 32/32 [00:00<00:00, 63.70it/s]
# Valid F1: 0.5780
# No improvement for 5 epochs
# Early stopping triggered
#
# Training completed in 0:00:35.538880
#
# Evaluating on test set...
# Evaluating: 100% 32/32 [00:00<00:00, 60.42it/s]
# ✓ Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/te/olfactory_more
# Test F1: 0.5955
# ✓ Completed olfactory_more on wikiann_te
#
# >>> Running Experiment: olfactory_mitral_more on wikiann_te <<<
# Using device: cuda
# ================================================================================
# Experiment: olfactory_mitral_more
# Dataset: wikiann_te
# ================================================================================
# Results will be saved to: /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/te/olfactory_mitral_more
# Loading wikiann dataset from HuggingFace (unimelb-nlp/wikiann)...
# Configuration: te
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#
# Data splits available: ['validation', 'test', 'train']
# Number of labels: 7
# Label names: ['O', 'B-PER', 'I-PER', 'B-ORG', 'I-ORG', 'B-LOC', 'I-LOC']
#
# Data splits:
#   Train: 1000 sentences
#   Valid: 1000 sentences
#   Test: 1000 sentences
#
# Building vocabularies...
# Vocabulary size: 833
# Number of labels: 7
#
# Starting training...
#
# Epoch 1/30
# Training: 100% 32/32 [00:01<00:00, 22.97it/s, loss=8]
# Train Loss: 10.2423
# Evaluating: 100% 32/32 [00:00<00:00, 55.53it/s]
# Valid F1: 0.0029
# ✓ Saved new best model
#
# Epoch 2/30
# Training: 100% 32/32 [00:01<00:00, 25.45it/s, loss=7.01]
# Train Loss: 8.2619
# Evaluating: 100% 32/32 [00:00<00:00, 63.51it/s]
# Valid F1: 0.0403
# ✓ Saved new best model
#
# Epoch 3/30
# Training: 100% 32/32 [00:01<00:00, 28.91it/s, loss=5.87]
# Train Loss: 6.5736
# Evaluating: 100% 32/32 [00:00<00:00, 84.49it/s]
# Valid F1: 0.1898
# ✓ Saved new best model
#
# Epoch 4/30
# Training: 100% 32/32 [00:00<00:00, 34.46it/s, loss=5.92]
# Train Loss: 4.9786
# Evaluating: 100% 32/32 [00:00<00:00, 90.09it/s]
# Valid F1: 0.2434
# ✓ Saved new best model
#
# Epoch 5/30
# Training: 100% 32/32 [00:00<00:00, 36.38it/s, loss=3.4]
# Train Loss: 3.8380
# Evaluating: 100% 32/32 [00:00<00:00, 88.88it/s]
# Valid F1: 0.3752
# ✓ Saved new best model
#
# Epoch 6/30
# Training: 100% 32/32 [00:00<00:00, 36.33it/s, loss=3.07]
# Train Loss: 3.2729
# Evaluating: 100% 32/32 [00:00<00:00, 88.96it/s]
# Valid F1: 0.4390
# ✓ Saved new best model
#
# Epoch 7/30
# Training: 100% 32/32 [00:00<00:00, 35.34it/s, loss=1.73]
# Train Loss: 2.9167
# Evaluating: 100% 32/32 [00:00<00:00, 82.98it/s]
# Valid F1: 0.4550
# ✓ Saved new best model
#
# Epoch 8/30
# Training: 100% 32/32 [00:00<00:00, 33.64it/s, loss=3]
# Train Loss: 2.6127
# Evaluating: 100% 32/32 [00:00<00:00, 83.55it/s]
# Valid F1: 0.5292
# ✓ Saved new best model
#
# Epoch 9/30
# Training: 100% 32/32 [00:00<00:00, 35.36it/s, loss=2.6]
# Train Loss: 2.4418
# Evaluating: 100% 32/32 [00:00<00:00, 78.29it/s]
# Valid F1: 0.4903
# No improvement for 1 epochs
#
# Epoch 10/30
# Training: 100% 32/32 [00:01<00:00, 25.29it/s, loss=1.74]
# Train Loss: 2.2171
# Evaluating: 100% 32/32 [00:00<00:00, 58.33it/s]
# Valid F1: 0.5076
# No improvement for 2 epochs
#
# Epoch 11/30
# Training: 100% 32/32 [00:01<00:00, 24.54it/s, loss=1.88]
# Train Loss: 2.0193
# Evaluating: 100% 32/32 [00:00<00:00, 56.51it/s]
# Valid F1: 0.5113
# No improvement for 3 epochs
#
# Epoch 12/30
# Training: 100% 32/32 [00:00<00:00, 33.28it/s, loss=1.19]
# Train Loss: 1.8608
# Evaluating: 100% 32/32 [00:00<00:00, 83.12it/s]
# Valid F1: 0.5231
# No improvement for 4 epochs
#
# Epoch 13/30
# Training: 100% 32/32 [00:00<00:00, 35.28it/s, loss=2.38]
# Train Loss: 1.7510
# Evaluating: 100% 32/32 [00:00<00:00, 80.00it/s]
# Valid F1: 0.5287
# No improvement for 5 epochs
# Early stopping triggered
#
# Training completed in 0:00:22.046673
#
# Evaluating on test set...
# Evaluating: 100% 32/32 [00:00<00:00, 77.33it/s]
# ✓ Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/te/olfactory_mitral_more
# Test F1: 0.4960
# ✓ Completed olfactory_mitral_more on wikiann_te

# %%
# @title Fix Config & Run WikiANN Bangla/Telugu
import os
import yaml

CONFIG_PATH = 'config/mitral_config.yaml'
BASE_SAVE_DIR = '/content/drive/My Drive/olfaction_inspired_ner_mitral' if os.path.exists('/content/drive') else './results'

print("Fixing Configuration File...")

if os.path.exists(CONFIG_PATH):
    with open(CONFIG_PATH, 'r') as f:
        config = yaml.safe_load(f)

    # Define the new datasets
    new_datasets = {
        'wikiann_bn': {
            'dataset': "wikiann",
            'language': "bn",
            'glove_path': None,
            'use_pretrained_embeddings': False
        },
        'wikiann_te': {
            'dataset': "wikiann",
            'language': "te",
            'glove_path': None,
            'use_pretrained_embeddings': False
        }
    }

    # 1. Clean up: Remove if they were accidentally added to 'experiments'
    if 'experiments' in config:
        for key in ['wikiann_bn', 'wikiann_te']:
            if key in config['experiments']:
                print(f"Removing {key} from experiments section...")
                del config['experiments'][key]

    # 2. Add to 'datasets' section
    if 'datasets' not in config:
        config['datasets'] = {}

    for key, val in new_datasets.items():
        config['datasets'][key] = val
        print(f"Added {key} to datasets section.")

    # 3. Save corrected config
    with open(CONFIG_PATH, 'w') as f:
        yaml.dump(config, f, sort_keys=False, default_flow_style=False)
    print("✓ Configuration file corrected and saved.")

else:
    print(f"Error: {CONFIG_PATH} not found!")

# ------------------------------------------------------------------------------
# Run Experiments
# ------------------------------------------------------------------------------
NEW_DATASETS = ['wikiann_bn', 'wikiann_te']
ALL_EXPERIMENTS = list(config['experiments'].keys())

print(f"\nRunning on Datasets: {NEW_DATASETS}")
print(f"Running Experiments: {ALL_EXPERIMENTS}")

for dataset_key in NEW_DATASETS:
    print(f"\n{'#'*80}")
    print(f"PROCESSING DATASET: {dataset_key}")
    print(f"{'#'*80}")

    for exp in ALL_EXPERIMENTS:
        print(f"\n>>> Running Experiment: {exp} on {dataset_key} <<<")

        # !python src/train_universal.py \
            --config {CONFIG_PATH} \
            --dataset_key {dataset_key} \
            --experiment {exp} \
            --save_dir "{BASE_SAVE_DIR}"

        print(f"✓ Completed {exp} on {dataset_key}")

# %%
# @title 3. Generate Visualizations & Metrics (Corrected)
# ==============================================================================
import torch
import json
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import sys

# Ensure src is in path
if os.getcwd() not in sys.path:
    sys.path.append(os.getcwd())

from src.model.olfactory_ner import create_olfactory_ner
from src.data.unified_loader import get_dataset
from src.analysis.visualize import analyze_receptor_activations

# Setup paths (same as before)
if 'BASE_SAVE_DIR' not in locals():
    BASE_SAVE_DIR = '/content/drive/My Drive/olfaction_inspired_ner_mitral' if os.path.exists('/content/drive') else './results'

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

print(f"Scanning results in: {BASE_SAVE_DIR}")

# Scan directory for datasets
if not os.path.exists(BASE_SAVE_DIR):
    print("Results directory not found!")
else:
    # Get all dataset folders
    datasets_found = [d for d in os.listdir(BASE_SAVE_DIR) if os.path.isdir(os.path.join(BASE_SAVE_DIR, d))]

    for dataset_dir_name in datasets_found: # e.g., 'conll2003' or 'wikiann'
        d_path = os.path.join(BASE_SAVE_DIR, dataset_dir_name)

        # Get Language folders
        languages = [l for l in os.listdir(d_path) if os.path.isdir(os.path.join(d_path, l))]

        for lang in languages: # e.g., 'default' or 'hi'
            print(f"\n{'='*80}")
            print(f"Processing: {dataset_dir_name} - {lang}")
            print(f"{'='*80}")

            full_results_dir = os.path.join(d_path, lang)
            viz_dir = os.path.join(full_results_dir, 'visualizations')
            os.makedirs(viz_dir, exist_ok=True)

            # Identify experiments in this folder
            experiments_found = [e for e in os.listdir(full_results_dir)
                                if os.path.isdir(os.path.join(full_results_dir, e)) and e != 'visualizations']

            if not experiments_found:
                print("No experiments found.")
                continue

            # Load Data specific to this dataset/language
            # We need to map the directory structure back to dataset keys for get_dataset
            # This is tricky if names differ, but let's try standard names.
            # Usually dataset_name passed to get_dataset is 'conll2003' or 'wikiann'

            print("Loading test data...")
            try:
                _, _, test_loader, vocab_info = get_dataset(
                    dataset_name=dataset_dir_name,
                    language=lang if lang != 'default' else 'en', # guess 'en' for default
                    cache_dir='./data'
                )
            except Exception as e:
                print(f"Warning: Could not load data for {dataset_dir_name}/{lang}. Skipping heatmaps. Error: {e}")
                test_loader = None

            # ------------------------------------------------------------------
            # Generate Heatmaps
            # ------------------------------------------------------------------
            if test_loader:
                print("Generating Heatmaps...")
                for exp in experiments_found:
                    # Skip if baseline (no receptors)
                    if 'baseline' in exp: continue

                    model_path = os.path.join(full_results_dir, exp, 'best_model.pt')
                    results_path = os.path.join(full_results_dir, exp, 'results.json')

                    if not os.path.exists(model_path): continue

                    try:
                        # Load config
                        with open(results_path, 'r') as f:
                            res = json.load(f)
                        model_config = res['config']

                        if not model_config.get('use_receptors', True): continue

                        # Load Model
                        model = create_olfactory_ner(len(vocab_info['word2idx']), len(vocab_info['label2idx']), model_config)
                        checkpoint = torch.load(model_path, map_location=device, weights_only=False)
                        model.load_state_dict(checkpoint['model_state_dict'])
                        model = model.to(device)

                        save_path_exp = os.path.join(viz_dir, exp)
                        analyze_receptor_activations(model, test_loader, vocab_info, device, save_dir=save_path_exp, experiment_name=exp)
                        print(f"✓ Heatmaps generated for {exp}")

                    except Exception as e:
                        print(f"Error processing {exp}: {e}")

            # ------------------------------------------------------------------
            # Aggregate Metrics for this Language
            # ------------------------------------------------------------------
            metrics = []
            for exp in experiments_found:
                res_path = os.path.join(full_results_dir, exp, 'results.json')
                if os.path.exists(res_path):
                    try:
                        with open(res_path, 'r') as f:
                            data = json.load(f)
                        test_res = data['test']
                        metrics.append({
                            'Experiment': exp,
                            'F1': test_res['f1'],
                            'Precision': test_res['precision'],
                            'Recall': test_res['recall']
                        })
                    except:
                        pass

            if metrics:
                df = pd.DataFrame(metrics)
                print(f"\nResults Summary ({lang}):")
                print(df.sort_values(by='F1', ascending=False).to_string(index=False))
                df.to_csv(os.path.join(viz_dir, 'summary_metrics.csv'), index=False)
# Out:
# Scanning results in: /content/drive/My Drive/olfaction_inspired_ner_mitral
#
# ================================================================================
# Processing: conll2003 - default
# ================================================================================
# Loading test data...
# Initialize CoNLL-2003 dataset loading...
# Loading training data...
#
# Building vocabularies...
# Vocabulary size: 11984
# Number of labels: 8
# Generating Heatmaps...
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Creating glomeruli activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   Games: 0.417
#   BEAT: 0.409
#   BEAT: 0.409
#   League: 0.402
#   League: 0.402
#
# Receptor 1:
#   0: 3.844
#   0: 3.844
#   0: 3.844
#   0: 3.844
#   0: 3.844
#
# Receptor 2:
#   0: 1.708
#   0: 1.708
#   0: 1.708
#   0: 1.708
#   0: 1.708
#
# Receptor 3:
#   0: 5.628
#   0: 5.628
#   0: 5.628
#   0: 5.628
#   0: 5.628
#
# Receptor 4:
#   told: 1.785
#   told: 1.785
#   told: 1.785
#   told: 1.785
#   told: 1.785
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 31.17%
# Average activation (when active): 0.334
# Average Receptor Selectivity Index (RSI): 0.8289
#
# ✓ Analysis complete! Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/conll2003/default/visualizations/olfactory_base
# ✓ Heatmaps generated for olfactory_base
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Creating glomeruli activation heatmap...
# Creating mitral activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   ,: 7.338
#   ,: 7.338
#   ,: 7.338
#   ,: 7.338
#   ,: 7.338
#
# Receptor 1:
#   ,: 6.393
#   ,: 6.393
#   ,: 6.393
#   ,: 6.393
#   ,: 6.393
#
# Receptor 2:
#   ,: 5.577
#   ,: 5.577
#   ,: 5.577
#   ,: 5.577
#   ,: 5.577
#
# Receptor 3:
#   ,: 5.834
#   ,: 5.834
#   ,: 5.834
#   ,: 5.834
#   ,: 5.834
#
# Receptor 4:
#   Jan: 1.524
#   Jan: 1.524
#   CHAMPIONSHIP: 1.187
#   Group: 1.179
#   Group: 1.179
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 44.46%
# Average activation (when active): 0.341
# Average Receptor Selectivity Index (RSI): 0.5669
#
# ✓ Analysis complete! Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/conll2003/default/visualizations/olfactory_mitral_base
# ✓ Heatmaps generated for olfactory_mitral_base
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Creating glomeruli activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   v: 1.194
#   v: 1.194
#   v: 1.194
#   v: 1.194
#   v: 1.194
#
# Receptor 1:
#   National: 0.923
#   National: 0.923
#   National: 0.923
#   National: 0.923
#   National: 0.923
#
# Receptor 2:
#   Inc: 0.938
#   Inc: 0.938
#   Inc: 0.938
#   Inc: 0.938
#   Sachs: 0.832
#
# Receptor 3:
#   neighbouring: 0.765
#   Yeltsin: 0.753
#   Yeltsin: 0.753
#   Yeltsin: 0.753
#   Yeltsin: 0.753
#
# Receptor 4:
#   v: 2.673
#   v: 2.673
#   v: 2.673
#   v: 2.673
#   v: 2.673
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 22.56%
# Average activation (when active): 0.318
# Average Receptor Selectivity Index (RSI): 0.8401
#
# ✓ Analysis complete! Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/conll2003/default/visualizations/olfactory_more
# ✓ Heatmaps generated for olfactory_more
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Creating glomeruli activation heatmap...
# Creating mitral activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   ,: 1.669
#   ,: 1.669
#   ,: 1.669
#   ,: 1.669
#   ,: 1.669
#
# Receptor 1:
#   said: 1.461
#   said: 1.461
#   said: 1.461
#   said: 1.461
#   said: 1.461
#
# Receptor 2:
#   said: 2.631
#   said: 2.631
#   said: 2.631
#   said: 2.631
#   said: 2.631
#
# Receptor 3:
#   said: 1.154
#   said: 1.154
#   said: 1.154
#   said: 1.154
#   said: 1.154
#
# Receptor 4:
#   said: 1.886
#   said: 1.886
#   said: 1.886
#   said: 1.886
#   said: 1.886
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 21.55%
# Average activation (when active): 0.210
# Average Receptor Selectivity Index (RSI): 0.7744
#
# ✓ Analysis complete! Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/conll2003/default/visualizations/olfactory_mitral_more
# ✓ Heatmaps generated for olfactory_mitral_more
#
# Results Summary (default):
#            Experiment       F1  Precision   Recall
#              baseline 0.738598   0.770029 0.709632
#        olfactory_more 0.714919   0.746914 0.685552
# olfactory_mitral_more 0.709421   0.743117 0.678647
#        olfactory_base 0.705372   0.736791 0.676523
# olfactory_mitral_base 0.687585   0.758871 0.628541
#
# ================================================================================
# Processing: wikiann - hi
# ================================================================================
# Loading test data...
# Loading wikiann dataset from HuggingFace (unimelb-nlp/wikiann)...
# Configuration: hi
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Data splits available: ['validation', 'test', 'train']
# Number of labels: 7
# Label names: ['O', 'B-PER', 'I-PER', 'B-ORG', 'I-ORG', 'B-LOC', 'I-LOC']
#
# Data splits:
#   Train: 5000 sentences
#   Valid: 1000 sentences
#   Test: 1000 sentences
#
# Building vocabularies...
# Vocabulary size: 2844
# Number of labels: 7
# Generating Heatmaps...
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Creating glomeruli activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   में: 4.539
#   में: 4.539
#   में: 4.539
#   में: 4.539
#   में: 4.539
#
# Receptor 1:
#   को: 5.214
#   को: 5.214
#   को: 5.214
#   को: 5.214
#   को: 5.214
#
# Receptor 2:
#   मुख्यमन्त्रियों: 4.483
#   मुख्यमन्त्रियों: 4.483
#   मुख्यमन्त्रियों: 4.483
#   मुख्यमन्त्रियों: 4.483
#   मुख्यमन्त्रियों: 4.483
#
# Receptor 3:
#   बल: 4.291
#   बल: 4.291
#   फॉर: 3.702
#   रिकॉर्ड: 3.604
#   एन: 3.575
#
# Receptor 4:
#   भौतिक: 5.087
#   महाराष्ट्र: 4.428
#   महाराष्ट्र: 4.428
#   महाराष्ट्र: 4.428
#   महाराष्ट्र: 4.428
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 31.10%
# Average activation (when active): 1.410
# Average Receptor Selectivity Index (RSI): 0.5296
#
# ✓ Analysis complete! Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/hi/visualizations/olfactory_base
# ✓ Heatmaps generated for olfactory_base
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Creating glomeruli activation heatmap...
# Creating mitral activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   में: 7.504
#   में: 7.504
#   में: 7.504
#   में: 7.504
#   में: 7.504
#
# Receptor 1:
#   को: 5.854
#   को: 5.854
#   को: 5.854
#   को: 5.854
#   को: 5.854
#
# Receptor 2:
#   अनुप्रेषित: 7.636
#   अनुप्रेषित: 7.636
#   अनुप्रेषित: 7.636
#   अनुप्रेषित: 7.636
#   अनुप्रेषित: 7.636
#
# Receptor 3:
#   ...: 4.290
#   ...: 4.290
#   ': 3.773
#   ': 3.773
#   ': 3.773
#
# Receptor 4:
#   और: 7.869
#   और: 7.869
#   और: 7.869
#   और: 7.869
#   और: 7.869
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 29.30%
# Average activation (when active): 1.693
# Average Receptor Selectivity Index (RSI): 0.4703
#
# ✓ Analysis complete! Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/hi/visualizations/olfactory_mitral_base
# ✓ Heatmaps generated for olfactory_mitral_base
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Creating glomeruli activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   कुमार: 4.130
#   कुमार: 4.130
#   कुमार: 4.130
#   कुमार: 4.130
#   कुमार: 4.130
#
# Receptor 1:
#   भूमिका: 3.070
#   भूमिका: 3.070
#   भूमिका: 3.070
#   भूमिका: 3.070
#   भूमिका: 3.070
#
# Receptor 2:
#   भारत: 4.018
#   भारत: 4.018
#   भारत: 4.018
#   भारत: 4.018
#   भारत: 4.018
#
# Receptor 3:
#   कुणाल: 3.891
#   का: 3.854
#   का: 3.854
#   का: 3.854
#   का: 3.854
#
# Receptor 4:
#   मुख्य: 5.051
#   मारिया: 3.572
#   प्रीमियर: 3.561
#   अजमेर: 3.536
#   ईसा: 3.392
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 28.73%
# Average activation (when active): 1.155
# Average Receptor Selectivity Index (RSI): 0.5141
#
# ✓ Analysis complete! Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/hi/visualizations/olfactory_more
# ✓ Heatmaps generated for olfactory_more
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Creating glomeruli activation heatmap...
# Creating mitral activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   जिला: 6.233
#   जिला: 6.233
#   जिला: 6.233
#   जिला: 6.233
#   जिला: 6.233
#
# Receptor 1:
#   --: 4.431
#   --: 4.431
#   --: 4.431
#   --: 4.431
#   --: 4.431
#
# Receptor 2:
#   से: 4.369
#   से: 4.369
#   से: 4.369
#   से: 4.369
#   से: 4.369
#
# Receptor 3:
#   ...: 4.141
#   ...: 4.141
#   तथा: 4.022
#   तथा: 4.022
#   ': 3.789
#
# Receptor 4:
#   E: 5.123
#   E: 5.123
#   ``: 4.002
#   ``: 4.002
#   ``: 4.002
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 29.53%
# Average activation (when active): 1.243
# Average Receptor Selectivity Index (RSI): 0.4939
#
# ✓ Analysis complete! Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/hi/visualizations/olfactory_mitral_more
# ✓ Heatmaps generated for olfactory_mitral_more
#
# Results Summary (hi):
#            Experiment       F1  Precision   Recall
#        olfactory_more 0.843660   0.850289 0.837134
#              baseline 0.836676   0.841152 0.832248
# olfactory_mitral_more 0.819422   0.807753 0.831433
# olfactory_mitral_base 0.804330   0.822828 0.786645
#        olfactory_base 0.795853   0.779687 0.812704
#
# ================================================================================
# Processing: wikiann - mr
# ================================================================================
# Loading test data...
# Loading wikiann dataset from HuggingFace (unimelb-nlp/wikiann)...
# Configuration: mr
#
# Data splits available: ['validation', 'test', 'train']
# Number of labels: 7
# Label names: ['O', 'B-PER', 'I-PER', 'B-ORG', 'I-ORG', 'B-LOC', 'I-LOC']
#
# Data splits:
#   Train: 5000 sentences
#   Valid: 1000 sentences
#   Test: 1000 sentences
#
# Building vocabularies...
# Vocabulary size: 3208
# Number of labels: 7
# Generating Heatmaps...
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Creating glomeruli activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   सम्राट: 5.773
#   सम्राट: 5.773
#   सम्राट: 5.773
#   सम्राट: 5.773
#   खेळाडू: 5.667
#
# Receptor 1:
#   ट्रेक: 5.422
#   ट्रेक: 5.422
#   ट्रेक: 5.422
#   ट्रेक: 5.422
#   ट्रेक: 5.422
#
# Receptor 2:
#   ': 4.143
#   ': 4.143
#   ': 4.143
#   ': 4.143
#   ': 4.143
#
# Receptor 3:
#   इंडिया: 5.956
#   इंडिया: 5.956
#   इंडिया: 5.956
#   इंडिया: 5.956
#   इंडिया: 5.956
#
# Receptor 4:
#   <UNK>: 7.511
#   <UNK>: 7.511
#   <UNK>: 7.511
#   <UNK>: 7.511
#   <UNK>: 7.511
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 31.26%
# Average activation (when active): 1.562
# Average Receptor Selectivity Index (RSI): 0.5350
#
# ✓ Analysis complete! Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/mr/visualizations/olfactory_base
# ✓ Heatmaps generated for olfactory_base
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Creating glomeruli activation heatmap...
# Creating mitral activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   विनोद: 4.028
#   भारतात: 3.870
#   भारतात: 3.870
#   भारतात: 3.870
#   भारतात: 3.870
#
# Receptor 1:
#   शहरात: 4.902
#   शिक्षण: 4.407
#   शिक्षण: 4.407
#   शिक्षण: 4.407
#   शिक्षण: 4.407
#
# Receptor 2:
#   मतदारसंघ: 5.702
#   मतदारसंघ: 5.702
#   मतदारसंघ: 5.702
#   मतदारसंघ: 5.702
#   मतदारसंघ: 5.702
#
# Receptor 3:
#   आहे: 4.422
#   आहे: 4.422
#   आहे: 4.422
#   आहे: 4.422
#   आहे: 4.422
#
# Receptor 4:
#   <UNK>: 6.022
#   <UNK>: 6.022
#   <UNK>: 6.022
#   <UNK>: 6.022
#   <UNK>: 6.022
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 27.85%
# Average activation (when active): 1.437
# Average Receptor Selectivity Index (RSI): 0.4954
#
# ✓ Analysis complete! Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/mr/visualizations/olfactory_mitral_base
# ✓ Heatmaps generated for olfactory_mitral_base
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Creating glomeruli activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   ऑक्सफर्ड: 3.679
#   बँक: 3.581
#   बँक: 3.581
#   बँक: 3.581
#   बँक: 3.581
#
# Receptor 1:
#   ': 3.435
#   ': 3.435
#   ': 3.435
#   ': 3.435
#   ': 3.435
#
# Receptor 2:
#   भाभा: 3.420
#   पुणे: 3.405
#   पुणे: 3.405
#   पुणे: 3.405
#   पुणे: 3.405
#
# Receptor 3:
#   परमार: 2.870
#   बच्चन: 2.792
#   बच्चन: 2.792
#   बच्चन: 2.792
#   बच्चन: 2.792
#
# Receptor 4:
#   हे: 4.258
#   हे: 4.258
#   हे: 4.258
#   हे: 4.258
#   हे: 4.258
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 28.04%
# Average activation (when active): 1.072
# Average Receptor Selectivity Index (RSI): 0.5227
#
# ✓ Analysis complete! Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/mr/visualizations/olfactory_more
# ✓ Heatmaps generated for olfactory_more
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Creating glomeruli activation heatmap...
# Creating mitral activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   हायकमिशन: 3.821
#   हायकमिशन: 3.821
#   हायकमिशन: 3.821
#   येते: 3.587
#   येते: 3.587
#
# Receptor 1:
#   येते: 4.577
#   येते: 4.577
#   येते: 4.577
#   येते: 4.577
#   धावणाऱ्या: 3.152
#
# Receptor 2:
#   ': 5.429
#   ': 5.429
#   ': 5.429
#   ': 5.429
#   ': 5.429
#
# Receptor 3:
#   /: 3.780
#   /: 3.780
#   ,: 3.722
#   ,: 3.722
#   ,: 3.722
#
# Receptor 4:
#   नारायण: 3.625
#   नारायण: 3.625
#   नारायण: 3.625
#   नारायण: 3.625
#   आल्प-मरितीम: 3.385
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 30.81%
# Average activation (when active): 1.249
# Average Receptor Selectivity Index (RSI): 0.4558
#
# ✓ Analysis complete! Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/mr/visualizations/olfactory_mitral_more
# ✓ Heatmaps generated for olfactory_mitral_more
#
# Results Summary (mr):
#            Experiment       F1  Precision   Recall
# olfactory_mitral_more 0.796741   0.821159 0.773734
#        olfactory_base 0.789088   0.812919 0.766614
#              baseline 0.788077   0.814346 0.763449
#        olfactory_more 0.772986   0.795645 0.751582
# olfactory_mitral_base 0.763245   0.800347 0.729430
#
# ================================================================================
# Processing: wikiann - ta
# ================================================================================
# Loading test data...
# Loading wikiann dataset from HuggingFace (unimelb-nlp/wikiann)...
# Configuration: ta
#
# Data splits available: ['validation', 'test', 'train']
# Number of labels: 7
# Label names: ['O', 'B-PER', 'I-PER', 'B-ORG', 'I-ORG', 'B-LOC', 'I-LOC']
#
# Data splits:
#   Train: 15000 sentences
#   Valid: 1000 sentences
#   Test: 1000 sentences
#
# Building vocabularies...
# Vocabulary size: 8867
# Number of labels: 7
# Generating Heatmaps...
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Creating glomeruli activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   ``: 6.125
#   ``: 6.125
#   ``: 6.125
#   ``: 6.125
#   ``: 6.125
#
# Receptor 1:
#   முக்கிய: 6.302
#   முக்கிய: 6.302
#   முக்கிய: 6.302
#   முக்கிய: 6.302
#   முக்கிய: 6.302
#
# Receptor 2:
#   பிரதேசம்: 6.840
#   கொல்கத்தா: 6.643
#   டென்னிசு: 6.265
#   தமிழ்நாட்டில்: 5.988
#   தமிழ்நாட்டில்: 5.988
#
# Receptor 3:
#   உயரமான: 6.013
#   தொடக்க: 5.975
#   தொடக்க: 5.975
#   புலவர்: 5.732
#   அனேக: 5.695
#
# Receptor 4:
#   ;: 8.928
#   ;: 8.928
#   ;: 8.928
#   ;: 8.928
#   ;: 8.928
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 30.86%
# Average activation (when active): 1.904
# Average Receptor Selectivity Index (RSI): 0.5286
#
# ✓ Analysis complete! Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/ta/visualizations/olfactory_base
# ✓ Heatmaps generated for olfactory_base
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Creating glomeruli activation heatmap...
# Creating mitral activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   பல்கலைக்கழகம்: 6.805
#   பல்கலைக்கழகம்: 6.805
#   பல்கலைக்கழகம்: 6.805
#   பல்கலைக்கழகம்: 6.805
#   பல்கலைக்கழகம்: 6.805
#
# Receptor 1:
#   தலம்: 6.665
#   இடம்: 6.465
#   இடம்: 6.465
#   தொடர்ந்து: 5.971
#   இவர்: 5.623
#
# Receptor 2:
#   துறை: 7.741
#   படுத்தினார்: 6.233
#   தமிழீழ: 5.631
#   தமிழீழ: 5.631
#   பிரதேசம்: 5.534
#
# Receptor 3:
#   .: 12.067
#   .: 12.067
#   .: 12.067
#   .: 12.067
#   .: 12.067
#
# Receptor 4:
#   கட்சி: 8.731
#   கட்சி: 8.731
#   கட்சி: 8.731
#   கட்சி: 8.731
#   கட்சி: 8.731
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 26.58%
# Average activation (when active): 2.256
# Average Receptor Selectivity Index (RSI): 0.5494
#
# ✓ Analysis complete! Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/ta/visualizations/olfactory_mitral_base
# ✓ Heatmaps generated for olfactory_mitral_base
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Creating glomeruli activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   வழிமாற்று: 6.165
#   வழிமாற்று: 6.165
#   வழிமாற்று: 6.165
#   வழிமாற்று: 6.165
#   வழிமாற்று: 6.165
#
# Receptor 1:
#   து: 7.090
#   ஜொகூர்: 5.210
#   ஜொகூர்: 5.210
#   தொகுதியாகும்: 5.004
#   தொகுதியாகும்: 5.004
#
# Receptor 2:
#   மைக்ரோசாப்ட்: 5.431
#   மியூசிக்: 4.940
#   இரு: 4.677
#   இரு: 4.677
#   இரு: 4.677
#
# Receptor 3:
#   கூட்டு: 6.075
#   கூட்டமைப்பு: 5.053
#   கூட்டமைப்பு: 5.053
#   பொறியியல்: 4.785
#   செயற்றிட்டம்: 4.574
#
# Receptor 4:
#   வட: 5.531
#   வட: 5.531
#   வட: 5.531
#   வட: 5.531
#   நா.: 5.183
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 28.97%
# Average activation (when active): 1.426
# Average Receptor Selectivity Index (RSI): 0.4655
#
# ✓ Analysis complete! Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/ta/visualizations/olfactory_more
# ✓ Heatmaps generated for olfactory_more
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Creating glomeruli activation heatmap...
# Creating mitral activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   வழிமாற்று: 6.916
#   வழிமாற்று: 6.916
#   வழிமாற்று: 6.916
#   வழிமாற்று: 6.916
#   வழிமாற்று: 6.916
#
# Receptor 1:
#   மன்னர்களின்: 6.690
#   ): 6.497
#   ): 6.497
#   ): 6.497
#   ): 6.497
#
# Receptor 2:
#   பாக்காத்தான்: 5.348
#   பாக்காத்தான்: 5.348
#   பாக்காத்தான்: 5.348
#   பாக்காத்தான்: 5.348
#   பாக்காத்தான்: 5.348
#
# Receptor 3:
#   அவையின்: 6.584
#   கூட்டமைப்பு: 6.019
#   கூட்டமைப்பு: 6.019
#   தொகுதி: 5.482
#   தொகுதி: 5.482
#
# Receptor 4:
#   இரு: 6.363
#   இரு: 6.363
#   இரு: 6.363
#   சார்லசு: 5.725
#   காலத்தில்: 5.652
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 26.03%
# Average activation (when active): 1.570
# Average Receptor Selectivity Index (RSI): 0.4859
#
# ✓ Analysis complete! Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/ta/visualizations/olfactory_mitral_more
# ✓ Heatmaps generated for olfactory_mitral_more
#
# Results Summary (ta):
#            Experiment       F1  Precision   Recall
# olfactory_mitral_more 0.799835   0.819797 0.780822
#        olfactory_more 0.796205   0.815723 0.777599
#        olfactory_base 0.793314   0.802805 0.784045
#              baseline 0.792988   0.822511 0.765512
# olfactory_mitral_base 0.749581   0.780296 0.721193
#
# ================================================================================
# Processing: wikiann - bn
# ================================================================================
# Loading test data...
# Loading wikiann dataset from HuggingFace (unimelb-nlp/wikiann)...
# Configuration: bn
#
# Data splits available: ['validation', 'test', 'train']
# Number of labels: 7
# Label names: ['O', 'B-PER', 'I-PER', 'B-ORG', 'I-ORG', 'B-LOC', 'I-LOC']
#
# Data splits:
#   Train: 10000 sentences
#   Valid: 1000 sentences
#   Test: 1000 sentences
#
# Building vocabularies...
# Vocabulary size: 3633
# Number of labels: 7
# Generating Heatmaps...
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Creating glomeruli activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   বিভাগের: 5.778
#   বিভাগের: 5.778
#   বিভাগের: 5.778
#   বিভাগের: 5.778
#   হারারে: 4.953
#
# Receptor 1:
#   উমিয়া: 5.055
#   উমিয়া: 5.055
#   অশোক: 4.999
#   ফেরিস: 4.987
#   শারজাহ]]: 4.778
#
# Receptor 2:
#   ইনস্টিটিউট: 4.777
#   ইনস্টিটিউট: 4.777
#   ইনস্টিটিউট: 4.777
#   ইনস্টিটিউট: 4.777
#   আর্বী: 4.545
#
# Receptor 3:
#   ,: 5.898
#   ,: 5.898
#   ,: 5.898
#   ,: 5.898
#   ,: 5.898
#
# Receptor 4:
#   উপদ্বীপ: 6.387
#   উন্নয়ন: 5.621
#   উন্নয়ন: 5.621
#   উন্নয়ন: 5.621
#   গ্রীষ্মকালীন: 5.078
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 36.33%
# Average activation (when active): 1.567
# Average Receptor Selectivity Index (RSI): 0.6069
#
# ✓ Analysis complete! Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/bn/visualizations/olfactory_base
# ✓ Heatmaps generated for olfactory_base
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Creating glomeruli activation heatmap...
# Creating mitral activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   চীনের: 7.142
#   চীনের: 7.142
#   চীনের: 7.142
#   চীনের: 7.142
#   ,: 6.910
#
# Receptor 1:
#   বিশ্বকাপ: 4.924
#   বিশ্বকাপ: 4.924
#   বিশ্বকাপ: 4.924
#   বিশ্বকাপ: 4.924
#   বিশ্বকাপ: 4.924
#
# Receptor 2:
#   স্কুল: 7.294
#   স্কুল: 7.294
#   স্কুল: 7.294
#   স্কুল: 7.294
#   অলিম্পিকে: 6.944
#
# Receptor 3:
#   (: 5.350
#   (: 5.350
#   (: 5.350
#   (: 5.350
#   (: 5.350
#
# Receptor 4:
#   টাউন: 5.293
#   টাউন: 5.293
#   টাউন: 5.293
#   টাউন: 5.293
#   সংস্থা: 4.302
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 36.25%
# Average activation (when active): 1.725
# Average Receptor Selectivity Index (RSI): 0.6530
#
# ✓ Analysis complete! Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/bn/visualizations/olfactory_mitral_base
# ✓ Heatmaps generated for olfactory_mitral_base
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Creating glomeruli activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   জেলা: 5.426
#   জেলা: 5.426
#   জেলা: 5.426
#   জেলা: 5.426
#   জেলা: 5.426
#
# Receptor 1:
#   হল: 3.978
#   আন্তর্জাতিক: 3.874
#   আন্তর্জাতিক: 3.874
#   আন্তর্জাতিক: 3.874
#   আন্তর্জাতিক: 3.874
#
# Receptor 2:
#   জোন: 5.466
#   জোন: 5.466
#   ইসরায়েলের: 4.386
#   ইয়োহান: 3.729
#   ইয়োহান: 3.729
#
# Receptor 3:
#   ফন: 5.181
#   ফন: 5.181
#   ফন: 5.181
#   ফন: 5.181
#   ফন: 5.181
#
# Receptor 4:
#   পরিষদ: 5.845
#   ক্রিকেট: 4.420
#   ক্রিকেট: 4.420
#   ক্রিকেট: 4.420
#   ক্রিকেট: 4.420
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 34.11%
# Average activation (when active): 1.234
# Average Receptor Selectivity Index (RSI): 0.5623
#
# ✓ Analysis complete! Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/bn/visualizations/olfactory_more
# ✓ Heatmaps generated for olfactory_more
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Creating glomeruli activation heatmap...
# Creating mitral activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   প্রিন্স: 3.951
#   প্রিন্স: 3.951
#   প্রিন্স: 3.951
#   প্রিন্স: 3.951
#   পরগণা: 3.912
#
# Receptor 1:
#   দ্য: 3.771
#   দ্য: 3.771
#   দ্য: 3.771
#   দ্য: 3.771
#   দ্য: 3.771
#
# Receptor 2:
#   সিডনি: 3.541
#   সিডনি: 3.541
#   সিডনি: 3.541
#   সিডনি: 3.541
#   চন্দ্র: 3.430
#
# Receptor 3:
#   ধনেশ: 4.120
#   ধনেশ: 4.120
#   ধনেশ: 4.120
#   ধনেশ: 4.120
#   ধনেশ: 4.120
#
# Receptor 4:
#   পুরাণ: 4.151
#   জর্জ: 3.268
#   জর্জ: 3.268
#   জর্জ: 3.268
#   জর্জ: 3.268
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 35.24%
# Average activation (when active): 1.119
# Average Receptor Selectivity Index (RSI): 0.5932
#
# ✓ Analysis complete! Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/bn/visualizations/olfactory_mitral_more
# ✓ Heatmaps generated for olfactory_mitral_more
#
# Results Summary (bn):
#            Experiment       F1  Precision   Recall
#              baseline 0.939114   0.943466 0.934803
#        olfactory_more 0.935113   0.937269 0.932966
#        olfactory_base 0.923077   0.931712 0.914601
# olfactory_mitral_base 0.923006   0.926852 0.919192
# olfactory_mitral_more 0.916705   0.929245 0.904500
#
# ================================================================================
# Processing: wikiann - te
# ================================================================================
# Loading test data...
# Loading wikiann dataset from HuggingFace (unimelb-nlp/wikiann)...
# Configuration: te
#
# Data splits available: ['validation', 'test', 'train']
# Number of labels: 7
# Label names: ['O', 'B-PER', 'I-PER', 'B-ORG', 'I-ORG', 'B-LOC', 'I-LOC']
#
# Data splits:
#   Train: 1000 sentences
#   Valid: 1000 sentences
#   Test: 1000 sentences
#
# Building vocabularies...
# Vocabulary size: 833
# Number of labels: 7
# Generating Heatmaps...
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Creating glomeruli activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   ధర్మరాజు: 5.521
#   ధర్మరాజు: 5.521
#   ధర్మరాజు: 5.521
#   ధర్మరాజు: 5.521
#   ధర్మరాజు: 5.521
#
# Receptor 1:
#   ': 3.807
#   ': 3.807
#   ': 3.807
#   ': 3.807
#   ': 3.807
#
# Receptor 2:
#   కుబేరుడు: 3.379
#   తానే: 3.027
#   ధర్మరాజు: 2.974
#   ధర్మరాజు: 2.974
#   ధర్మరాజు: 2.974
#
# Receptor 3:
#   దారిమార్పు: 8.211
#   దారిమార్పు: 8.211
#   దారిమార్పు: 8.211
#   దారిమార్పు: 8.211
#   దారిమార్పు: 8.211
#
# Receptor 4:
#   <UNK>: 2.789
#   <UNK>: 2.789
#   <UNK>: 2.789
#   <UNK>: 2.789
#   <UNK>: 2.789
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 31.51%
# Average activation (when active): 1.723
# Average Receptor Selectivity Index (RSI): 0.6456
#
# ✓ Analysis complete! Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/te/visualizations/olfactory_base
# ✓ Heatmaps generated for olfactory_base
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Creating glomeruli activation heatmap...
# Creating mitral activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   భారీ: 3.271
#   ప్రసాద్: 2.917
#   కారణం: 2.876
#   కారణం: 2.876
#   నేను: 2.844
#
# Receptor 1:
#   కర్ణుడు: 4.312
#   కర్ణుడు: 4.312
#   కర్ణుడు: 4.312
#   కర్ణుడు: 4.312
#   కర్ణుడు: 4.312
#
# Receptor 2:
#   <UNK>: 3.969
#   <UNK>: 3.969
#   <UNK>: 3.969
#   <UNK>: 3.969
#   <UNK>: 3.969
#
# Receptor 3:
#   -: 5.289
#   -: 5.289
#   -: 5.289
#   -: 5.289
#   -: 5.289
#
# Receptor 4:
#   ': 5.273
#   ': 5.273
#   ': 5.273
#   ': 5.273
#   ': 5.273
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 25.37%
# Average activation (when active): 1.695
# Average Receptor Selectivity Index (RSI): 0.5982
#
# ✓ Analysis complete! Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/te/visualizations/olfactory_mitral_base
# ✓ Heatmaps generated for olfactory_mitral_base
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Creating glomeruli activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   నుండి: 2.229
#   నుండి: 2.229
#   నుండి: 2.229
#   నుండి: 2.229
#   నుండి: 2.229
#
# Receptor 1:
#   నందమూరి: 2.324
#   నందమూరి: 2.324
#   నందమూరి: 2.324
#   నందమూరి: 2.324
#   కర్ణుడు: 2.307
#
# Receptor 2:
#   రాష్ట్రములోని: 3.004
#   మరియు: 2.922
#   మరియు: 2.922
#   మరియు: 2.922
#   మరియు: 2.922
#
# Receptor 3:
#   దారిమార్పు: 4.495
#   దారిమార్పు: 4.495
#   దారిమార్పు: 4.495
#   దారిమార్పు: 4.495
#   దారిమార్పు: 4.495
#
# Receptor 4:
#   జిల్లా: 5.486
#   జిల్లా: 5.486
#   జిల్లా: 5.486
#   జిల్లా: 5.486
#   జిల్లా: 5.486
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 23.54%
# Average activation (when active): 0.999
# Average Receptor Selectivity Index (RSI): 0.6500
#
# ✓ Analysis complete! Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/te/visualizations/olfactory_more
# ✓ Heatmaps generated for olfactory_more
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Creating glomeruli activation heatmap...
# Creating mitral activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   చెందిన: 1.890
#   చెందిన: 1.890
#   చెందిన: 1.890
#   చెందిన: 1.890
#   చెందిన: 1.890
#
# Receptor 1:
#   .: 2.334
#   .: 2.334
#   .: 2.334
#   .: 2.334
#   .: 2.334
#
# Receptor 2:
#   మరియు: 2.981
#   మరియు: 2.981
#   మరియు: 2.981
#   మరియు: 2.981
#   మరియు: 2.981
#
# Receptor 3:
#   దారిమార్పు: 4.762
#   దారిమార్పు: 4.762
#   దారిమార్పు: 4.762
#   దారిమార్పు: 4.762
#   దారిమార్పు: 4.762
#
# Receptor 4:
#   ఈయన: 3.337
#   ఈయన: 3.337
#   ఈయన: 3.337
#   ఈయన: 3.337
#   ఈయన: 3.337
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 33.50%
# Average activation (when active): 1.199
# Average Receptor Selectivity Index (RSI): 0.5717
#
# ✓ Analysis complete! Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/te/visualizations/olfactory_mitral_more
# ✓ Heatmaps generated for olfactory_mitral_more
#
# Results Summary (te):
#            Experiment       F1  Precision   Recall
#        olfactory_more 0.595506   0.659067 0.543126
#        olfactory_base 0.572097   0.633161 0.521776
#              baseline 0.503844   0.535577 0.475662
# olfactory_mitral_more 0.495962   0.558887 0.445773
# olfactory_mitral_base 0.477722   0.516899 0.444065

# %%
# @title 4. Save Olfactory Metrics to Results
from src.analysis.visualize import analyze_receptor_activations
from src.model.olfactory_ner import create_olfactory_ner
from src.data.unified_loader import get_dataset
import torch
import json
import os
import sys

# Ensure src is in path
if os.getcwd() not in sys.path:
    sys.path.append(os.getcwd())

if 'BASE_SAVE_DIR' not in locals():
    BASE_SAVE_DIR = '/content/drive/My Drive/olfaction_inspired_ner_mitral' if os.path.exists('/content/drive') else './results'

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Updating results in: {BASE_SAVE_DIR}")

# Scan for datasets
datasets_found = [d for d in os.listdir(BASE_SAVE_DIR) if os.path.isdir(os.path.join(BASE_SAVE_DIR, d))]

for dataset_name in datasets_found:
    d_path = os.path.join(BASE_SAVE_DIR, dataset_name)
    languages = [l for l in os.listdir(d_path) if os.path.isdir(os.path.join(d_path, l))]

    for lang in languages:
        full_results_dir = os.path.join(d_path, lang)
        print(f"\nProcessing {dataset_name}/{lang}...")

        # Load Data once per dataset/language
        try:
            _, _, test_loader, vocab_info = get_dataset(
                dataset_name=dataset_name,
                language=lang if lang != 'default' else 'en',
                cache_dir='./data'
            )
        except Exception as e:
            print(f"Skipping data load for {dataset_name} ({e})")
            continue

        experiments = [e for e in os.listdir(full_results_dir) if os.path.isdir(os.path.join(full_results_dir, e))]

        for exp in experiments:
            if 'baseline' in exp: continue

            res_path = os.path.join(full_results_dir, exp, 'results.json')
            model_path = os.path.join(full_results_dir, exp, 'best_model.pt')

            if os.path.exists(res_path) and os.path.exists(model_path):
                # Load existing results
                with open(res_path, 'r') as f:
                    results = json.load(f)

                # Check if metrics already exist to save time (optional, remove check to force update)
                # if 'olfactory_metrics' in results: continue

                config = results['config']
                if not config.get('use_receptors', True): continue

                print(f"  Analyzing {exp}...")

                # Load Model
                try:
                    model = create_olfactory_ner(len(vocab_info['word2idx']), len(vocab_info['label2idx']), config)
                    checkpoint = torch.load(model_path, map_location=device, weights_only=False)
                    model.load_state_dict(checkpoint['model_state_dict'])
                    model = model.to(device)

                    # Run Analysis (suppress plots by saving to temp or just ignoring)
                    # analyze_receptor_activations returns a dict with metrics
                    # We pass a dummy save_dir because the function tries to save plots
                    dummy_dir = os.path.join(full_results_dir, exp, 'temp_viz')
                    os.makedirs(dummy_dir, exist_ok=True)

                    analysis_stats = analyze_receptor_activations(
                        model, test_loader, vocab_info, device,
                        save_dir=dummy_dir, experiment_name=exp
                    )

                    # Extract Metrics
                    olfactory_metrics = {
                        'sparsity': analysis_stats.get('sparsity', 0),
                        'avg_activation': analysis_stats.get('avg_activation', 0),
                        'avg_rsi': analysis_stats.get('avg_rsi', 0)
                    }

                    # Update Results
                    results['olfactory_metrics'] = olfactory_metrics

                    # Save back
                    with open(res_path, 'w') as f:
                        json.dump(results, f, indent=2)

                    print(f"    -> Saved Sparsity: {olfactory_metrics['sparsity']:.2%}, RSI: {olfactory_metrics['avg_rsi']:.4f}")

                except Exception as e:
                    print(f"    -> Error: {e}")

print("\nDONE. All results.json files updated.")
# Out:
# Updating results in: /content/drive/My Drive/olfaction_inspired_ner_mitral
#
# Processing conll2003/default...
# Initialize CoNLL-2003 dataset loading...
# Loading training data...
#
# Building vocabularies...
# Vocabulary size: 11984
# Number of labels: 8
#   Analyzing olfactory_base...
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Creating glomeruli activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   Games: 0.417
#   BEAT: 0.409
#   BEAT: 0.409
#   League: 0.402
#   League: 0.402
#
# Receptor 1:
#   0: 3.844
#   0: 3.844
#   0: 3.844
#   0: 3.844
#   0: 3.844
#
# Receptor 2:
#   0: 1.708
#   0: 1.708
#   0: 1.708
#   0: 1.708
#   0: 1.708
#
# Receptor 3:
#   0: 5.628
#   0: 5.628
#   0: 5.628
#   0: 5.628
#   0: 5.628
#
# Receptor 4:
#   told: 1.785
#   told: 1.785
#   told: 1.785
#   told: 1.785
#   told: 1.785
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 31.17%
# Average activation (when active): 0.334
# Average Receptor Selectivity Index (RSI): 0.8289
#
# ✓ Analysis complete! Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/conll2003/default/olfactory_base/temp_viz
#     -> Saved Sparsity: 31.17%, RSI: 0.8289
#   Analyzing olfactory_mitral_base...
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Creating glomeruli activation heatmap...
# Creating mitral activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   ,: 7.338
#   ,: 7.338
#   ,: 7.338
#   ,: 7.338
#   ,: 7.338
#
# Receptor 1:
#   ,: 6.393
#   ,: 6.393
#   ,: 6.393
#   ,: 6.393
#   ,: 6.393
#
# Receptor 2:
#   ,: 5.577
#   ,: 5.577
#   ,: 5.577
#   ,: 5.577
#   ,: 5.577
#
# Receptor 3:
#   ,: 5.834
#   ,: 5.834
#   ,: 5.834
#   ,: 5.834
#   ,: 5.834
#
# Receptor 4:
#   Jan: 1.524
#   Jan: 1.524
#   CHAMPIONSHIP: 1.187
#   Group: 1.179
#   Group: 1.179
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 44.46%
# Average activation (when active): 0.341
# Average Receptor Selectivity Index (RSI): 0.5669
#
# ✓ Analysis complete! Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/conll2003/default/olfactory_mitral_base/temp_viz
#     -> Saved Sparsity: 44.46%, RSI: 0.5669
#   Analyzing olfactory_more...
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Creating glomeruli activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   v: 1.194
#   v: 1.194
#   v: 1.194
#   v: 1.194
#   v: 1.194
#
# Receptor 1:
#   National: 0.923
#   National: 0.923
#   National: 0.923
#   National: 0.923
#   National: 0.923
#
# Receptor 2:
#   Inc: 0.938
#   Inc: 0.938
#   Inc: 0.938
#   Inc: 0.938
#   Sachs: 0.832
#
# Receptor 3:
#   neighbouring: 0.765
#   Yeltsin: 0.753
#   Yeltsin: 0.753
#   Yeltsin: 0.753
#   Yeltsin: 0.753
#
# Receptor 4:
#   v: 2.673
#   v: 2.673
#   v: 2.673
#   v: 2.673
#   v: 2.673
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 22.56%
# Average activation (when active): 0.318
# Average Receptor Selectivity Index (RSI): 0.8401
#
# ✓ Analysis complete! Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/conll2003/default/olfactory_more/temp_viz
#     -> Saved Sparsity: 22.56%, RSI: 0.8401
#   Analyzing olfactory_mitral_more...
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Creating glomeruli activation heatmap...
# Creating mitral activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   ,: 1.669
#   ,: 1.669
#   ,: 1.669
#   ,: 1.669
#   ,: 1.669
#
# Receptor 1:
#   said: 1.461
#   said: 1.461
#   said: 1.461
#   said: 1.461
#   said: 1.461
#
# Receptor 2:
#   said: 2.631
#   said: 2.631
#   said: 2.631
#   said: 2.631
#   said: 2.631
#
# Receptor 3:
#   said: 1.154
#   said: 1.154
#   said: 1.154
#   said: 1.154
#   said: 1.154
#
# Receptor 4:
#   said: 1.886
#   said: 1.886
#   said: 1.886
#   said: 1.886
#   said: 1.886
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 21.55%
# Average activation (when active): 0.210
# Average Receptor Selectivity Index (RSI): 0.7744
#
# ✓ Analysis complete! Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/conll2003/default/olfactory_mitral_more/temp_viz
#     -> Saved Sparsity: 21.55%, RSI: 0.7744
#
# Processing wikiann/hi...
# Loading wikiann dataset from HuggingFace (unimelb-nlp/wikiann)...
# Configuration: hi
#
# Data splits available: ['validation', 'test', 'train']
# Number of labels: 7
# Label names: ['O', 'B-PER', 'I-PER', 'B-ORG', 'I-ORG', 'B-LOC', 'I-LOC']
#
# Data splits:
#   Train: 5000 sentences
#   Valid: 1000 sentences
#   Test: 1000 sentences
#
# Building vocabularies...
# Vocabulary size: 2844
# Number of labels: 7
#   Analyzing olfactory_base...
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Creating glomeruli activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   में: 4.539
#   में: 4.539
#   में: 4.539
#   में: 4.539
#   में: 4.539
#
# Receptor 1:
#   को: 5.214
#   को: 5.214
#   को: 5.214
#   को: 5.214
#   को: 5.214
#
# Receptor 2:
#   मुख्यमन्त्रियों: 4.483
#   मुख्यमन्त्रियों: 4.483
#   मुख्यमन्त्रियों: 4.483
#   मुख्यमन्त्रियों: 4.483
#   मुख्यमन्त्रियों: 4.483
#
# Receptor 3:
#   बल: 4.291
#   बल: 4.291
#   फॉर: 3.702
#   रिकॉर्ड: 3.604
#   एन: 3.575
#
# Receptor 4:
#   भौतिक: 5.087
#   महाराष्ट्र: 4.428
#   महाराष्ट्र: 4.428
#   महाराष्ट्र: 4.428
#   महाराष्ट्र: 4.428
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 31.10%
# Average activation (when active): 1.410
# Average Receptor Selectivity Index (RSI): 0.5296
#
# ✓ Analysis complete! Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/hi/olfactory_base/temp_viz
#     -> Saved Sparsity: 31.10%, RSI: 0.5296
#   Analyzing olfactory_mitral_base...
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Creating glomeruli activation heatmap...
# Creating mitral activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   में: 7.504
#   में: 7.504
#   में: 7.504
#   में: 7.504
#   में: 7.504
#
# Receptor 1:
#   को: 5.854
#   को: 5.854
#   को: 5.854
#   को: 5.854
#   को: 5.854
#
# Receptor 2:
#   अनुप्रेषित: 7.636
#   अनुप्रेषित: 7.636
#   अनुप्रेषित: 7.636
#   अनुप्रेषित: 7.636
#   अनुप्रेषित: 7.636
#
# Receptor 3:
#   ...: 4.290
#   ...: 4.290
#   ': 3.773
#   ': 3.773
#   ': 3.773
#
# Receptor 4:
#   और: 7.869
#   और: 7.869
#   और: 7.869
#   और: 7.869
#   और: 7.869
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 29.30%
# Average activation (when active): 1.693
# Average Receptor Selectivity Index (RSI): 0.4703
#
# ✓ Analysis complete! Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/hi/olfactory_mitral_base/temp_viz
#     -> Saved Sparsity: 29.30%, RSI: 0.4703
#   Analyzing olfactory_more...
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Creating glomeruli activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   कुमार: 4.130
#   कुमार: 4.130
#   कुमार: 4.130
#   कुमार: 4.130
#   कुमार: 4.130
#
# Receptor 1:
#   भूमिका: 3.070
#   भूमिका: 3.070
#   भूमिका: 3.070
#   भूमिका: 3.070
#   भूमिका: 3.070
#
# Receptor 2:
#   भारत: 4.018
#   भारत: 4.018
#   भारत: 4.018
#   भारत: 4.018
#   भारत: 4.018
#
# Receptor 3:
#   कुणाल: 3.891
#   का: 3.854
#   का: 3.854
#   का: 3.854
#   का: 3.854
#
# Receptor 4:
#   मुख्य: 5.051
#   मारिया: 3.572
#   प्रीमियर: 3.561
#   अजमेर: 3.536
#   ईसा: 3.392
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 28.73%
# Average activation (when active): 1.155
# Average Receptor Selectivity Index (RSI): 0.5141
#
# ✓ Analysis complete! Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/hi/olfactory_more/temp_viz
#     -> Saved Sparsity: 28.73%, RSI: 0.5141
#   Analyzing olfactory_mitral_more...
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Creating glomeruli activation heatmap...
# Creating mitral activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   जिला: 6.233
#   जिला: 6.233
#   जिला: 6.233
#   जिला: 6.233
#   जिला: 6.233
#
# Receptor 1:
#   --: 4.431
#   --: 4.431
#   --: 4.431
#   --: 4.431
#   --: 4.431
#
# Receptor 2:
#   से: 4.369
#   से: 4.369
#   से: 4.369
#   से: 4.369
#   से: 4.369
#
# Receptor 3:
#   ...: 4.141
#   ...: 4.141
#   तथा: 4.022
#   तथा: 4.022
#   ': 3.789
#
# Receptor 4:
#   E: 5.123
#   E: 5.123
#   ``: 4.002
#   ``: 4.002
#   ``: 4.002
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 29.53%
# Average activation (when active): 1.243
# Average Receptor Selectivity Index (RSI): 0.4939
#
# ✓ Analysis complete! Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/hi/olfactory_mitral_more/temp_viz
#     -> Saved Sparsity: 29.53%, RSI: 0.4939
#
# Processing wikiann/mr...
# Loading wikiann dataset from HuggingFace (unimelb-nlp/wikiann)...
# Configuration: mr
#
# Data splits available: ['validation', 'test', 'train']
# Number of labels: 7
# Label names: ['O', 'B-PER', 'I-PER', 'B-ORG', 'I-ORG', 'B-LOC', 'I-LOC']
#
# Data splits:
#   Train: 5000 sentences
#   Valid: 1000 sentences
#   Test: 1000 sentences
#
# Building vocabularies...
# Vocabulary size: 3208
# Number of labels: 7
#   Analyzing olfactory_base...
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Creating glomeruli activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   सम्राट: 5.773
#   सम्राट: 5.773
#   सम्राट: 5.773
#   सम्राट: 5.773
#   खेळाडू: 5.667
#
# Receptor 1:
#   ट्रेक: 5.422
#   ट्रेक: 5.422
#   ट्रेक: 5.422
#   ट्रेक: 5.422
#   ट्रेक: 5.422
#
# Receptor 2:
#   ': 4.143
#   ': 4.143
#   ': 4.143
#   ': 4.143
#   ': 4.143
#
# Receptor 3:
#   इंडिया: 5.956
#   इंडिया: 5.956
#   इंडिया: 5.956
#   इंडिया: 5.956
#   इंडिया: 5.956
#
# Receptor 4:
#   <UNK>: 7.511
#   <UNK>: 7.511
#   <UNK>: 7.511
#   <UNK>: 7.511
#   <UNK>: 7.511
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 31.26%
# Average activation (when active): 1.562
# Average Receptor Selectivity Index (RSI): 0.5350
#
# ✓ Analysis complete! Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/mr/olfactory_base/temp_viz
#     -> Saved Sparsity: 31.26%, RSI: 0.5350
#   Analyzing olfactory_mitral_base...
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Creating glomeruli activation heatmap...
# Creating mitral activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   विनोद: 4.028
#   भारतात: 3.870
#   भारतात: 3.870
#   भारतात: 3.870
#   भारतात: 3.870
#
# Receptor 1:
#   शहरात: 4.902
#   शिक्षण: 4.407
#   शिक्षण: 4.407
#   शिक्षण: 4.407
#   शिक्षण: 4.407
#
# Receptor 2:
#   मतदारसंघ: 5.702
#   मतदारसंघ: 5.702
#   मतदारसंघ: 5.702
#   मतदारसंघ: 5.702
#   मतदारसंघ: 5.702
#
# Receptor 3:
#   आहे: 4.422
#   आहे: 4.422
#   आहे: 4.422
#   आहे: 4.422
#   आहे: 4.422
#
# Receptor 4:
#   <UNK>: 6.022
#   <UNK>: 6.022
#   <UNK>: 6.022
#   <UNK>: 6.022
#   <UNK>: 6.022
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 27.85%
# Average activation (when active): 1.437
# Average Receptor Selectivity Index (RSI): 0.4954
#
# ✓ Analysis complete! Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/mr/olfactory_mitral_base/temp_viz
#     -> Saved Sparsity: 27.85%, RSI: 0.4954
#   Analyzing olfactory_more...
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Creating glomeruli activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   ऑक्सफर्ड: 3.679
#   बँक: 3.581
#   बँक: 3.581
#   बँक: 3.581
#   बँक: 3.581
#
# Receptor 1:
#   ': 3.435
#   ': 3.435
#   ': 3.435
#   ': 3.435
#   ': 3.435
#
# Receptor 2:
#   भाभा: 3.420
#   पुणे: 3.405
#   पुणे: 3.405
#   पुणे: 3.405
#   पुणे: 3.405
#
# Receptor 3:
#   परमार: 2.870
#   बच्चन: 2.792
#   बच्चन: 2.792
#   बच्चन: 2.792
#   बच्चन: 2.792
#
# Receptor 4:
#   हे: 4.258
#   हे: 4.258
#   हे: 4.258
#   हे: 4.258
#   हे: 4.258
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 28.04%
# Average activation (when active): 1.072
# Average Receptor Selectivity Index (RSI): 0.5227
#
# ✓ Analysis complete! Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/mr/olfactory_more/temp_viz
#     -> Saved Sparsity: 28.04%, RSI: 0.5227
#   Analyzing olfactory_mitral_more...
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Creating glomeruli activation heatmap...
# Creating mitral activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   हायकमिशन: 3.821
#   हायकमिशन: 3.821
#   हायकमिशन: 3.821
#   येते: 3.587
#   येते: 3.587
#
# Receptor 1:
#   येते: 4.577
#   येते: 4.577
#   येते: 4.577
#   येते: 4.577
#   धावणाऱ्या: 3.152
#
# Receptor 2:
#   ': 5.429
#   ': 5.429
#   ': 5.429
#   ': 5.429
#   ': 5.429
#
# Receptor 3:
#   /: 3.780
#   /: 3.780
#   ,: 3.722
#   ,: 3.722
#   ,: 3.722
#
# Receptor 4:
#   नारायण: 3.625
#   नारायण: 3.625
#   नारायण: 3.625
#   नारायण: 3.625
#   आल्प-मरितीम: 3.385
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 30.81%
# Average activation (when active): 1.249
# Average Receptor Selectivity Index (RSI): 0.4558
#
# ✓ Analysis complete! Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/mr/olfactory_mitral_more/temp_viz
#     -> Saved Sparsity: 30.81%, RSI: 0.4558
#
# Processing wikiann/ta...
# Loading wikiann dataset from HuggingFace (unimelb-nlp/wikiann)...
# Configuration: ta
#
# Data splits available: ['validation', 'test', 'train']
# Number of labels: 7
# Label names: ['O', 'B-PER', 'I-PER', 'B-ORG', 'I-ORG', 'B-LOC', 'I-LOC']
#
# Data splits:
#   Train: 15000 sentences
#   Valid: 1000 sentences
#   Test: 1000 sentences
#
# Building vocabularies...
# Vocabulary size: 8867
# Number of labels: 7
#   Analyzing olfactory_base...
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Creating glomeruli activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   ``: 6.125
#   ``: 6.125
#   ``: 6.125
#   ``: 6.125
#   ``: 6.125
#
# Receptor 1:
#   முக்கிய: 6.302
#   முக்கிய: 6.302
#   முக்கிய: 6.302
#   முக்கிய: 6.302
#   முக்கிய: 6.302
#
# Receptor 2:
#   பிரதேசம்: 6.840
#   கொல்கத்தா: 6.643
#   டென்னிசு: 6.265
#   தமிழ்நாட்டில்: 5.988
#   தமிழ்நாட்டில்: 5.988
#
# Receptor 3:
#   உயரமான: 6.013
#   தொடக்க: 5.975
#   தொடக்க: 5.975
#   புலவர்: 5.732
#   அனேக: 5.695
#
# Receptor 4:
#   ;: 8.928
#   ;: 8.928
#   ;: 8.928
#   ;: 8.928
#   ;: 8.928
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 30.86%
# Average activation (when active): 1.904
# Average Receptor Selectivity Index (RSI): 0.5286
#
# ✓ Analysis complete! Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/ta/olfactory_base/temp_viz
#     -> Saved Sparsity: 30.86%, RSI: 0.5286
#   Analyzing olfactory_mitral_base...
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Creating glomeruli activation heatmap...
# Creating mitral activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   பல்கலைக்கழகம்: 6.805
#   பல்கலைக்கழகம்: 6.805
#   பல்கலைக்கழகம்: 6.805
#   பல்கலைக்கழகம்: 6.805
#   பல்கலைக்கழகம்: 6.805
#
# Receptor 1:
#   தலம்: 6.665
#   இடம்: 6.465
#   இடம்: 6.465
#   தொடர்ந்து: 5.971
#   இவர்: 5.623
#
# Receptor 2:
#   துறை: 7.741
#   படுத்தினார்: 6.233
#   தமிழீழ: 5.631
#   தமிழீழ: 5.631
#   பிரதேசம்: 5.534
#
# Receptor 3:
#   .: 12.067
#   .: 12.067
#   .: 12.067
#   .: 12.067
#   .: 12.067
#
# Receptor 4:
#   கட்சி: 8.731
#   கட்சி: 8.731
#   கட்சி: 8.731
#   கட்சி: 8.731
#   கட்சி: 8.731
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 26.58%
# Average activation (when active): 2.256
# Average Receptor Selectivity Index (RSI): 0.5494
#
# ✓ Analysis complete! Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/ta/olfactory_mitral_base/temp_viz
#     -> Saved Sparsity: 26.58%, RSI: 0.5494
#   Analyzing olfactory_more...
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Creating glomeruli activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   வழிமாற்று: 6.165
#   வழிமாற்று: 6.165
#   வழிமாற்று: 6.165
#   வழிமாற்று: 6.165
#   வழிமாற்று: 6.165
#
# Receptor 1:
#   து: 7.090
#   ஜொகூர்: 5.210
#   ஜொகூர்: 5.210
#   தொகுதியாகும்: 5.004
#   தொகுதியாகும்: 5.004
#
# Receptor 2:
#   மைக்ரோசாப்ட்: 5.431
#   மியூசிக்: 4.940
#   இரு: 4.677
#   இரு: 4.677
#   இரு: 4.677
#
# Receptor 3:
#   கூட்டு: 6.075
#   கூட்டமைப்பு: 5.053
#   கூட்டமைப்பு: 5.053
#   பொறியியல்: 4.785
#   செயற்றிட்டம்: 4.574
#
# Receptor 4:
#   வட: 5.531
#   வட: 5.531
#   வட: 5.531
#   வட: 5.531
#   நா.: 5.183
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 28.97%
# Average activation (when active): 1.426
# Average Receptor Selectivity Index (RSI): 0.4655
#
# ✓ Analysis complete! Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/ta/olfactory_more/temp_viz
#     -> Saved Sparsity: 28.97%, RSI: 0.4655
#   Analyzing olfactory_mitral_more...
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Creating glomeruli activation heatmap...
# Creating mitral activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   வழிமாற்று: 6.916
#   வழிமாற்று: 6.916
#   வழிமாற்று: 6.916
#   வழிமாற்று: 6.916
#   வழிமாற்று: 6.916
#
# Receptor 1:
#   மன்னர்களின்: 6.690
#   ): 6.497
#   ): 6.497
#   ): 6.497
#   ): 6.497
#
# Receptor 2:
#   பாக்காத்தான்: 5.348
#   பாக்காத்தான்: 5.348
#   பாக்காத்தான்: 5.348
#   பாக்காத்தான்: 5.348
#   பாக்காத்தான்: 5.348
#
# Receptor 3:
#   அவையின்: 6.584
#   கூட்டமைப்பு: 6.019
#   கூட்டமைப்பு: 6.019
#   தொகுதி: 5.482
#   தொகுதி: 5.482
#
# Receptor 4:
#   இரு: 6.363
#   இரு: 6.363
#   இரு: 6.363
#   சார்லசு: 5.725
#   காலத்தில்: 5.652
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 26.03%
# Average activation (when active): 1.570
# Average Receptor Selectivity Index (RSI): 0.4859
#
# ✓ Analysis complete! Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/ta/olfactory_mitral_more/temp_viz
#     -> Saved Sparsity: 26.03%, RSI: 0.4859
#
# Processing wikiann/bn...
# Loading wikiann dataset from HuggingFace (unimelb-nlp/wikiann)...
# Configuration: bn
#
# Data splits available: ['validation', 'test', 'train']
# Number of labels: 7
# Label names: ['O', 'B-PER', 'I-PER', 'B-ORG', 'I-ORG', 'B-LOC', 'I-LOC']
#
# Data splits:
#   Train: 10000 sentences
#   Valid: 1000 sentences
#   Test: 1000 sentences
#
# Building vocabularies...
# Vocabulary size: 3633
# Number of labels: 7
#   Analyzing olfactory_base...
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Creating glomeruli activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   বিভাগের: 5.778
#   বিভাগের: 5.778
#   বিভাগের: 5.778
#   বিভাগের: 5.778
#   হারারে: 4.953
#
# Receptor 1:
#   উমিয়া: 5.055
#   উমিয়া: 5.055
#   অশোক: 4.999
#   ফেরিস: 4.987
#   শারজাহ]]: 4.778
#
# Receptor 2:
#   ইনস্টিটিউট: 4.777
#   ইনস্টিটিউট: 4.777
#   ইনস্টিটিউট: 4.777
#   ইনস্টিটিউট: 4.777
#   আর্বী: 4.545
#
# Receptor 3:
#   ,: 5.898
#   ,: 5.898
#   ,: 5.898
#   ,: 5.898
#   ,: 5.898
#
# Receptor 4:
#   উপদ্বীপ: 6.387
#   উন্নয়ন: 5.621
#   উন্নয়ন: 5.621
#   উন্নয়ন: 5.621
#   গ্রীষ্মকালীন: 5.078
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 36.33%
# Average activation (when active): 1.567
# Average Receptor Selectivity Index (RSI): 0.6069
#
# ✓ Analysis complete! Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/bn/olfactory_base/temp_viz
#     -> Saved Sparsity: 36.33%, RSI: 0.6069
#   Analyzing olfactory_mitral_base...
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Creating glomeruli activation heatmap...
# Creating mitral activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   চীনের: 7.142
#   চীনের: 7.142
#   চীনের: 7.142
#   চীনের: 7.142
#   ,: 6.910
#
# Receptor 1:
#   বিশ্বকাপ: 4.924
#   বিশ্বকাপ: 4.924
#   বিশ্বকাপ: 4.924
#   বিশ্বকাপ: 4.924
#   বিশ্বকাপ: 4.924
#
# Receptor 2:
#   স্কুল: 7.294
#   স্কুল: 7.294
#   স্কুল: 7.294
#   স্কুল: 7.294
#   অলিম্পিকে: 6.944
#
# Receptor 3:
#   (: 5.350
#   (: 5.350
#   (: 5.350
#   (: 5.350
#   (: 5.350
#
# Receptor 4:
#   টাউন: 5.293
#   টাউন: 5.293
#   টাউন: 5.293
#   টাউন: 5.293
#   সংস্থা: 4.302
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 36.25%
# Average activation (when active): 1.725
# Average Receptor Selectivity Index (RSI): 0.6530
#
# ✓ Analysis complete! Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/bn/olfactory_mitral_base/temp_viz
#     -> Saved Sparsity: 36.25%, RSI: 0.6530
#   Analyzing olfactory_more...
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Creating glomeruli activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   জেলা: 5.426
#   জেলা: 5.426
#   জেলা: 5.426
#   জেলা: 5.426
#   জেলা: 5.426
#
# Receptor 1:
#   হল: 3.978
#   আন্তর্জাতিক: 3.874
#   আন্তর্জাতিক: 3.874
#   আন্তর্জাতিক: 3.874
#   আন্তর্জাতিক: 3.874
#
# Receptor 2:
#   জোন: 5.466
#   জোন: 5.466
#   ইসরায়েলের: 4.386
#   ইয়োহান: 3.729
#   ইয়োহান: 3.729
#
# Receptor 3:
#   ফন: 5.181
#   ফন: 5.181
#   ফন: 5.181
#   ফন: 5.181
#   ফন: 5.181
#
# Receptor 4:
#   পরিষদ: 5.845
#   ক্রিকেট: 4.420
#   ক্রিকেট: 4.420
#   ক্রিকেট: 4.420
#   ক্রিকেট: 4.420
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 34.11%
# Average activation (when active): 1.234
# Average Receptor Selectivity Index (RSI): 0.5623
#
# ✓ Analysis complete! Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/bn/olfactory_more/temp_viz
#     -> Saved Sparsity: 34.11%, RSI: 0.5623
#   Analyzing olfactory_mitral_more...
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Creating glomeruli activation heatmap...
# Creating mitral activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   প্রিন্স: 3.951
#   প্রিন্স: 3.951
#   প্রিন্স: 3.951
#   প্রিন্স: 3.951
#   পরগণা: 3.912
#
# Receptor 1:
#   দ্য: 3.771
#   দ্য: 3.771
#   দ্য: 3.771
#   দ্য: 3.771
#   দ্য: 3.771
#
# Receptor 2:
#   সিডনি: 3.541
#   সিডনি: 3.541
#   সিডনি: 3.541
#   সিডনি: 3.541
#   চন্দ্র: 3.430
#
# Receptor 3:
#   ধনেশ: 4.120
#   ধনেশ: 4.120
#   ধনেশ: 4.120
#   ধনেশ: 4.120
#   ধনেশ: 4.120
#
# Receptor 4:
#   পুরাণ: 4.151
#   জর্জ: 3.268
#   জর্জ: 3.268
#   জর্জ: 3.268
#   জর্জ: 3.268
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 35.24%
# Average activation (when active): 1.119
# Average Receptor Selectivity Index (RSI): 0.5932
#
# ✓ Analysis complete! Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/bn/olfactory_mitral_more/temp_viz
#     -> Saved Sparsity: 35.24%, RSI: 0.5932
#
# Processing wikiann/te...
# Loading wikiann dataset from HuggingFace (unimelb-nlp/wikiann)...
# Configuration: te
#
# Data splits available: ['validation', 'test', 'train']
# Number of labels: 7
# Label names: ['O', 'B-PER', 'I-PER', 'B-ORG', 'I-ORG', 'B-LOC', 'I-LOC']
#
# Data splits:
#   Train: 1000 sentences
#   Valid: 1000 sentences
#   Test: 1000 sentences
#
# Building vocabularies...
# Vocabulary size: 833
# Number of labels: 7
#   Analyzing olfactory_base...
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Creating glomeruli activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   ధర్మరాజు: 5.521
#   ధర్మరాజు: 5.521
#   ధర్మరాజు: 5.521
#   ధర్మరాజు: 5.521
#   ధర్మరాజు: 5.521
#
# Receptor 1:
#   ': 3.807
#   ': 3.807
#   ': 3.807
#   ': 3.807
#   ': 3.807
#
# Receptor 2:
#   కుబేరుడు: 3.379
#   తానే: 3.027
#   ధర్మరాజు: 2.974
#   ధర్మరాజు: 2.974
#   ధర్మరాజు: 2.974
#
# Receptor 3:
#   దారిమార్పు: 8.211
#   దారిమార్పు: 8.211
#   దారిమార్పు: 8.211
#   దారిమార్పు: 8.211
#   దారిమార్పు: 8.211
#
# Receptor 4:
#   <UNK>: 2.789
#   <UNK>: 2.789
#   <UNK>: 2.789
#   <UNK>: 2.789
#   <UNK>: 2.789
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 31.51%
# Average activation (when active): 1.723
# Average Receptor Selectivity Index (RSI): 0.6456
#
# ✓ Analysis complete! Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/te/olfactory_base/temp_viz
#     -> Saved Sparsity: 31.51%, RSI: 0.6456
#   Analyzing olfactory_mitral_base...
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Creating glomeruli activation heatmap...
# Creating mitral activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   భారీ: 3.271
#   ప్రసాద్: 2.917
#   కారణం: 2.876
#   కారణం: 2.876
#   నేను: 2.844
#
# Receptor 1:
#   కర్ణుడు: 4.312
#   కర్ణుడు: 4.312
#   కర్ణుడు: 4.312
#   కర్ణుడు: 4.312
#   కర్ణుడు: 4.312
#
# Receptor 2:
#   <UNK>: 3.969
#   <UNK>: 3.969
#   <UNK>: 3.969
#   <UNK>: 3.969
#   <UNK>: 3.969
#
# Receptor 3:
#   -: 5.289
#   -: 5.289
#   -: 5.289
#   -: 5.289
#   -: 5.289
#
# Receptor 4:
#   ': 5.273
#   ': 5.273
#   ': 5.273
#   ': 5.273
#   ': 5.273
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 25.37%
# Average activation (when active): 1.695
# Average Receptor Selectivity Index (RSI): 0.5982
#
# ✓ Analysis complete! Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/te/olfactory_mitral_base/temp_viz
#     -> Saved Sparsity: 25.37%, RSI: 0.5982
#   Analyzing olfactory_more...
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Creating glomeruli activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   నుండి: 2.229
#   నుండి: 2.229
#   నుండి: 2.229
#   నుండి: 2.229
#   నుండి: 2.229
#
# Receptor 1:
#   నందమూరి: 2.324
#   నందమూరి: 2.324
#   నందమూరి: 2.324
#   నందమూరి: 2.324
#   కర్ణుడు: 2.307
#
# Receptor 2:
#   రాష్ట్రములోని: 3.004
#   మరియు: 2.922
#   మరియు: 2.922
#   మరియు: 2.922
#   మరియు: 2.922
#
# Receptor 3:
#   దారిమార్పు: 4.495
#   దారిమార్పు: 4.495
#   దారిమార్పు: 4.495
#   దారిమార్పు: 4.495
#   దారిమార్పు: 4.495
#
# Receptor 4:
#   జిల్లా: 5.486
#   జిల్లా: 5.486
#   జిల్లా: 5.486
#   జిల్లా: 5.486
#   జిల్లా: 5.486
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 23.54%
# Average activation (when active): 0.999
# Average Receptor Selectivity Index (RSI): 0.6500
#
# ✓ Analysis complete! Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/te/olfactory_more/temp_viz
#     -> Saved Sparsity: 23.54%, RSI: 0.6500
#   Analyzing olfactory_mitral_more...
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Creating glomeruli activation heatmap...
# Creating mitral activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   చెందిన: 1.890
#   చెందిన: 1.890
#   చెందిన: 1.890
#   చెందిన: 1.890
#   చెందిన: 1.890
#
# Receptor 1:
#   .: 2.334
#   .: 2.334
#   .: 2.334
#   .: 2.334
#   .: 2.334
#
# Receptor 2:
#   మరియు: 2.981
#   మరియు: 2.981
#   మరియు: 2.981
#   మరియు: 2.981
#   మరియు: 2.981
#
# Receptor 3:
#   దారిమార్పు: 4.762
#   దారిమార్పు: 4.762
#   దారిమార్పు: 4.762
#   దారిమార్పు: 4.762
#   దారిమార్పు: 4.762
#
# Receptor 4:
#   ఈయన: 3.337
#   ఈయన: 3.337
#   ఈయన: 3.337
#   ఈయన: 3.337
#   ఈయన: 3.337
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 33.50%
# Average activation (when active): 1.199
# Average Receptor Selectivity Index (RSI): 0.5717
#
# ✓ Analysis complete! Results saved to /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/te/olfactory_mitral_more/temp_viz
#     -> Saved Sparsity: 33.50%, RSI: 0.5717
#
# DONE. All results.json files updated.

# %%
# @title 4. Compare Results (F1 Score Bar Plots for All Datasets)
import os
import json
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Setup paths
if 'BASE_SAVE_DIR' not in locals():
    BASE_SAVE_DIR = '/content/drive/My Drive/olfaction_inspired_ner_mitral' if os.path.exists('/content/drive') else './results'

print(f"Generating plots from: {BASE_SAVE_DIR}")

if not os.path.exists(BASE_SAVE_DIR):
    print("Results directory not found.")
else:
    # Scan for datasets
    datasets_found = [d for d in os.listdir(BASE_SAVE_DIR) if os.path.isdir(os.path.join(BASE_SAVE_DIR, d))]

    for dataset_name in datasets_found:
        d_path = os.path.join(BASE_SAVE_DIR, dataset_name)
        languages = [l for l in os.listdir(d_path) if os.path.isdir(os.path.join(d_path, l))]

        for lang in languages:
            full_results_dir = os.path.join(d_path, lang)
            viz_dir = os.path.join(full_results_dir, 'visualizations')
            os.makedirs(viz_dir, exist_ok=True)

            # Collect metrics for this dataset/language
            metrics = []
            experiments = [e for e in os.listdir(full_results_dir) if os.path.isdir(os.path.join(full_results_dir, e)) and e != 'visualizations']

            for exp in experiments:
                res_path = os.path.join(full_results_dir, exp, 'results.json')
                if os.path.exists(res_path):
                    try:
                        with open(res_path, 'r') as f:
                            data = json.load(f)
                        metrics.append({
                            'Experiment': exp,
                            'F1': data['test']['f1']
                        })
                    except:
                        pass

            # Plot
            if metrics:
                df = pd.DataFrame(metrics)
                df = df.sort_values(by='F1', ascending=False)

                plt.figure(figsize=(10, 6))
                sns.barplot(x='F1', y='Experiment', data=df, palette='viridis')
                plt.title(f'F1 Score Comparison - {dataset_name} ({lang})')
                plt.xlim(0, 1.0)
                plt.grid(axis='x', alpha=0.3)
                plt.tight_layout()

                # Save and Show
                save_path = os.path.join(viz_dir, 'f1_comparison.png')
                plt.savefig(save_path, dpi=300)
                plt.show()
                print(f"✓ Generated plot for {dataset_name}/{lang}")
                plt.close()
            else:
                print(f"No results found for {dataset_name}/{lang}")
# Out:
# Generating plots from: /content/drive/My Drive/olfaction_inspired_ner_mitral
# /tmp/ipython-input-3616013194.py:52: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='F1', y='Experiment', data=df, palette='viridis')
# ✓ Generated plot for conll2003/default
# /tmp/ipython-input-3616013194.py:52: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='F1', y='Experiment', data=df, palette='viridis')
# ✓ Generated plot for wikiann/hi
# /tmp/ipython-input-3616013194.py:52: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='F1', y='Experiment', data=df, palette='viridis')
# ✓ Generated plot for wikiann/mr
# /tmp/ipython-input-3616013194.py:52: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='F1', y='Experiment', data=df, palette='viridis')
# ✓ Generated plot for wikiann/ta
# /tmp/ipython-input-3616013194.py:52: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='F1', y='Experiment', data=df, palette='viridis')
# ✓ Generated plot for wikiann/bn
# /tmp/ipython-input-3616013194.py:52: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='F1', y='Experiment', data=df, palette='viridis')
# ✓ Generated plot for wikiann/te

# %%
# @title 4b. Plot Per-Entity F1 Scores
# ==============================================================================
import os
import json
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Setup paths (ensure BASE_SAVE_DIR is correct)
if 'BASE_SAVE_DIR' not in locals():
    BASE_SAVE_DIR = '/content/drive/My Drive/olfaction_inspired_ner_mitral' if os.path.exists('/content/drive') else './results'

print(f"Generating Per-Entity plots from: {BASE_SAVE_DIR}")

if not os.path.exists(BASE_SAVE_DIR):
    print("Results directory not found.")
else:
    # Scan for datasets
    datasets_found = [d for d in os.listdir(BASE_SAVE_DIR) if os.path.isdir(os.path.join(BASE_SAVE_DIR, d))]

    for dataset_name in datasets_found:
        d_path = os.path.join(BASE_SAVE_DIR, dataset_name)
        languages = [l for l in os.listdir(d_path) if os.path.isdir(os.path.join(d_path, l))]

        for lang in languages:
            full_results_dir = os.path.join(d_path, lang)
            viz_dir = os.path.join(full_results_dir, 'visualizations')
            os.makedirs(viz_dir, exist_ok=True)

            # Collect Per-Entity metrics
            data_records = []
            experiments = [e for e in os.listdir(full_results_dir) if os.path.isdir(os.path.join(full_results_dir, e)) and e != 'visualizations']

            for exp in experiments:
                res_path = os.path.join(full_results_dir, exp, 'results.json')
                if os.path.exists(res_path):
                    try:
                        with open(res_path, 'r') as f:
                            res = json.load(f)

                        test_metrics = res['test']
                        per_entity = test_metrics.get('per_entity', {})

                        for entity, f1 in per_entity.items():
                            data_records.append({
                                'Experiment': exp,
                                'Entity Type': entity,
                                'F1 Score': f1
                            })
                    except Exception as e:
                        print(f"Skipping {exp}: {e}")

            # Plot
            if data_records:
                df_entity = pd.DataFrame(data_records)

                plt.figure(figsize=(14, 8))

                # Grouped Bar Plot
                chart = sns.barplot(
                    data=df_entity,
                    x='Entity Type',
                    y='F1 Score',
                    hue='Experiment',
                    palette='tab10',
                    edgecolor='black'
                )

                plt.title(f'Per-Entity F1 Score Comparison ({dataset_name} - {lang})', fontsize=16, fontweight='bold')
                plt.ylim(0, 1.05)
                plt.grid(axis='y', alpha=0.3)

                # Legend placement outside
                plt.legend(bbox_to_anchor=(1.01, 1), loc='upper left', borderaxespad=0.)
                plt.tight_layout()

                # Save and Show
                save_path = os.path.join(viz_dir, 'per_entity_f1_comparison.png')
                plt.savefig(save_path, dpi=300, bbox_inches='tight')
                plt.show()
                print(f"✓ Generated Per-Entity plot for {dataset_name}/{lang}")
                plt.close()
            else:
                print(f"No per-entity data found for {dataset_name}/{lang}")
# Out:
# Generating Per-Entity plots from: /content/drive/My Drive/olfaction_inspired_ner_mitral
# ✓ Generated Per-Entity plot for conll2003/default
# ✓ Generated Per-Entity plot for wikiann/hi
# ✓ Generated Per-Entity plot for wikiann/mr
# ✓ Generated Per-Entity plot for wikiann/ta
# ✓ Generated Per-Entity plot for wikiann/bn
# ✓ Generated Per-Entity plot for wikiann/te

# %%
# @title 4c. Plot Precision vs Recall (Bubble Chart)
# ==============================================================================
import os
import json
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Setup paths
if 'BASE_SAVE_DIR' not in locals():
    BASE_SAVE_DIR = '/content/drive/My Drive/olfaction_inspired_ner_mitral' if os.path.exists('/content/drive') else './results'

print(f"Generating Bubble Plots from: {BASE_SAVE_DIR}")

if not os.path.exists(BASE_SAVE_DIR):
    print("Results directory not found.")
else:
    # Scan for datasets
    datasets_found = [d for d in os.listdir(BASE_SAVE_DIR) if os.path.isdir(os.path.join(BASE_SAVE_DIR, d))]

    for dataset_name in datasets_found:
        d_path = os.path.join(BASE_SAVE_DIR, dataset_name)
        languages = [l for l in os.listdir(d_path) if os.path.isdir(os.path.join(d_path, l))]

        for lang in languages:
            full_results_dir = os.path.join(d_path, lang)
            viz_dir = os.path.join(full_results_dir, 'visualizations')
            os.makedirs(viz_dir, exist_ok=True)

            # Collect metrics
            metrics = []
            experiments = [e for e in os.listdir(full_results_dir) if os.path.isdir(os.path.join(full_results_dir, e)) and e != 'visualizations']

            for exp in experiments:
                res_path = os.path.join(full_results_dir, exp, 'results.json')
                if os.path.exists(res_path):
                    try:
                        with open(res_path, 'r') as f:
                            data = json.load(f)
                        metrics.append({
                            'Experiment': exp,
                            'F1': data['test']['f1'],
                            'Precision': data['test']['precision'],
                            'Recall': data['test']['recall']
                        })
                    except:
                        pass

            # Plot
            if metrics:
                df = pd.DataFrame(metrics)

                plt.figure(figsize=(12, 10))

                # Bubble Plot: X=Recall, Y=Precision, Size=F1
                scatter = sns.scatterplot(
                    data=df,
                    x='Recall',
                    y='Precision',
                    size='F1',
                    sizes=(400, 2000), # Adjust bubble sizes
                    hue='Experiment',
                    palette='tab10',
                    alpha=0.7,
                    edgecolor='black',
                    legend=False
                )

                # Annotate points
                for i, row in df.iterrows():
                    plt.text(
                        row['Recall'],
                        row['Precision'],
                        f"{row['Experiment']}",
                        fontsize=10,
                        ha='center',
                        va='center',
                        fontweight='bold'
                    )

                plt.title(f'Precision vs Recall (Bubble Size = F1 Score) - {dataset_name}/{lang}', fontsize=16, fontweight='bold')
                plt.xlabel('Recall', fontsize=12, fontweight='bold')
                plt.ylabel('Precision', fontsize=12, fontweight='bold')
                plt.grid(True, alpha=0.3)
                plt.tight_layout()

                # Save and Show
                save_path = os.path.join(viz_dir, 'precision_recall_bubble.png')
                plt.savefig(save_path, dpi=300, bbox_inches='tight')
                plt.show()
                print(f"✓ Generated Bubble plot for {dataset_name}/{lang}")
                plt.close()
            else:
                print(f"No results found for {dataset_name}/{lang}")
# Out:
# Generating Bubble Plots from: /content/drive/My Drive/olfaction_inspired_ner_mitral
# ✓ Generated Bubble plot for conll2003/default
# ✓ Generated Bubble plot for wikiann/hi
# ✓ Generated Bubble plot for wikiann/mr
# ✓ Generated Bubble plot for wikiann/ta
# ✓ Generated Bubble plot for wikiann/bn
# ✓ Generated Bubble plot for wikiann/te

# %%
# @title 4d. Comprehensive Metrics Table (Dataset-wide)
# ==============================================================================
import os
import json
import pandas as pd

# Setup paths
if 'BASE_SAVE_DIR' not in locals():
    BASE_SAVE_DIR = '/content/drive/My Drive/olfaction_inspired_ner_mitral' if os.path.exists('/content/drive') else './results'

print(f"Generating Tables from: {BASE_SAVE_DIR}")

if not os.path.exists(BASE_SAVE_DIR):
    print("Results directory not found.")
else:
    # Scan for datasets
    datasets_found = [d for d in os.listdir(BASE_SAVE_DIR) if os.path.isdir(os.path.join(BASE_SAVE_DIR, d))]

    for dataset_name in datasets_found:
        d_path = os.path.join(BASE_SAVE_DIR, dataset_name)
        languages = [l for l in os.listdir(d_path) if os.path.isdir(os.path.join(d_path, l))]

        for lang in languages:
            full_results_dir = os.path.join(d_path, lang)
            viz_dir = os.path.join(full_results_dir, 'visualizations')
            os.makedirs(viz_dir, exist_ok=True)

            print(f"\n{'#'*100}")
            print(f"DATASET: {dataset_name} | LANGUAGE: {lang}")
            print(f"{'#'*100}")

            # Collect metrics
            metrics_data = []
            experiments = [e for e in os.listdir(full_results_dir) if os.path.isdir(os.path.join(full_results_dir, e)) and e != 'visualizations']

            for exp_name in experiments:
                res_path = os.path.join(full_results_dir, exp_name, 'results.json')
                if os.path.exists(res_path):
                    try:
                        with open(res_path, 'r') as f:
                            data = json.load(f)

                        test_metrics = data.get('test', {})
                        per_entity = test_metrics.get('per_entity', {})

                        # Extract metrics matching your desired format
                        # Note: keys for per_entity depend on the dataset (LOC/PER/ORG vs others)
                        # We try to get common ones, or default to 0

                        row = {
                            'Experiment': exp_name,
                            'F1': test_metrics.get('f1', 0),
                            'Precision': test_metrics.get('precision', 0),
                            'Recall': test_metrics.get('recall', 0),
                            # Try standard entities, use .get() to be safe
                            'LOC_F1': per_entity.get('LOC', 0),
                            'MISC_F1': per_entity.get('MISC', 0),
                            'ORG_F1': per_entity.get('ORG', 0),
                            'PER_F1': per_entity.get('PER', 0),
                            # Averages might be stored directly or inside per_entity depending on implementation
                            # If not present, we use Overall F1 as Micro Avg proxy
                            'Micro_Avg': per_entity.get('micro avg', test_metrics.get('f1', 0)),
                            'Macro_Avg': per_entity.get('macro avg', 0),
                            'Weighted_Avg': per_entity.get('weighted avg', 0)
                            # If your evaluation code calculates macro/weighted, fetch it here.
                            # Standard seqeval output often puts averages in the report dict,
                            # but simpler implementations might not save them explicitly.
                            # We'll check if they exist in per_entity (output of classification_report(output_dict=True))
                        }

                        # Add any other entities dynamically if they exist and aren't standard
                        # (Optional: uncomment to see all dynamic keys)
                        # for k, v in per_entity.items():
                        #     if k not in ['LOC', 'MISC', 'ORG', 'PER']:
                        #         row[f'{k}_F1'] = v

                        metrics_data.append(row)
                    except Exception as e:
                        print(f"Error reading {exp_name}: {e}")

            # Create DataFrame
            if metrics_data:
                metrics_df = pd.DataFrame(metrics_data)

                # Sort by F1 score descending
                metrics_df = metrics_df.sort_values('F1', ascending=False)

                # Display
                print(metrics_df.round(4).to_string(index=False))

                # Save
                save_path = os.path.join(viz_dir, 'comprehensive_metrics_table.csv')
                metrics_df.to_csv(save_path, index=False)
                print(f"\n✓ Table saved to: {save_path}")
            else:
                print("No experiment data found.")
            print("\n")
# Out:
# Generating Tables from: /content/drive/My Drive/olfaction_inspired_ner_mitral
#
# ####################################################################################################
# DATASET: conll2003 | LANGUAGE: default
# ####################################################################################################
#            Experiment     F1  Precision  Recall  LOC_F1  MISC_F1  ORG_F1  PER_F1  Micro_Avg  Macro_Avg  Weighted_Avg
#              baseline 0.7386     0.7700  0.7096  0.8391   0.6511  0.6841  0.7291     0.7386     0.7259        0.7387
#        olfactory_more 0.7149     0.7469  0.6856  0.8054   0.6700  0.6660  0.6834     0.7149     0.7062        0.7126
# olfactory_mitral_more 0.7094     0.7431  0.6786  0.8201   0.6769  0.6214  0.7069     0.7094     0.7063        0.7114
#        olfactory_base 0.7054     0.7368  0.6765  0.7859   0.5709  0.6940  0.6984     0.7054     0.6873        0.7071
# olfactory_mitral_base 0.6876     0.7589  0.6285  0.8046   0.6552  0.6199  0.6365     0.6876     0.6791        0.6836
#
# ✓ Table saved to: /content/drive/My Drive/olfaction_inspired_ner_mitral/conll2003/default/visualizations/comprehensive_metrics_table.csv
#
#
#
# ####################################################################################################
# DATASET: wikiann | LANGUAGE: hi
# ####################################################################################################
#            Experiment     F1  Precision  Recall  LOC_F1  MISC_F1  ORG_F1  PER_F1  Micro_Avg  Macro_Avg  Weighted_Avg
#        olfactory_more 0.8437     0.8503  0.8371  0.8287        0  0.8168  0.8788     0.8437     0.8414        0.8435
#              baseline 0.8367     0.8412  0.8322  0.8366        0  0.8126  0.8581     0.8367     0.8358        0.8374
# olfactory_mitral_more 0.8194     0.8078  0.8314  0.8087        0  0.8352  0.8174     0.8194     0.8204        0.8197
# olfactory_mitral_base 0.8043     0.8228  0.7866  0.7964        0  0.7816  0.8314     0.8043     0.8031        0.8048
#        olfactory_base 0.7959     0.7797  0.8127  0.7745        0  0.7434  0.8610     0.7959     0.7930        0.7970
#
# ✓ Table saved to: /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/hi/visualizations/comprehensive_metrics_table.csv
#
#
#
# ####################################################################################################
# DATASET: wikiann | LANGUAGE: mr
# ####################################################################################################
#            Experiment     F1  Precision  Recall  LOC_F1  MISC_F1  ORG_F1  PER_F1  Micro_Avg  Macro_Avg  Weighted_Avg
# olfactory_mitral_more 0.7967     0.8212  0.7737  0.7468        0  0.7825  0.8768     0.7967     0.8020        0.7956
#        olfactory_base 0.7891     0.8129  0.7666  0.7369        0  0.7983  0.8514     0.7891     0.7955        0.7886
#              baseline 0.7881     0.8143  0.7634  0.7558        0  0.7768  0.8408     0.7881     0.7912        0.7871
#        olfactory_more 0.7730     0.7956  0.7516  0.7518        0  0.7507  0.8240     0.7730     0.7755        0.7729
# olfactory_mitral_base 0.7632     0.8003  0.7294  0.6977        0  0.7489  0.8575     0.7632     0.7680        0.7599
#
# ✓ Table saved to: /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/mr/visualizations/comprehensive_metrics_table.csv
#
#
#
# ####################################################################################################
# DATASET: wikiann | LANGUAGE: ta
# ####################################################################################################
#            Experiment     F1  Precision  Recall  LOC_F1  MISC_F1  ORG_F1  PER_F1  Micro_Avg  Macro_Avg  Weighted_Avg
# olfactory_mitral_more 0.7998     0.8198  0.7808  0.7774        0  0.8011  0.8218     0.7998     0.8001        0.7998
#        olfactory_more 0.7962     0.8157  0.7776  0.7761        0  0.7978  0.8162     0.7962     0.7967        0.7964
#        olfactory_base 0.7933     0.8028  0.7840  0.7890        0  0.7891  0.8014     0.7933     0.7932        0.7933
#              baseline 0.7930     0.8225  0.7655  0.7872        0  0.7919  0.8000     0.7930     0.7930        0.7930
# olfactory_mitral_base 0.7496     0.7803  0.7212  0.7626        0  0.7123  0.7676     0.7496     0.7475        0.7488
#
# ✓ Table saved to: /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/ta/visualizations/comprehensive_metrics_table.csv
#
#
#
# ####################################################################################################
# DATASET: wikiann | LANGUAGE: bn
# ####################################################################################################
#            Experiment     F1  Precision  Recall  LOC_F1  MISC_F1  ORG_F1  PER_F1  Micro_Avg  Macro_Avg  Weighted_Avg
#              baseline 0.9391     0.9435  0.9348  0.9366        0  0.9457  0.9353     0.9391     0.9392        0.9391
#        olfactory_more 0.9351     0.9373  0.9330  0.9156        0  0.9510  0.9412     0.9351     0.9359        0.9351
#        olfactory_base 0.9231     0.9317  0.9146  0.9079        0  0.9458  0.9176     0.9231     0.9238        0.9232
# olfactory_mitral_base 0.9230     0.9269  0.9192  0.9124        0  0.9396  0.9188     0.9230     0.9236        0.9231
# olfactory_mitral_more 0.9167     0.9292  0.9045  0.8979        0  0.9354  0.9186     0.9167     0.9173        0.9165
#
# ✓ Table saved to: /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/bn/visualizations/comprehensive_metrics_table.csv
#
#
#
# ####################################################################################################
# DATASET: wikiann | LANGUAGE: te
# ####################################################################################################
#            Experiment     F1  Precision  Recall  LOC_F1  MISC_F1  ORG_F1  PER_F1  Micro_Avg  Macro_Avg  Weighted_Avg
#        olfactory_more 0.5955     0.6591  0.5431  0.6400        0  0.5778  0.5610     0.5955     0.5930        0.5963
#        olfactory_base 0.5721     0.6332  0.5218  0.5806        0  0.6269  0.5163     0.5721     0.5746        0.5731
#              baseline 0.5038     0.5356  0.4757  0.5968        0  0.5107  0.3857     0.5038     0.4977        0.5031
# olfactory_mitral_more 0.4960     0.5589  0.4458  0.5632        0  0.5223  0.4038     0.4960     0.4965        0.4995
# olfactory_mitral_base 0.4777     0.5169  0.4441  0.5512        0  0.4611  0.4012     0.4777     0.4712        0.4762
#
# ✓ Table saved to: /content/drive/My Drive/olfaction_inspired_ner_mitral/wikiann/te/visualizations/comprehensive_metrics_table.csv

# %%
# done
