# %% [markdown]
# # 🧪 Comprehensive Olfaction-Inspired NER Experiments
#
# **Goal**: Run 12 different NER experiments with comprehensive analysis
#
# This notebook includes:
# - ✅ 12 different experiment configurations
# - ✅ Heatmap generation for receptor and glomeruli activations
# - ✅ Comprehensive metrics (micro/macro averages, per-entity F1)
# - ✅ Model saving and comparison
# - ✅ Visualization and results export
#
# **Estimated Runtime**: 3-5 hours on GPU (T4), longer on CPU
#
# ---

# %% [markdown]
# ## 📋 Section 1: Setup & Environment

# %% [markdown]
# ### 1.1 Check GPU Availability

# %%
import torch
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
else:
    print("⚠️ No GPU - training will be slow!")
# Out:
# PyTorch version: 2.9.0+cu126
# CUDA available: True
# GPU: Tesla T4

# %% [markdown]
# ### 1.2 Clone Repository

# %%
import getpass
import os

# Check if already in the repo directory
if not os.path.exists('src/train.py'):
    # Get your token securely (won't be visible in output)
    token = getpass.getpass('Enter your GitHub Personal Access Token: ')
    
    # Clone using token
    # !git clone https://{token}@github.com/bhushan1729/olfaction-inspired-ner.git
    # %cd olfaction-inspired-ner
else:
    print("✓ Already in repository directory")
# Out:
# Cloning into 'olfaction-inspired-ner'...
# remote: Enumerating objects: 222, done.
# remote: Counting objects: 100% (222/222), done.
# remote: Compressing objects: 100% (157/157), done.
# remote: Total 222 (delta 99), reused 175 (delta 56), pack-reused 0 (from 0)
# Receiving objects: 100% (222/222), 2.07 MiB | 20.21 MiB/s, done.
# Resolving deltas: 100% (99/99), done.
# /content/olfaction-inspired-ner

# %% [markdown]
# ### 1.3 Install Dependencies

# %%
# !pip install -q torch numpy scikit-learn seqeval matplotlib seaborn pandas tqdm tensorboard pyyaml requests
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 3.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for seqeval (setup.py) ... done

# %% [markdown]
# ### 1.4 Download GloVe Embeddings

# %%
import os

if not os.path.exists('./data/glove.6B.300d.txt'):
    print("Downloading GloVe embeddings (takes ~5 min)...")
    # !mkdir -p data
    # !wget -q http://nlp.stanford.edu/data/glove.6B.zip -O data/glove.6B.zip
    # !unzip -q data/glove.6B.zip -d data/
    # !rm data/glove.6B.zip
    print("✓ GloVe downloaded")
else:
    print("✓ GloVe already exists")
# Out:
# Downloading GloVe embeddings (takes ~5 min)...
# ✓ GloVe downloaded

# %% [markdown]
# ### 1.5 Configure Python Path

# %%
import sys
import os

# Get the current working directory and add to path
project_root = os.getcwd()
if project_root not in sys.path:
    sys.path.insert(0, project_root)

print(f"✓ Path configured: {project_root}")
# Out:
# ✓ Path configured: /content/olfaction-inspired-ner

# %% [markdown]
# ### 1.6 Create Results Directories

# %%
# Create directories for results and visualizations
# !mkdir -p results visualizations

print("✓ Directories created:")
print("  - results/")
print("  - visualizations/")
# Out:
# ✓ Directories created:
#   - results/
#   - visualizations/

# %% [markdown]
# ---
# ## 🏋️ Section 2: Train 12 Experiments
#
# Each experiment trains a different model configuration and saves:
# - Best model checkpoint (`best_model.pt`)
# - Training results (`results.json`)
# - Training metrics (`metrics.json`)

# %% [markdown]
# ### Experiment 1: GELU Activation
# **Hypothesis**: Biologically-plausible GELU activation improves receptor specialization

# %%
# !python src/train.py \
  --config config/tuning_experiments.yaml \
  --experiment activation_gelu \
  --save_dir results/activation_gelu
# Out:
# 2026-01-15 09:09:14.862274: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768468154.882995    3253 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768468154.888964    3253 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1768468154.903678    3253 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768468154.903704    3253 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768468154.903708    3253 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768468154.903712    3253 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-01-15 09:09:14.908217: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Using device: cuda
#
# ==================================================
# Loading data...
# ==================================================
# Downloading CoNLL-2003 dataset...
# Downloading train.txt from https://raw.githubusercontent.com/patverga/torch-ner-nlp-from-scratch/master/data/conll2003/eng.train...
# ✓ Downloaded train.txt
# Downloading valid.txt from https://raw.githubusercontent.com/patverga/torch-ner-nlp-from-scratch/master/data/conll2003/eng.testa...
# ✓ Downloaded valid.txt
# Downloading test.txt from https://raw.githubusercontent.com/patverga/torch-ner-nlp-from-scratch/master/data/conll2003/eng.testb...
# ✓ Downloaded test.txt
# Loading training data...
# Loading validation data...
# Loading test data...
# Train: 14041 sentences
# Valid: 3250 sentences
# Test: 3453 sentences
#
# Building vocabularies...
# Vocabulary size: 11984
# Number of labels: 8
# Labels: ['B-LOC', 'B-MISC', 'B-ORG', 'I-LOC', 'I-MISC', 'I-ORG', 'I-PER', 'O']
#
# Loading GloVe embeddings from ./data/glove.6B.300d.txt...
# Loading GloVe embeddings from ./data/glove.6B.300d.txt...
# Found embeddings for 6544/11984 words (54.6%)
#
# ==================================================
# Creating olfactory model...
# ==================================================
# Total parameters: 4,235,928
# Trainable parameters: 4,235,928
#
# ==================================================
# Starting training...
# ==================================================
#
# ==================================================
# Epoch 1/50
# ==================================================
# Training: 100% 439/439 [00:23<00:00, 18.80it/s, loss=2.0653, task=2.0630]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 50.89it/s]
#
# Train Loss: 4.8268
# Valid F1: 0.5741
# Valid Precision: 0.6482
# Valid Recall: 0.5151
#
# ✓ Saved new best model (F1: 0.5741)
#
# ==================================================
# Epoch 2/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.34it/s, loss=2.1528, task=2.1508]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 52.43it/s]
#
# Train Loss: 2.1361
# Valid F1: 0.7441
# Valid Precision: 0.8118
# Valid Recall: 0.6868
#
# ✓ Saved new best model (F1: 0.7441)
#
# ==================================================
# Epoch 3/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.37it/s, loss=1.9373, task=1.9354]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 53.42it/s]
#
# Train Loss: 1.4751
# Valid F1: 0.7809
# Valid Precision: 0.8414
# Valid Recall: 0.7285
#
# ✓ Saved new best model (F1: 0.7809)
#
# ==================================================
# Epoch 4/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.50it/s, loss=1.6864, task=1.6847]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 52.01it/s]
#
# Train Loss: 1.2017
# Valid F1: 0.7871
# Valid Precision: 0.8379
# Valid Recall: 0.7422
#
# ✓ Saved new best model (F1: 0.7871)
#
# ==================================================
# Epoch 5/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.53it/s, loss=1.0557, task=1.0540]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 53.01it/s]
#
# Train Loss: 1.0489
# Valid F1: 0.8001
# Valid Precision: 0.8521
# Valid Recall: 0.7541
#
# ✓ Saved new best model (F1: 0.8001)
#
# ==================================================
# Epoch 6/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.62it/s, loss=0.6471, task=0.6456]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 45.94it/s]
#
# Train Loss: 0.9541
# Valid F1: 0.8024
# Valid Precision: 0.8620
# Valid Recall: 0.7506
#
# ✓ Saved new best model (F1: 0.8024)
#
# ==================================================
# Epoch 7/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.42it/s, loss=0.0719, task=0.0704]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 53.05it/s]
#
# Train Loss: 0.8658
# Valid F1: 0.8061
# Valid Precision: 0.8563
# Valid Recall: 0.7614
#
# ✓ Saved new best model (F1: 0.8061)
#
# ==================================================
# Epoch 8/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.60it/s, loss=0.1453, task=0.1439]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 52.60it/s]
#
# Train Loss: 0.8167
# Valid F1: 0.8066
# Valid Precision: 0.8684
# Valid Recall: 0.7529
#
# ✓ Saved new best model (F1: 0.8066)
#
# ==================================================
# Epoch 9/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.57it/s, loss=1.0496, task=1.0482]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 52.36it/s]
#
# Train Loss: 0.7608
# Valid F1: 0.8074
# Valid Precision: 0.8530
# Valid Recall: 0.7664
#
# ✓ Saved new best model (F1: 0.8074)
#
# ==================================================
# Epoch 10/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.65it/s, loss=0.6501, task=0.6487]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 50.97it/s]
#
# Train Loss: 0.7295
# Valid F1: 0.8055
# Valid Precision: 0.8558
# Valid Recall: 0.7609
#
# No improvement (1/5)
#
# ==================================================
# Epoch 11/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.57it/s, loss=0.9812, task=0.9799]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 52.81it/s]
#
# Train Loss: 0.6810
# Valid F1: 0.8130
# Valid Precision: 0.8516
# Valid Recall: 0.7777
#
# ✓ Saved new best model (F1: 0.8130)
#
# ==================================================
# Epoch 12/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.59it/s, loss=0.2957, task=0.2943]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 52.85it/s]
#
# Train Loss: 0.6393
# Valid F1: 0.8217
# Valid Precision: 0.8715
# Valid Recall: 0.7773
#
# ✓ Saved new best model (F1: 0.8217)
#
# ==================================================
# Epoch 13/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.57it/s, loss=0.3163, task=0.3150]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 53.19it/s]
#
# Train Loss: 0.5978
# Valid F1: 0.8212
# Valid Precision: 0.8762
# Valid Recall: 0.7728
#
# No improvement (1/5)
#
# ==================================================
# Epoch 14/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.52it/s, loss=0.3067, task=0.3054]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 52.29it/s]
#
# Train Loss: 0.5760
# Valid F1: 0.8149
# Valid Precision: 0.8652
# Valid Recall: 0.7701
#
# No improvement (2/5)
#
# ==================================================
# Epoch 15/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.54it/s, loss=0.5300, task=0.5287]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 52.35it/s]
#
# Train Loss: 0.5591
# Valid F1: 0.8145
# Valid Precision: 0.8670
# Valid Recall: 0.7679
#
# No improvement (3/5)
#
# ==================================================
# Epoch 16/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.87it/s, loss=0.1350, task=0.1337]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 50.29it/s]
#
# Train Loss: 0.4874
# Valid F1: 0.8283
# Valid Precision: 0.8746
# Valid Recall: 0.7866
#
# ✓ Saved new best model (F1: 0.8283)
#
# ==================================================
# Epoch 17/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.18it/s, loss=0.5516, task=0.5503]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 46.49it/s]
#
# Train Loss: 0.4594
# Valid F1: 0.8305
# Valid Precision: 0.8759
# Valid Recall: 0.7896
#
# ✓ Saved new best model (F1: 0.8305)
#
# ==================================================
# Epoch 18/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.19it/s, loss=0.2755, task=0.2742]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 43.05it/s]
#
# Train Loss: 0.4401
# Valid F1: 0.8231
# Valid Precision: 0.8707
# Valid Recall: 0.7805
#
# No improvement (1/5)
#
# ==================================================
# Epoch 19/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.26it/s, loss=0.5005, task=0.4993]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 41.05it/s]
#
# Train Loss: 0.4217
# Valid F1: 0.8253
# Valid Precision: 0.8712
# Valid Recall: 0.7841
#
# No improvement (2/5)
#
# ==================================================
# Epoch 20/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.16it/s, loss=0.1633, task=0.1621]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 41.06it/s]
#
# Train Loss: 0.4103
# Valid F1: 0.8236
# Valid Precision: 0.8716
# Valid Recall: 0.7805
#
# No improvement (3/5)
#
# ==================================================
# Epoch 21/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 20.96it/s, loss=0.2004, task=0.1992]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 40.59it/s]
#
# Train Loss: 0.3770
# Valid F1: 0.8244
# Valid Precision: 0.8595
# Valid Recall: 0.7920
#
# No improvement (4/5)
#
# ==================================================
# Epoch 22/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.83it/s, loss=0.2342, task=0.2330]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 45.01it/s]
#
# Train Loss: 0.3616
# Valid F1: 0.8257
# Valid Precision: 0.8608
# Valid Recall: 0.7933
#
# No improvement (5/5)
#
# Early stopping triggered after 22 epochs
#
# ==================================================
# Final evaluation on test set...
# ==================================================
# Evaluating: 100% 108/108 [00:01<00:00, 56.81it/s]
#
# Test F1: 0.7306
# Test Precision: 0.7873
# Test Recall: 0.6815
#
# Per-entity F1 scores:
#   LOC: 0.8082
#   MISC: 0.6761
#   ORG: 0.7067
#   PER: 0.6914
#   micro avg: 0.7306
#   macro avg: 0.7206
#   weighted avg: 0.7285
#
# ✓ Training complete! Results saved to results/activation_gelu

# %%
# !ls -la
# !ls -la results/
# !ls -la visualizations/
# Out:
# total 172
# drwxr-xr-x 14 root root  4096 Jan 15 09:09 .
# drwxr-xr-x  1 root root  4096 Jan 15 09:04 ..
# drwxr-xr-x  2 root root  4096 Jan 15 09:04 comparison_plots
# drwxr-xr-x  2 root root  4096 Jan 15 09:04 config
# drwxr-xr-x  3 root root  4096 Jan 15 09:09 data
# drwxr-xr-x  2 root root  4096 Jan 15 09:04 docs
# -rw-r--r--  1 root root  2319 Jan 15 09:04 EXECUTION_SUMMARY.md
# drwxr-xr-x  3 root root  4096 Jan 15 09:04 experiment_results
# -rwxr-xr-x  1 root root  9748 Jan 15 09:04 generate_heatmaps.py
# drwxr-xr-x  8 root root  4096 Jan 15 09:04 .git
# -rw-r--r--  1 root root   474 Jan 15 09:04 .gitignore
# -rw-r--r--  1 root root 10716 Jan 15 09:04 IMPLEMENTATION_PLAN.md
# -rw-r--r--  1 root root  2107 Jan 15 09:04 monitor_experiments.py
# drwxr-xr-x  4 root root  4096 Jan 15 09:04 notebooks
# -rw-r--r--  1 root root  5397 Jan 15 09:04 README.md
# -rw-r--r--  1 root root   332 Jan 15 09:04 requirements.txt
# drwxr-xr-x  3 root root  4096 Jan 15 09:10 results
# -rwxr-xr-x  1 root root 11430 Jan 15 09:04 run_all_experiments_cpu.py
# -rwxr-xr-x  1 root root  5643 Jan 15 09:04 run_experiments.sh
# drwxr-xr-x  3 root root  4096 Jan 15 09:09 runs
# drwxr-xr-x  2 root root  4096 Jan 15 09:04 scripts
# drwxr-xr-x  8 root root  4096 Jan 15 09:09 src
# -rw-r--r--  1 root root 24893 Jan 15 09:04 starting.md
# -rw-r--r--  1 root root  1761 Jan 15 09:04 STATUS_UPDATE.md
# -rw-r--r--  1 root root  2099 Jan 15 09:04 TUNING_QUICKSTART.md
# drwxr-xr-x  2 root root  4096 Jan 15 09:09 visualizations
# -rw-r--r--  1 root root 11417 Jan 15 09:04 WALKTHROUGH.md
# total 12
# drwxr-xr-x  3 root root 4096 Jan 15 09:10 .
# drwxr-xr-x 14 root root 4096 Jan 15 09:09 ..
# drwxr-xr-x  2 root root 4096 Jan 15 09:18 activation_gelu
# total 8
# drwxr-xr-x  2 root root 4096 Jan 15 09:09 .
# drwxr-xr-x 14 root root 4096 Jan 15 09:09 ..

# %%
import os
print("Current directory:", os.getcwd())
print("\nDirectories created:")
print("- results/ exists:", os.path.exists('results'))
print("- visualizations/ exists:", os.path.exists('visualizations'))

# List contents
if os.path.exists('results'):
    print("\nContents of results/:")
    print(os.listdir('results'))
# Out:
# Current directory: /content
#
# Directories created:
# - results/ exists: True
# - visualizations/ exists: True
#
# Contents of results/:
# []

# %% [markdown]
# ### Experiment 2: Swish Activation
# **Hypothesis**: Swish activation provides smooth non-linearity

# %%
# !python src/train.py \
  --config config/tuning_experiments.yaml \
  --experiment activation_swish \
  --save_dir results/activation_swish

# %% [markdown]
# ### Experiment 3: Mish Activation
# **Hypothesis**: Mish activation with smooth gradients helps training

# %%
# !python src/train.py \
  --config config/tuning_experiments.yaml \
  --experiment activation_mish \
  --save_dir results/activation_mish

# %% [markdown]
# ### Experiment 4: More Receptors (256)
# **Hypothesis**: More receptors increase model capacity and specialization

# %%
# !python src/train.py \
  --config config/tuning_experiments.yaml \
  --experiment more_receptors \
  --save_dir results/more_receptors
# Out:
# 2026-01-15 09:23:32.158659: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768469012.178234    6742 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768469012.184160    6742 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1768469012.199083    6742 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768469012.199110    6742 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768469012.199119    6742 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768469012.199124    6742 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-01-15 09:23:32.203696: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Using device: cuda
#
# ==================================================
# Loading data...
# ==================================================
# Loading training data...
# Loading validation data...
# Loading test data...
# Train: 14041 sentences
# Valid: 3250 sentences
# Test: 3453 sentences
#
# Building vocabularies...
# Vocabulary size: 11984
# Number of labels: 8
# Labels: ['B-LOC', 'B-MISC', 'B-ORG', 'I-LOC', 'I-MISC', 'I-ORG', 'I-PER', 'O']
#
# Loading GloVe embeddings from ./data/glove.6B.300d.txt...
# Loading GloVe embeddings from ./data/glove.6B.300d.txt...
# Found embeddings for 6544/11984 words (54.6%)
#
# ==================================================
# Creating olfactory model...
# ==================================================
# Total parameters: 4,352,280
# Trainable parameters: 4,352,280
#
# ==================================================
# Starting training...
# ==================================================
#
# ==================================================
# Epoch 1/50
# ==================================================
# Training: 100% 439/439 [00:22<00:00, 19.73it/s, loss=2.4840, task=2.4823]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 50.67it/s]
#
# Train Loss: 4.7169
# Valid F1: 0.5528
# Valid Precision: 0.5898
# Valid Recall: 0.5202
#
# ✓ Saved new best model (F1: 0.5528)
#
# ==================================================
# Epoch 2/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.66it/s, loss=1.6128, task=1.6114]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 52.57it/s]
#
# Train Loss: 2.1413
# Valid F1: 0.7143
# Valid Precision: 0.7723
# Valid Recall: 0.6644
#
# ✓ Saved new best model (F1: 0.7143)
#
# ==================================================
# Epoch 3/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.79it/s, loss=1.7090, task=1.7077]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 52.47it/s]
#
# Train Loss: 1.3847
# Valid F1: 0.7861
# Valid Precision: 0.8514
# Valid Recall: 0.7301
#
# ✓ Saved new best model (F1: 0.7861)
#
# ==================================================
# Epoch 4/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.64it/s, loss=0.8669, task=0.8656]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 51.84it/s]
#
# Train Loss: 1.0417
# Valid F1: 0.8093
# Valid Precision: 0.8659
# Valid Recall: 0.7597
#
# ✓ Saved new best model (F1: 0.8093)
#
# ==================================================
# Epoch 5/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.79it/s, loss=0.7255, task=0.7243]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 53.07it/s]
#
# Train Loss: 0.8745
# Valid F1: 0.8081
# Valid Precision: 0.8549
# Valid Recall: 0.7662
#
# No improvement (1/5)
#
# ==================================================
# Epoch 6/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.65it/s, loss=0.7833, task=0.7821]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 51.98it/s]
#
# Train Loss: 0.7652
# Valid F1: 0.8245
# Valid Precision: 0.8665
# Valid Recall: 0.7864
#
# ✓ Saved new best model (F1: 0.8245)
#
# ==================================================
# Epoch 7/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.83it/s, loss=0.7266, task=0.7255]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 52.63it/s]
#
# Train Loss: 0.7013
# Valid F1: 0.8334
# Valid Precision: 0.9018
# Valid Recall: 0.7747
#
# ✓ Saved new best model (F1: 0.8334)
#
# ==================================================
# Epoch 8/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.01it/s, loss=0.3232, task=0.3221]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 51.31it/s]
#
# Train Loss: 0.6209
# Valid F1: 0.8226
# Valid Precision: 0.8640
# Valid Recall: 0.7849
#
# No improvement (1/5)
#
# ==================================================
# Epoch 9/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 20.99it/s, loss=0.6204, task=0.6193]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 52.95it/s]
#
# Train Loss: 0.5806
# Valid F1: 0.8303
# Valid Precision: 0.8573
# Valid Recall: 0.8049
#
# No improvement (2/5)
#
# ==================================================
# Epoch 10/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.22it/s, loss=0.0991, task=0.0980]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 53.62it/s]
#
# Train Loss: 0.5332
# Valid F1: 0.8410
# Valid Precision: 0.8863
# Valid Recall: 0.8001
#
# ✓ Saved new best model (F1: 0.8410)
#
# ==================================================
# Epoch 11/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.15it/s, loss=0.5799, task=0.5788]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 49.70it/s]
#
# Train Loss: 0.4957
# Valid F1: 0.8424
# Valid Precision: 0.8818
# Valid Recall: 0.8063
#
# ✓ Saved new best model (F1: 0.8424)
#
# ==================================================
# Epoch 12/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.20it/s, loss=0.6812, task=0.6801]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 47.01it/s]
#
# Train Loss: 0.4614
# Valid F1: 0.8398
# Valid Precision: 0.8662
# Valid Recall: 0.8149
#
# No improvement (1/5)
#
# ==================================================
# Epoch 13/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.53it/s, loss=0.1305, task=0.1294]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 46.80it/s]
#
# Train Loss: 0.4306
# Valid F1: 0.8233
# Valid Precision: 0.8600
# Valid Recall: 0.7896
#
# No improvement (2/5)
#
# ==================================================
# Epoch 14/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.38it/s, loss=0.7305, task=0.7295]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 45.83it/s]
#
# Train Loss: 0.4026
# Valid F1: 0.8276
# Valid Precision: 0.8474
# Valid Recall: 0.8087
#
# No improvement (3/5)
#
# ==================================================
# Epoch 15/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.30it/s, loss=0.4574, task=0.4563]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 44.51it/s]
#
# Train Loss: 0.3362
# Valid F1: 0.8377
# Valid Precision: 0.8766
# Valid Recall: 0.8021
#
# No improvement (4/5)
#
# ==================================================
# Epoch 16/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.43it/s, loss=0.3298, task=0.3288]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 44.40it/s]
#
# Train Loss: 0.3009
# Valid F1: 0.8301
# Valid Precision: 0.8420
# Valid Recall: 0.8186
#
# No improvement (5/5)
#
# Early stopping triggered after 16 epochs
#
# ==================================================
# Final evaluation on test set...
# ==================================================
# Evaluating: 100% 108/108 [00:01<00:00, 57.28it/s]
#
# Test F1: 0.7528
# Test Precision: 0.7998
# Test Recall: 0.7110
#
# Per-entity F1 scores:
#   LOC: 0.8429
#   MISC: 0.6747
#   ORG: 0.7013
#   PER: 0.7462
#   micro avg: 0.7528
#   macro avg: 0.7413
#   weighted avg: 0.7527
#
# ✓ Training complete! Results saved to results/more_receptors

# %% [markdown]
# ### Experiment 4.1: More Glomeruli

# %%
# !python src/train.py \
  --config config/tuning_experiments.yaml \
  --experiment more_glomeruli \
  --save_dir results/more_glomeruli

# %% [markdown]
# ### Experiment 5: Fewer Receptors (64)
# **Hypothesis**: Fewer receptors test if 128 is optimal or over-parameterized

# %%
# !python src/train.py \
  --config config/tuning_experiments.yaml \
  --experiment fewer_receptors \
  --save_dir results/fewer_receptors

# %% [markdown]
# ### Experiment 6: Strong Diversity Loss
# **Hypothesis**: Stronger diversity regularization (5x) improves receptor specialization

# %%
# !python src/train.py \
  --config config/tuning_experiments.yaml \
  --experiment strong_diversity \
  --save_dir results/strong_diversity
# Out:
# 2026-01-15 09:30:39.152136: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768469439.172066    8484 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768469439.177973    8484 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1768469439.193488    8484 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768469439.193515    8484 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768469439.193519    8484 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768469439.193524    8484 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-01-15 09:30:39.198509: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Using device: cuda
#
# ==================================================
# Loading data...
# ==================================================
# Loading training data...
# Loading validation data...
# Loading test data...
# Train: 14041 sentences
# Valid: 3250 sentences
# Test: 3453 sentences
#
# Building vocabularies...
# Vocabulary size: 11984
# Number of labels: 8
# Labels: ['B-LOC', 'B-MISC', 'B-ORG', 'I-LOC', 'I-MISC', 'I-ORG', 'I-PER', 'O']
#
# Loading GloVe embeddings from ./data/glove.6B.300d.txt...
# Loading GloVe embeddings from ./data/glove.6B.300d.txt...
# Found embeddings for 6544/11984 words (54.6%)
#
# ==================================================
# Creating olfactory model...
# ==================================================
# Total parameters: 4,235,928
# Trainable parameters: 4,235,928
#
# ==================================================
# Starting training...
# ==================================================
#
# ==================================================
# Epoch 1/50
# ==================================================
# Training: 100% 439/439 [00:22<00:00, 19.76it/s, loss=1.7168, task=1.7092]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 50.47it/s]
#
# Train Loss: 4.4161
# Valid F1: 0.6416
# Valid Precision: 0.7166
# Valid Recall: 0.5808
#
# ✓ Saved new best model (F1: 0.6416)
#
# ==================================================
# Epoch 2/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.58it/s, loss=2.4516, task=2.4451]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 52.83it/s]
#
# Train Loss: 2.1111
# Valid F1: 0.7230
# Valid Precision: 0.7847
# Valid Recall: 0.6703
#
# ✓ Saved new best model (F1: 0.7230)
#
# ==================================================
# Epoch 3/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.67it/s, loss=2.0289, task=2.0227]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 52.70it/s]
#
# Train Loss: 1.6311
# Valid F1: 0.7442
# Valid Precision: 0.7919
# Valid Recall: 0.7020
#
# ✓ Saved new best model (F1: 0.7442)
#
# ==================================================
# Epoch 4/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.75it/s, loss=1.7520, task=1.7459]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 52.35it/s]
#
# Train Loss: 1.3221
# Valid F1: 0.7656
# Valid Precision: 0.8128
# Valid Recall: 0.7235
#
# ✓ Saved new best model (F1: 0.7656)
#
# ==================================================
# Epoch 5/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.81it/s, loss=0.9487, task=0.9429]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 52.32it/s]
#
# Train Loss: 1.1229
# Valid F1: 0.7853
# Valid Precision: 0.8458
# Valid Recall: 0.7329
#
# ✓ Saved new best model (F1: 0.7853)
#
# ==================================================
# Epoch 6/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.86it/s, loss=0.8329, task=0.8275]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 52.40it/s]
#
# Train Loss: 1.0358
# Valid F1: 0.7950
# Valid Precision: 0.8595
# Valid Recall: 0.7395
#
# ✓ Saved new best model (F1: 0.7950)
#
# ==================================================
# Epoch 7/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.76it/s, loss=0.2344, task=0.2293]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 52.96it/s]
#
# Train Loss: 0.9325
# Valid F1: 0.7934
# Valid Precision: 0.8542
# Valid Recall: 0.7407
#
# No improvement (1/5)
#
# ==================================================
# Epoch 8/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.81it/s, loss=0.1551, task=0.1500]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 45.61it/s]
#
# Train Loss: 0.8704
# Valid F1: 0.8049
# Valid Precision: 0.8657
# Valid Recall: 0.7521
#
# ✓ Saved new best model (F1: 0.8049)
#
# ==================================================
# Epoch 9/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 20.92it/s, loss=0.9345, task=0.9295]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 51.23it/s]
#
# Train Loss: 0.8144
# Valid F1: 0.8041
# Valid Precision: 0.8583
# Valid Recall: 0.7563
#
# No improvement (1/5)
#
# ==================================================
# Epoch 10/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.07it/s, loss=0.6920, task=0.6872]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 52.31it/s]
#
# Train Loss: 0.7698
# Valid F1: 0.8062
# Valid Precision: 0.8594
# Valid Recall: 0.7592
#
# ✓ Saved new best model (F1: 0.8062)
#
# ==================================================
# Epoch 11/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 20.91it/s, loss=1.2516, task=1.2468]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 52.73it/s]
#
# Train Loss: 0.7285
# Valid F1: 0.8004
# Valid Precision: 0.8407
# Valid Recall: 0.7637
#
# No improvement (1/5)
#
# ==================================================
# Epoch 12/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 20.96it/s, loss=0.3108, task=0.3061]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 52.62it/s]
#
# Train Loss: 0.6916
# Valid F1: 0.8090
# Valid Precision: 0.8595
# Valid Recall: 0.7641
#
# ✓ Saved new best model (F1: 0.8090)
#
# ==================================================
# Epoch 13/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.16it/s, loss=0.3426, task=0.3380]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 52.86it/s]
#
# Train Loss: 0.6596
# Valid F1: 0.8115
# Valid Precision: 0.8673
# Valid Recall: 0.7624
#
# ✓ Saved new best model (F1: 0.8115)
#
# ==================================================
# Epoch 14/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 20.96it/s, loss=0.5414, task=0.5368]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 50.07it/s]
#
# Train Loss: 0.6265
# Valid F1: 0.7974
# Valid Precision: 0.8367
# Valid Recall: 0.7615
#
# No improvement (1/5)
#
# ==================================================
# Epoch 15/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.25it/s, loss=0.2713, task=0.2667]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 49.46it/s]
#
# Train Loss: 0.6004
# Valid F1: 0.8046
# Valid Precision: 0.8581
# Valid Recall: 0.7573
#
# No improvement (2/5)
#
# ==================================================
# Epoch 16/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.38it/s, loss=0.2510, task=0.2466]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 48.37it/s]
#
# Train Loss: 0.5797
# Valid F1: 0.8119
# Valid Precision: 0.8536
# Valid Recall: 0.7742
#
# ✓ Saved new best model (F1: 0.8119)
#
# ==================================================
# Epoch 17/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.49it/s, loss=0.8031, task=0.7987]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 46.94it/s]
#
# Train Loss: 0.5408
# Valid F1: 0.8151
# Valid Precision: 0.8512
# Valid Recall: 0.7819
#
# ✓ Saved new best model (F1: 0.8151)
#
# ==================================================
# Epoch 18/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.46it/s, loss=0.3373, task=0.3330]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 45.29it/s]
#
# Train Loss: 0.5353
# Valid F1: 0.7970
# Valid Precision: 0.8229
# Valid Recall: 0.7726
#
# No improvement (1/5)
#
# ==================================================
# Epoch 19/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.55it/s, loss=0.7852, task=0.7809]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 45.12it/s]
#
# Train Loss: 0.5129
# Valid F1: 0.8119
# Valid Precision: 0.8483
# Valid Recall: 0.7785
#
# No improvement (2/5)
#
# ==================================================
# Epoch 20/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.49it/s, loss=0.1856, task=0.1813]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 44.95it/s]
#
# Train Loss: 0.4926
# Valid F1: 0.8069
# Valid Precision: 0.8460
# Valid Recall: 0.7713
#
# No improvement (3/5)
#
# ==================================================
# Epoch 21/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.43it/s, loss=0.5873, task=0.5831]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 44.84it/s]
#
# Train Loss: 0.4298
# Valid F1: 0.8137
# Valid Precision: 0.8581
# Valid Recall: 0.7736
#
# No improvement (4/5)
#
# ==================================================
# Epoch 22/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.41it/s, loss=0.1685, task=0.1644]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 44.12it/s]
#
# Train Loss: 0.4025
# Valid F1: 0.8163
# Valid Precision: 0.8451
# Valid Recall: 0.7895
#
# ✓ Saved new best model (F1: 0.8163)
#
# ==================================================
# Epoch 23/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.45it/s, loss=0.4593, task=0.4551]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 43.11it/s]
#
# Train Loss: 0.3866
# Valid F1: 0.8167
# Valid Precision: 0.8578
# Valid Recall: 0.7794
#
# ✓ Saved new best model (F1: 0.8167)
#
# ==================================================
# Epoch 24/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.61it/s, loss=0.2162, task=0.2121]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 42.71it/s]
#
# Train Loss: 0.3728
# Valid F1: 0.8176
# Valid Precision: 0.8518
# Valid Recall: 0.7861
#
# ✓ Saved new best model (F1: 0.8176)
#
# ==================================================
# Epoch 25/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.42it/s, loss=0.6772, task=0.6731]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 41.53it/s]
#
# Train Loss: 0.3585
# Valid F1: 0.8085
# Valid Precision: 0.8431
# Valid Recall: 0.7767
#
# No improvement (1/5)
#
# ==================================================
# Epoch 26/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.37it/s, loss=0.3836, task=0.3795]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 41.38it/s]
#
# Train Loss: 0.3519
# Valid F1: 0.8182
# Valid Precision: 0.8537
# Valid Recall: 0.7856
#
# ✓ Saved new best model (F1: 0.8182)
#
# ==================================================
# Epoch 27/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.34it/s, loss=0.2115, task=0.2074]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 40.49it/s]
#
# Train Loss: 0.3471
# Valid F1: 0.8146
# Valid Precision: 0.8416
# Valid Recall: 0.7893
#
# No improvement (1/5)
#
# ==================================================
# Epoch 28/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.50it/s, loss=0.1413, task=0.1373]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 41.64it/s]
#
# Train Loss: 0.3300
# Valid F1: 0.8223
# Valid Precision: 0.8547
# Valid Recall: 0.7922
#
# ✓ Saved new best model (F1: 0.8223)
#
# ==================================================
# Epoch 29/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.43it/s, loss=0.6619, task=0.6579]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 41.20it/s]
#
# Train Loss: 0.3151
# Valid F1: 0.8135
# Valid Precision: 0.8372
# Valid Recall: 0.7911
#
# No improvement (1/5)
#
# ==================================================
# Epoch 30/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.41it/s, loss=0.5041, task=0.5001]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 41.41it/s]
#
# Train Loss: 0.3111
# Valid F1: 0.8178
# Valid Precision: 0.8445
# Valid Recall: 0.7927
#
# No improvement (2/5)
#
# ==================================================
# Epoch 31/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.48it/s, loss=0.2282, task=0.2242]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 40.94it/s]
#
# Train Loss: 0.3099
# Valid F1: 0.8140
# Valid Precision: 0.8532
# Valid Recall: 0.7784
#
# No improvement (3/5)
#
# ==================================================
# Epoch 32/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.45it/s, loss=0.1495, task=0.1455]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 41.14it/s]
#
# Train Loss: 0.2773
# Valid F1: 0.8169
# Valid Precision: 0.8463
# Valid Recall: 0.7895
#
# No improvement (4/5)
#
# ==================================================
# Epoch 33/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.57it/s, loss=0.0555, task=0.0516]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 41.40it/s]
#
# Train Loss: 0.2726
# Valid F1: 0.8162
# Valid Precision: 0.8546
# Valid Recall: 0.7812
#
# No improvement (5/5)
#
# Early stopping triggered after 33 epochs
#
# ==================================================
# Final evaluation on test set...
# ==================================================
# Evaluating: 100% 108/108 [00:01<00:00, 56.52it/s]
#
# Test F1: 0.7169
# Test Precision: 0.7481
# Test Recall: 0.6882
#
# Per-entity F1 scores:
#   LOC: 0.8235
#   MISC: 0.6016
#   ORG: 0.6569
#   PER: 0.7182
#   micro avg: 0.7169
#   macro avg: 0.7000
#   weighted avg: 0.7168
#
# ✓ Training complete! Results saved to results/strong_diversity

# %% [markdown]
# ### Experiment 7: Very Strong Diversity Loss
# **Hypothesis**: Very strong diversity regularization (10x) - testing the limit

# %%
# !python src/train.py \
  --config config/tuning_experiments.yaml \
  --experiment very_strong_diversity \
  --save_dir results/very_strong_diversity

# %% [markdown]
# ### Experiment 8: GELU + More Receptors
# **Hypothesis**: Combining best activation (GELU) with more capacity (256 receptors)

# %%
# !python src/train.py \
  --config config/tuning_experiments.yaml \
  --experiment gelu_more_receptors \
  --save_dir results/gelu_more_receptors
# Out:
# 2026-01-15 09:44:27.336003: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768470267.355531   11848 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768470267.361384   11848 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1768470267.375969   11848 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768470267.375993   11848 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768470267.375997   11848 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768470267.376000   11848 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-01-15 09:44:27.380394: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Using device: cuda
#
# ==================================================
# Loading data...
# ==================================================
# Loading training data...
# Loading validation data...
# Loading test data...
# Train: 14041 sentences
# Valid: 3250 sentences
# Test: 3453 sentences
#
# Building vocabularies...
# Vocabulary size: 11984
# Number of labels: 8
# Labels: ['B-LOC', 'B-MISC', 'B-ORG', 'I-LOC', 'I-MISC', 'I-ORG', 'I-PER', 'O']
#
# Loading GloVe embeddings from ./data/glove.6B.300d.txt...
# Loading GloVe embeddings from ./data/glove.6B.300d.txt...
# Found embeddings for 6544/11984 words (54.6%)
#
# ==================================================
# Creating olfactory model...
# ==================================================
# Total parameters: 4,352,280
# Trainable parameters: 4,352,280
#
# ==================================================
# Starting training...
# ==================================================
#
# ==================================================
# Epoch 1/50
# ==================================================
# Training: 100% 439/439 [00:22<00:00, 19.86it/s, loss=2.3523, task=2.3419]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 49.62it/s]
#
# Train Loss: 4.9349
# Valid F1: 0.6138
# Valid Precision: 0.6786
# Valid Recall: 0.5602
#
# ✓ Saved new best model (F1: 0.6138)
#
# ==================================================
# Epoch 2/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.65it/s, loss=1.7248, task=1.7162]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 51.14it/s]
#
# Train Loss: 2.0259
# Valid F1: 0.7663
# Valid Precision: 0.8272
# Valid Recall: 0.7137
#
# ✓ Saved new best model (F1: 0.7663)
#
# ==================================================
# Epoch 3/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.60it/s, loss=1.6292, task=1.6218]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 51.93it/s]
#
# Train Loss: 1.3676
# Valid F1: 0.7963
# Valid Precision: 0.8656
# Valid Recall: 0.7373
#
# ✓ Saved new best model (F1: 0.7963)
#
# ==================================================
# Epoch 4/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.55it/s, loss=0.9923, task=0.9856]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 51.67it/s]
#
# Train Loss: 1.1016
# Valid F1: 0.8091
# Valid Precision: 0.8690
# Valid Recall: 0.7570
#
# ✓ Saved new best model (F1: 0.8091)
#
# ==================================================
# Epoch 5/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.57it/s, loss=0.5833, task=0.5770]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 51.37it/s]
#
# Train Loss: 0.9506
# Valid F1: 0.8118
# Valid Precision: 0.8630
# Valid Recall: 0.7664
#
# ✓ Saved new best model (F1: 0.8118)
#
# ==================================================
# Epoch 6/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.71it/s, loss=0.9150, task=0.9091]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 51.29it/s]
#
# Train Loss: 0.8231
# Valid F1: 0.8240
# Valid Precision: 0.8596
# Valid Recall: 0.7913
#
# ✓ Saved new best model (F1: 0.8240)
#
# ==================================================
# Epoch 7/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.60it/s, loss=0.7004, task=0.6950]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 51.30it/s]
#
# Train Loss: 0.7499
# Valid F1: 0.8260
# Valid Precision: 0.8793
# Valid Recall: 0.7787
#
# ✓ Saved new best model (F1: 0.8260)
#
# ==================================================
# Epoch 8/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.71it/s, loss=0.2992, task=0.2940]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 44.96it/s]
#
# Train Loss: 0.6666
# Valid F1: 0.8205
# Valid Precision: 0.8530
# Valid Recall: 0.7903
#
# No improvement (1/5)
#
# ==================================================
# Epoch 9/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 20.91it/s, loss=0.9214, task=0.9162]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 47.02it/s]
#
# Train Loss: 0.6187
# Valid F1: 0.8256
# Valid Precision: 0.8625
# Valid Recall: 0.7917
#
# No improvement (2/5)
#
# ==================================================
# Epoch 10/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.12it/s, loss=0.1072, task=0.1021]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 43.64it/s]
#
# Train Loss: 0.5666
# Valid F1: 0.8260
# Valid Precision: 0.8703
# Valid Recall: 0.7859
#
# ✓ Saved new best model (F1: 0.8260)
#
# ==================================================
# Epoch 11/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.19it/s, loss=1.2198, task=1.2148]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 40.10it/s]
#
# Train Loss: 0.4793
# Valid F1: 0.8459
# Valid Precision: 0.8933
# Valid Recall: 0.8033
#
# ✓ Saved new best model (F1: 0.8459)
#
# ==================================================
# Epoch 12/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.23it/s, loss=0.8223, task=0.8175]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 40.74it/s]
#
# Train Loss: 0.4355
# Valid F1: 0.8427
# Valid Precision: 0.8691
# Valid Recall: 0.8179
#
# No improvement (1/5)
#
# ==================================================
# Epoch 13/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.27it/s, loss=0.0997, task=0.0949]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 40.58it/s]
#
# Train Loss: 0.4121
# Valid F1: 0.8413
# Valid Precision: 0.8768
# Valid Recall: 0.8085
#
# No improvement (2/5)
#
# ==================================================
# Epoch 14/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.02it/s, loss=0.6313, task=0.6266]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 42.80it/s]
#
# Train Loss: 0.3835
# Valid F1: 0.8436
# Valid Precision: 0.8806
# Valid Recall: 0.8095
#
# No improvement (3/5)
#
# ==================================================
# Epoch 15/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.89it/s, loss=0.5900, task=0.5853]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 44.94it/s]
#
# Train Loss: 0.3437
# Valid F1: 0.8403
# Valid Precision: 0.8651
# Valid Recall: 0.8169
#
# No improvement (4/5)
#
# ==================================================
# Epoch 16/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 20.93it/s, loss=0.3058, task=0.3011]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 45.99it/s]
#
# Train Loss: 0.3260
# Valid F1: 0.8367
# Valid Precision: 0.8549
# Valid Recall: 0.8193
#
# No improvement (5/5)
#
# Early stopping triggered after 16 epochs
#
# ==================================================
# Final evaluation on test set...
# ==================================================
# Evaluating: 100% 108/108 [00:01<00:00, 56.43it/s]
#
# Test F1: 0.7613
# Test Precision: 0.8171
# Test Recall: 0.7126
#
# Per-entity F1 scores:
#   LOC: 0.8321
#   MISC: 0.6803
#   ORG: 0.7176
#   PER: 0.7672
#   micro avg: 0.7613
#   macro avg: 0.7493
#   weighted avg: 0.7610
#
# ✓ Training complete! Results saved to results/gelu_more_receptors

# %% [markdown]
# ### Experiment 9: Minimal GELU (No Glomeruli)
# **Hypothesis**: Glomeruli layer might not be necessary with good activation

# %%
# !python src/train.py \
  --config config/tuning_experiments.yaml \
  --experiment minimal_gelu \
  --save_dir results/minimal_gelu

# %% [markdown]
# ### Experiment 10: Baseline BiLSTM-CRF
# **Baseline**: Standard BiLSTM-CRF without olfactory components

# %%
# !python src/train.py \
  --config config/experiments.yaml \
  --experiment baseline \
  --save_dir results/baseline
# Out:
# 2026-01-15 10:25:46.815824: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768472746.836493   21917 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768472746.843205   21917 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1768472746.859764   21917 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768472746.859792   21917 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768472746.859807   21917 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768472746.859810   21917 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-01-15 10:25:46.864471: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Using device: cuda
#
# ==================================================
# Loading data...
# ==================================================
# Loading training data...
# Loading validation data...
# Loading test data...
# Train: 14041 sentences
# Valid: 3250 sentences
# Test: 3453 sentences
#
# Building vocabularies...
# Vocabulary size: 11984
# Number of labels: 8
# Labels: ['B-LOC', 'B-MISC', 'B-ORG', 'I-LOC', 'I-MISC', 'I-ORG', 'I-PER', 'O']
#
# Loading GloVe embeddings from ./data/glove.6B.300d.txt...
# Loading GloVe embeddings from ./data/glove.6B.300d.txt...
# Found embeddings for 6544/11984 words (54.6%)
#
# ==================================================
# Creating baseline model...
# ==================================================
# Total parameters: 4,742,168
# Trainable parameters: 4,742,168
#
# ==================================================
# Starting training...
# ==================================================
#
# ==================================================
# Epoch 1/10
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.82it/s, loss=1.4222, task=1.4222]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 40.36it/s]
#
# Train Loss: 4.4558
# Valid F1: 0.7439
# Valid Precision: 0.7627
# Valid Recall: 0.7260
#
# ✓ Saved new best model (F1: 0.7439)
#
# ==================================================
# Epoch 2/10
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.63it/s, loss=0.9428, task=0.9428]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 41.06it/s]
#
# Train Loss: 1.2757
# Valid F1: 0.8239
# Valid Precision: 0.8580
# Valid Recall: 0.7923
#
# ✓ Saved new best model (F1: 0.8239)
#
# ==================================================
# Epoch 3/10
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.77it/s, loss=0.4746, task=0.4746]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 41.63it/s]
#
# Train Loss: 0.7424
# Valid F1: 0.8341
# Valid Precision: 0.8697
# Valid Recall: 0.8012
#
# ✓ Saved new best model (F1: 0.8341)
#
# ==================================================
# Epoch 4/10
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.79it/s, loss=0.4915, task=0.4915]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 42.88it/s]
#
# Train Loss: 0.5309
# Valid F1: 0.8414
# Valid Precision: 0.8758
# Valid Recall: 0.8095
#
# ✓ Saved new best model (F1: 0.8414)
#
# ==================================================
# Epoch 5/10
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.79it/s, loss=0.4342, task=0.4342]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 45.63it/s]
#
# Train Loss: 0.3949
# Valid F1: 0.8451
# Valid Precision: 0.8647
# Valid Recall: 0.8263
#
# ✓ Saved new best model (F1: 0.8451)
#
# ==================================================
# Epoch 6/10
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.85it/s, loss=0.3807, task=0.3807]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 46.49it/s]
#
# Train Loss: 0.2909
# Valid F1: 0.8432
# Valid Precision: 0.8804
# Valid Recall: 0.8090
#
# No improvement (1/5)
#
# ==================================================
# Epoch 7/10
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.90it/s, loss=0.0278, task=0.0278]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 49.05it/s]
#
# Train Loss: 0.2184
# Valid F1: 0.8536
# Valid Precision: 0.8773
# Valid Recall: 0.8312
#
# ✓ Saved new best model (F1: 0.8536)
#
# ==================================================
# Epoch 8/10
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.83it/s, loss=0.5214, task=0.5214]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 42.17it/s]
#
# Train Loss: 0.1891
# Valid F1: 0.8469
# Valid Precision: 0.8575
# Valid Recall: 0.8366
#
# No improvement (1/5)
#
# ==================================================
# Epoch 9/10
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.93it/s, loss=0.1199, task=0.1199]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 49.75it/s]
#
# Train Loss: 0.1416
# Valid F1: 0.8526
# Valid Precision: 0.8849
# Valid Recall: 0.8226
#
# No improvement (2/5)
#
# ==================================================
# Epoch 10/10
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.90it/s, loss=0.1378, task=0.1378]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 53.48it/s]
#
# Train Loss: 0.1189
# Valid F1: 0.8535
# Valid Precision: 0.8730
# Valid Recall: 0.8349
#
# No improvement (3/5)
#
# ==================================================
# Final evaluation on test set...
# ==================================================
# Evaluating: 100% 108/108 [00:02<00:00, 50.69it/s]
#
# Test F1: 0.7650
# Test Precision: 0.7882
# Test Recall: 0.7431
#
# Per-entity F1 scores:
#   LOC: 0.8547
#   MISC: 0.6809
#   ORG: 0.7247
#   PER: 0.7514
#   micro avg: 0.7650
#   macro avg: 0.7529
#   weighted avg: 0.7653
#
# ✓ Training complete! Results saved to results/baseline

# %% [markdown]
# ### Experiment 11: Olfactory Full
# **Full Model**: Complete olfactory-inspired architecture with all components

# %%
# !python src/train.py \
  --config config/experiments.yaml \
  --experiment olfactory_full \
  --save_dir results/olfactory_full
# Out:
# 2026-01-15 10:30:04.974789: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768473004.994182   22975 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768473005.000054   22975 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1768473005.015569   22975 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768473005.015594   22975 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768473005.015598   22975 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768473005.015601   22975 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-01-15 10:30:05.020065: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Using device: cuda
#
# ==================================================
# Loading data...
# ==================================================
# Loading training data...
# Loading validation data...
# Loading test data...
# Train: 14041 sentences
# Valid: 3250 sentences
# Test: 3453 sentences
#
# Building vocabularies...
# Vocabulary size: 11984
# Number of labels: 8
# Labels: ['B-LOC', 'B-MISC', 'B-ORG', 'I-LOC', 'I-MISC', 'I-ORG', 'I-PER', 'O']
#
# Loading GloVe embeddings from ./data/glove.6B.300d.txt...
# Loading GloVe embeddings from ./data/glove.6B.300d.txt...
# Found embeddings for 6544/11984 words (54.6%)
#
# ==================================================
# Creating olfactory model...
# ==================================================
# Total parameters: 4,235,928
# Trainable parameters: 4,235,928
#
# ==================================================
# Starting training...
# ==================================================
#
# ==================================================
# Epoch 1/50
# ==================================================
# Training: 100% 439/439 [00:22<00:00, 19.77it/s, loss=1.7314, task=1.7297]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 49.67it/s]
#
# Train Loss: 4.4118
# Valid F1: 0.6379
# Valid Precision: 0.7149
# Valid Recall: 0.5759
#
# ✓ Saved new best model (F1: 0.6379)
#
# ==================================================
# Epoch 2/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.80it/s, loss=2.4520, task=2.4506]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 47.24it/s]
#
# Train Loss: 2.1119
# Valid F1: 0.7201
# Valid Precision: 0.7802
# Valid Recall: 0.6686
#
# ✓ Saved new best model (F1: 0.7201)
#
# ==================================================
# Epoch 3/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.14it/s, loss=1.9698, task=1.9684]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 42.70it/s]
#
# Train Loss: 1.6223
# Valid F1: 0.7520
# Valid Precision: 0.8010
# Valid Recall: 0.7087
#
# ✓ Saved new best model (F1: 0.7520)
#
# ==================================================
# Epoch 4/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.20it/s, loss=1.8711, task=1.8697]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 41.15it/s]
#
# Train Loss: 1.3046
# Valid F1: 0.7651
# Valid Precision: 0.8125
# Valid Recall: 0.7228
#
# ✓ Saved new best model (F1: 0.7651)
#
# ==================================================
# Epoch 5/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.14it/s, loss=0.9181, task=0.9168]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 41.70it/s]
#
# Train Loss: 1.1241
# Valid F1: 0.7831
# Valid Precision: 0.8442
# Valid Recall: 0.7302
#
# ✓ Saved new best model (F1: 0.7831)
#
# ==================================================
# Epoch 6/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.15it/s, loss=0.7658, task=0.7646]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 43.15it/s]
#
# Train Loss: 1.0282
# Valid F1: 0.7934
# Valid Precision: 0.8564
# Valid Recall: 0.7390
#
# ✓ Saved new best model (F1: 0.7934)
#
# ==================================================
# Epoch 7/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.90it/s, loss=0.1527, task=0.1515]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 45.55it/s]
#
# Train Loss: 0.9303
# Valid F1: 0.7885
# Valid Precision: 0.8429
# Valid Recall: 0.7407
#
# No improvement (1/5)
#
# ==================================================
# Epoch 8/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.54it/s, loss=0.1655, task=0.1644]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 44.77it/s]
#
# Train Loss: 0.8649
# Valid F1: 0.7984
# Valid Precision: 0.8645
# Valid Recall: 0.7417
#
# ✓ Saved new best model (F1: 0.7984)
#
# ==================================================
# Epoch 9/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.75it/s, loss=0.9905, task=0.9894]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 52.52it/s]
#
# Train Loss: 0.8183
# Valid F1: 0.7978
# Valid Precision: 0.8483
# Valid Recall: 0.7529
#
# No improvement (1/5)
#
# ==================================================
# Epoch 10/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.76it/s, loss=0.6779, task=0.6768]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 51.85it/s]
#
# Train Loss: 0.7644
# Valid F1: 0.8007
# Valid Precision: 0.8542
# Valid Recall: 0.7535
#
# ✓ Saved new best model (F1: 0.8007)
#
# ==================================================
# Epoch 11/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.62it/s, loss=1.0879, task=1.0868]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 52.29it/s]
#
# Train Loss: 0.7297
# Valid F1: 0.8061
# Valid Precision: 0.8374
# Valid Recall: 0.7772
#
# ✓ Saved new best model (F1: 0.8061)
#
# ==================================================
# Epoch 12/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.73it/s, loss=0.2683, task=0.2673]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 52.76it/s]
#
# Train Loss: 0.6906
# Valid F1: 0.8010
# Valid Precision: 0.8499
# Valid Recall: 0.7575
#
# No improvement (1/5)
#
# ==================================================
# Epoch 13/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.81it/s, loss=0.2955, task=0.2944]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 52.60it/s]
#
# Train Loss: 0.6589
# Valid F1: 0.8096
# Valid Precision: 0.8590
# Valid Recall: 0.7656
#
# ✓ Saved new best model (F1: 0.8096)
#
# ==================================================
# Epoch 14/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.65it/s, loss=0.4923, task=0.4912]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 53.20it/s]
#
# Train Loss: 0.6215
# Valid F1: 0.8021
# Valid Precision: 0.8467
# Valid Recall: 0.7620
#
# No improvement (1/5)
#
# ==================================================
# Epoch 15/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.46it/s, loss=0.3645, task=0.3635]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 52.19it/s]
#
# Train Loss: 0.6006
# Valid F1: 0.8074
# Valid Precision: 0.8613
# Valid Recall: 0.7598
#
# No improvement (2/5)
#
# ==================================================
# Epoch 16/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.76it/s, loss=0.3004, task=0.2994]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 52.28it/s]
#
# Train Loss: 0.5652
# Valid F1: 0.8087
# Valid Precision: 0.8399
# Valid Recall: 0.7797
#
# No improvement (3/5)
#
# ==================================================
# Epoch 17/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.81it/s, loss=0.5993, task=0.5983]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 51.53it/s]
#
# Train Loss: 0.4946
# Valid F1: 0.8244
# Valid Precision: 0.8666
# Valid Recall: 0.7861
#
# ✓ Saved new best model (F1: 0.8244)
#
# ==================================================
# Epoch 18/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.77it/s, loss=0.2547, task=0.2537]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 52.39it/s]
#
# Train Loss: 0.4714
# Valid F1: 0.8122
# Valid Precision: 0.8524
# Valid Recall: 0.7757
#
# No improvement (1/5)
#
# ==================================================
# Epoch 19/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.80it/s, loss=0.6066, task=0.6056]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 52.48it/s]
#
# Train Loss: 0.4538
# Valid F1: 0.8101
# Valid Precision: 0.8447
# Valid Recall: 0.7782
#
# No improvement (2/5)
#
# ==================================================
# Epoch 20/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.81it/s, loss=0.1540, task=0.1530]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 52.58it/s]
#
# Train Loss: 0.4349
# Valid F1: 0.8137
# Valid Precision: 0.8481
# Valid Recall: 0.7819
#
# No improvement (3/5)
#
# ==================================================
# Epoch 21/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.59it/s, loss=0.4297, task=0.4286]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 52.53it/s]
#
# Train Loss: 0.3991
# Valid F1: 0.8153
# Valid Precision: 0.8542
# Valid Recall: 0.7799
#
# No improvement (4/5)
#
# ==================================================
# Epoch 22/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.86it/s, loss=0.1380, task=0.1370]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 52.72it/s]
#
# Train Loss: 0.3943
# Valid F1: 0.8164
# Valid Precision: 0.8463
# Valid Recall: 0.7886
#
# No improvement (5/5)
#
# Early stopping triggered after 22 epochs
#
# ==================================================
# Final evaluation on test set...
# ==================================================
# Evaluating: 100% 108/108 [00:01<00:00, 56.16it/s]
#
# Test F1: 0.7256
# Test Precision: 0.7679
# Test Recall: 0.6877
#
# Per-entity F1 scores:
#   LOC: 0.8138
#   MISC: 0.6227
#   ORG: 0.6899
#   PER: 0.7120
#   micro avg: 0.7256
#   macro avg: 0.7096
#   weighted avg: 0.7245
#
# ✓ Training complete! Results saved to results/olfactory_full

# %% [markdown]
# ### Experiment 12: No Glomeruli Ablation
# **Ablation**: Test importance of glomerular layer

# %%
# !python src/train.py \
  --config config/experiments.yaml \
  --experiment olfactory_no_glomeruli \
  --save_dir results/olfactory_no_glomeruli
# Out:
# 2026-01-15 10:39:16.773820: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768473556.793356   25227 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768473556.799380   25227 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1768473556.814575   25227 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768473556.814601   25227 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768473556.814606   25227 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768473556.814610   25227 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-01-15 10:39:16.819036: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Using device: cuda
#
# ==================================================
# Loading data...
# ==================================================
# Loading training data...
# Loading validation data...
# Loading test data...
# Train: 14041 sentences
# Valid: 3250 sentences
# Test: 3453 sentences
#
# Building vocabularies...
# Vocabulary size: 11984
# Number of labels: 8
# Labels: ['B-LOC', 'B-MISC', 'B-ORG', 'I-LOC', 'I-MISC', 'I-ORG', 'I-PER', 'O']
#
# Loading GloVe embeddings from ./data/glove.6B.300d.txt...
# Loading GloVe embeddings from ./data/glove.6B.300d.txt...
# Found embeddings for 6544/11984 words (54.6%)
#
# ==================================================
# Creating olfactory model...
# ==================================================
# Total parameters: 4,444,824
# Trainable parameters: 4,444,824
#
# ==================================================
# Starting training...
# ==================================================
#
# ==================================================
# Epoch 1/50
# ==================================================
# Training: 100% 439/439 [00:22<00:00, 19.88it/s, loss=3.2094, task=3.2080]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 51.53it/s]
#
# Train Loss: 4.8508
# Valid F1: 0.6031
# Valid Precision: 0.6400
# Valid Recall: 0.5702
#
# ✓ Saved new best model (F1: 0.6031)
#
# ==================================================
# Epoch 2/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.67it/s, loss=0.8152, task=0.8140]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 52.75it/s]
#
# Train Loss: 1.8083
# Valid F1: 0.7249
# Valid Precision: 0.7690
# Valid Recall: 0.6856
#
# ✓ Saved new best model (F1: 0.7249)
#
# ==================================================
# Epoch 3/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.77it/s, loss=1.0486, task=1.0474]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 52.68it/s]
#
# Train Loss: 1.2497
# Valid F1: 0.7693
# Valid Precision: 0.8105
# Valid Recall: 0.7321
#
# ✓ Saved new best model (F1: 0.7693)
#
# ==================================================
# Epoch 4/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.76it/s, loss=1.6649, task=1.6638]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 52.71it/s]
#
# Train Loss: 1.0294
# Valid F1: 0.7849
# Valid Precision: 0.8442
# Valid Recall: 0.7334
#
# ✓ Saved new best model (F1: 0.7849)
#
# ==================================================
# Epoch 5/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.77it/s, loss=0.5110, task=0.5099]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 52.40it/s]
#
# Train Loss: 0.9048
# Valid F1: 0.7859
# Valid Precision: 0.8437
# Valid Recall: 0.7356
#
# ✓ Saved new best model (F1: 0.7859)
#
# ==================================================
# Epoch 6/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.84it/s, loss=0.4373, task=0.4362]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 53.12it/s]
#
# Train Loss: 0.7806
# Valid F1: 0.7909
# Valid Precision: 0.8306
# Valid Recall: 0.7548
#
# ✓ Saved new best model (F1: 0.7909)
#
# ==================================================
# Epoch 7/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.73it/s, loss=0.6001, task=0.5990]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 53.19it/s]
#
# Train Loss: 0.7155
# Valid F1: 0.8058
# Valid Precision: 0.8445
# Valid Recall: 0.7704
#
# ✓ Saved new best model (F1: 0.8058)
#
# ==================================================
# Epoch 8/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.70it/s, loss=0.4257, task=0.4247]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 45.84it/s]
#
# Train Loss: 0.6419
# Valid F1: 0.8105
# Valid Precision: 0.8482
# Valid Recall: 0.7760
#
# ✓ Saved new best model (F1: 0.8105)
#
# ==================================================
# Epoch 9/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.78it/s, loss=0.4252, task=0.4242]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 53.08it/s]
#
# Train Loss: 0.5936
# Valid F1: 0.8003
# Valid Precision: 0.8164
# Valid Recall: 0.7849
#
# No improvement (1/5)
#
# ==================================================
# Epoch 10/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.74it/s, loss=0.7527, task=0.7517]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 52.39it/s]
#
# Train Loss: 0.5379
# Valid F1: 0.8215
# Valid Precision: 0.8278
# Valid Recall: 0.8154
#
# ✓ Saved new best model (F1: 0.8215)
#
# ==================================================
# Epoch 11/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.68it/s, loss=0.5538, task=0.5528]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 53.37it/s]
#
# Train Loss: 0.5061
# Valid F1: 0.8238
# Valid Precision: 0.8501
# Valid Recall: 0.7991
#
# ✓ Saved new best model (F1: 0.8238)
#
# ==================================================
# Epoch 12/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.82it/s, loss=0.5228, task=0.5218]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 52.95it/s]
#
# Train Loss: 0.4752
# Valid F1: 0.8184
# Valid Precision: 0.8334
# Valid Recall: 0.8039
#
# No improvement (1/5)
#
# ==================================================
# Epoch 13/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.83it/s, loss=0.3335, task=0.3325]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 52.96it/s]
#
# Train Loss: 0.4296
# Valid F1: 0.8283
# Valid Precision: 0.8501
# Valid Recall: 0.8076
#
# ✓ Saved new best model (F1: 0.8283)
#
# ==================================================
# Epoch 14/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.79it/s, loss=0.6310, task=0.6300]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 53.12it/s]
#
# Train Loss: 0.3882
# Valid F1: 0.8328
# Valid Precision: 0.8585
# Valid Recall: 0.8087
#
# ✓ Saved new best model (F1: 0.8328)
#
# ==================================================
# Epoch 15/50
# ==================================================
# Training: 100% 439/439 [00:21<00:00, 20.76it/s, loss=0.1196, task=0.1187]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 52.92it/s]
#
# Train Loss: 0.3596
# Valid F1: 0.8305
# Valid Precision: 0.8625
# Valid Recall: 0.8009
#
# No improvement (1/5)
#
# ==================================================
# Epoch 16/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.11it/s, loss=0.5951, task=0.5941]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 52.81it/s]
#
# Train Loss: 0.3367
# Valid F1: 0.8337
# Valid Precision: 0.8489
# Valid Recall: 0.8191
#
# ✓ Saved new best model (F1: 0.8337)
#
# ==================================================
# Epoch 17/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.07it/s, loss=0.3474, task=0.3465]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:01<00:00, 52.29it/s]
#
# Train Loss: 0.3210
# Valid F1: 0.8359
# Valid Precision: 0.8697
# Valid Recall: 0.8046
#
# ✓ Saved new best model (F1: 0.8359)
#
# ==================================================
# Epoch 18/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.18it/s, loss=0.5499, task=0.5490]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 47.92it/s]
#
# Train Loss: 0.3055
# Valid F1: 0.8306
# Valid Precision: 0.8523
# Valid Recall: 0.8100
#
# No improvement (1/5)
#
# ==================================================
# Epoch 19/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.42it/s, loss=0.1102, task=0.1093]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 47.01it/s]
#
# Train Loss: 0.2829
# Valid F1: 0.8255
# Valid Precision: 0.8355
# Valid Recall: 0.8157
#
# No improvement (2/5)
#
# ==================================================
# Epoch 20/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.35it/s, loss=0.5128, task=0.5119]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 44.27it/s]
#
# Train Loss: 0.2641
# Valid F1: 0.8350
# Valid Precision: 0.8568
# Valid Recall: 0.8144
#
# No improvement (3/5)
#
# ==================================================
# Epoch 21/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.42it/s, loss=0.0764, task=0.0755]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 44.47it/s]
#
# Train Loss: 0.2061
# Valid F1: 0.8350
# Valid Precision: 0.8575
# Valid Recall: 0.8135
#
# No improvement (4/5)
#
# ==================================================
# Epoch 22/50
# ==================================================
# Training: 100% 439/439 [00:20<00:00, 21.44it/s, loss=0.4582, task=0.4573]
#
# Evaluating on validation set...
# Evaluating: 100% 102/102 [00:02<00:00, 43.19it/s]
#
# Train Loss: 0.1791
# Valid F1: 0.8358
# Valid Precision: 0.8591
# Valid Recall: 0.8137
#
# No improvement (5/5)
#
# Early stopping triggered after 22 epochs
#
# ==================================================
# Final evaluation on test set...
# ==================================================
# Evaluating: 100% 108/108 [00:01<00:00, 57.78it/s]
#
# Test F1: 0.7353
# Test Precision: 0.7813
# Test Recall: 0.6944
#
# Per-entity F1 scores:
#   LOC: 0.8119
#   MISC: 0.6529
#   ORG: 0.6950
#   PER: 0.7325
#   micro avg: 0.7353
#   macro avg: 0.7231
#   weighted avg: 0.7350
#
# ✓ Training complete! Results saved to results/olfactory_no_glomeruli

# %% [markdown]
# ---
# ## 🔥 Section 3: Generate Heatmaps
#
# Generate receptor and glomeruli activation heatmaps for all olfactory experiments.

# %% [markdown]
# ### 3.1 Load Data and Setup

# %%
import torch
import json
import os
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from src.data.dataset import prepare_data
from src.model.olfactory_ner import create_olfactory_ner
from src.analysis.visualize import analyze_receptor_activations

# Load test data
print("Loading CoNLL-2003 dataset for analysis...")
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

train_loader, valid_loader, test_loader, vocab_info = prepare_data(
    data_dir='./data/raw',
    batch_size=32,
    min_freq=2
)

print(f"✓ Data loaded (Test: {len(test_loader.dataset)} samples)")
print(f"✓ Device: {device}")
# Out:
# Loading CoNLL-2003 dataset for analysis...
# Loading training data...
# Loading validation data...
# Loading test data...
# Train: 14041 sentences
# Valid: 3250 sentences
# Test: 3453 sentences
#
# Building vocabularies...
# Vocabulary size: 11984
# Number of labels: 8
# Labels: ['B-LOC', 'B-MISC', 'B-ORG', 'I-LOC', 'I-MISC', 'I-ORG', 'I-PER', 'O']
# ✓ Data loaded (Test: 3453 samples)
# ✓ Device: cuda

# %% [markdown]
# ### 3.2 Generate Heatmaps for All Olfactory Experiments

# %%
# List of olfactory experiments (experiments that have receptor layers)
olfactory_experiments = [
    'activation_gelu',
    'activation_swish',
    'activation_mish',
    'more_receptors',
    'fewer_receptors',
    'strong_diversity',
    'very_strong_diversity',
    'gelu_more_receptors',
    'minimal_gelu',
    'olfactory_full',
    'olfactory_no_glomeruli'
]

print("=" * 80)
print("GENERATING HEATMAPS FOR OLFACTORY EXPERIMENTS")
print("=" * 80)

heatmap_results = {}

for exp_name in olfactory_experiments:
    model_path = f'results/{exp_name}/best_model.pt'
    results_path = f'results/{exp_name}/results.json'
    
    if not os.path.exists(model_path):
        print(f"⚠️  Skipping {exp_name} - model not found")
        continue
    
    if not os.path.exists(results_path):
        print(f"⚠️  Skipping {exp_name} - results not found")
        continue
    
    print(f"\n{'='*80}")
    print(f"Processing: {exp_name}")
    print(f"{'='*80}")
    
    # Load config
    with open(results_path, 'r') as f:
        exp_results = json.load(f)
    
    config = exp_results.get('config', {})
    
    # Load model
    vocab_size = len(vocab_info['word2idx'])
    num_tags = len(vocab_info['label2idx'])
    
    try:
        model = create_olfactory_ner(vocab_size, num_tags, config)
        checkpoint = torch.load(model_path, map_location=device, weights_only=False)
        model.load_state_dict(checkpoint['model_state_dict'])
        model = model.to(device)
        model.eval()
        
        # Create save directory for this experiment
        save_dir = f'visualizations/{exp_name}'
        os.makedirs(save_dir, exist_ok=True)
        
        # Analyze receptors
        print(f"Analyzing receptor activations...")
        results = analyze_receptor_activations(
            model, 
            test_loader, 
            vocab_info, 
            device, 
            save_dir=save_dir
        )
        
        heatmap_results[exp_name] = {
            'save_dir': save_dir,
            'results': results
        }
        
        print(f"✓ Heatmaps saved to {save_dir}")
        
    except Exception as e:
        print(f"❌ Error processing {exp_name}: {e}")
        continue

print("\n" + "="*80)
print("HEATMAP GENERATION COMPLETE!")
print("="*80)
print(f"Generated heatmaps for {len(heatmap_results)} experiments")
# Out:
# ================================================================================
# GENERATING HEATMAPS FOR OLFACTORY EXPERIMENTS
# ================================================================================
#
# ================================================================================
# Processing: activation_gelu
# ================================================================================
# Analyzing receptor activations...
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   said: 7.352
#   said: 7.352
#   said: 7.352
#   said: 7.352
#   said: 7.352
#
# Receptor 1:
#   3: 11.951
#   3: 11.951
#   3: 11.951
#   3: 11.951
#   3: 11.951
#
# Receptor 2:
#   said: 7.909
#   said: 7.909
#   said: 7.909
#   said: 7.909
#   said: 7.909
#
# Receptor 3:
#   3: 6.901
#   3: 6.901
#   3: 6.901
#   3: 6.901
#   3: 6.901
#
# Receptor 4:
#   5.: 6.717
#   5.: 6.717
#   5.: 6.717
#   5.: 6.717
#   5.: 6.717
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 26.44%
# Average activation (when active): 0.328
#
# ✓ Analysis complete! Results saved to visualizations/activation_gelu
# ✓ Heatmaps saved to visualizations/activation_gelu
# ⚠️  Skipping activation_swish - model not found
# ⚠️  Skipping activation_mish - model not found
#
# ================================================================================
# Processing: more_receptors
# ================================================================================
# Analyzing receptor activations...
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   offences: 1.702
#   offences: 1.702
#   0.05: 1.698
#   0.05: 1.698
#   sentenced: 1.689
#
# Receptor 1:
#   .467: 2.737
#   +44: 2.606
#   +44: 2.606
#   +44: 2.606
#   arch-rivals: 2.545
#
# Receptor 2:
#   the: 4.514
#   the: 4.514
#   the: 4.514
#   the: 4.514
#   the: 4.514
#
# Receptor 3:
#   0: 10.023
#   0: 10.023
#   0: 10.023
#   0: 10.023
#   0: 10.023
#
# Receptor 4:
#   at: 5.834
#   at: 5.834
#   at: 5.834
#   at: 5.834
#   at: 5.834
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 22.98%
# Average activation (when active): 0.247
#
# ✓ Analysis complete! Results saved to visualizations/more_receptors
# ✓ Heatmaps saved to visualizations/more_receptors
# ⚠️  Skipping fewer_receptors - model not found
#
# ================================================================================
# Processing: strong_diversity
# ================================================================================
# Analyzing receptor activations...
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   2: 8.768
#   2: 8.768
#   2: 8.768
#   2: 8.768
#   2: 8.768
#
# Receptor 1:
#   stg: 3.973
#   2: 3.527
#   2: 3.527
#   2: 3.527
#   2: 3.527
#
# Receptor 2:
#   (: 6.690
#   (: 6.690
#   (: 6.690
#   (: 6.690
#   (: 6.690
#
# Receptor 3:
#   2: 4.497
#   2: 4.497
#   2: 4.497
#   2: 4.497
#   2: 4.497
#
# Receptor 4:
#   2: 4.698
#   2: 4.698
#   2: 4.698
#   2: 4.698
#   2: 4.698
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 25.63%
# Average activation (when active): 0.368
#
# ✓ Analysis complete! Results saved to visualizations/strong_diversity
# ✓ Heatmaps saved to visualizations/strong_diversity
# ⚠️  Skipping very_strong_diversity - model not found
#
# ================================================================================
# Processing: gelu_more_receptors
# ================================================================================
# Analyzing receptor activations...
# Collecting receptor activations...
# Creating receptor activation heatmap...
# Finding top activating tokens per receptor...
#
# Top 5 receptors and their top tokens:
#
# Receptor 0:
#   0: 7.049
#   0: 7.049
#   0: 7.049
#   0: 7.049
#   0: 7.049
#
# Receptor 1:
#   2w: 3.210
#   +44: 2.416
#   +44: 2.416
#   +44: 2.416
#   1nb: 2.267
#
# Receptor 2:
#   the: 5.326
#   the: 5.326
#   the: 5.326
#   the: 5.326
#   the: 5.326
#
# Receptor 3:
#   1.: 3.490
#   1.: 3.490
#   1.: 3.490
#   1.: 3.490
#   1.: 3.490
#
# Receptor 4:
#   at: 4.164
#   at: 4.164
#   at: 4.164
#   at: 4.164
#   at: 4.164
#
# Creating t-SNE visualization...
#
# Computing receptor specialization metrics...
# Receptor activation sparsity: 15.49%
# Average activation (when active): 0.225
#
# ✓ Analysis complete! Results saved to visualizations/gelu_more_receptors
# ✓ Heatmaps saved to visualizations/gelu_more_receptors
# ⚠️  Skipping minimal_gelu - model not found
# ⚠️  Skipping olfactory_full - model not found
# ⚠️  Skipping olfactory_no_glomeruli - model not found
#
# ================================================================================
# HEATMAP GENERATION COMPLETE!
# ================================================================================
# Generated heatmaps for 4 experiments

# %% [markdown]
# ### 3.3 Display Heatmaps Grid

# %%
from IPython.display import Image, display

print("\n" + "="*80)
print("RECEPTOR ACTIVATION HEATMAPS")
print("="*80)

for exp_name, data in heatmap_results.items():
    heatmap_path = os.path.join(data['save_dir'], 'receptor_heatmap.png')
    
    if os.path.exists(heatmap_path):
        print(f"\n{'='*80}")
        print(f"{exp_name.upper()}")
        print(f"{'='*80}")
        display(Image(filename=heatmap_path))

print("\n" + "="*80)
print("t-SNE VISUALIZATIONS")
print("="*80)

for exp_name, data in heatmap_results.items():
    tsne_path = os.path.join(data['save_dir'], 'glomeruli_tsne.png')
    
    if os.path.exists(tsne_path):
        print(f"\n{'='*80}")
        print(f"{exp_name.upper()}")
        print(f"{'='*80}")
        display(Image(filename=tsne_path))
# Out:
# ================================================================================
# RECEPTOR ACTIVATION HEATMAPS
# ================================================================================
#
# ================================================================================
# ACTIVATION_GELU
# ================================================================================
# ================================================================================
# MORE_RECEPTORS
# ================================================================================
# ================================================================================
# STRONG_DIVERSITY
# ================================================================================
# ================================================================================
# GELU_MORE_RECEPTORS
# ================================================================================
# ================================================================================
# t-SNE VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# ACTIVATION_GELU
# ================================================================================
# ================================================================================
# MORE_RECEPTORS
# ================================================================================
# ================================================================================
# STRONG_DIVERSITY
# ================================================================================
# ================================================================================
# GELU_MORE_RECEPTORS
# ================================================================================

# %% [markdown]
# ---
# ## 📊 Section 4: Comprehensive Metrics Analysis

# %% [markdown]
# ### 4.1 Load All Experiment Results

# %%
import json
import pandas as pd
from pathlib import Path

# Load results from all experiments
all_experiments = [
    'activation_gelu',
    'activation_swish', 
    'activation_mish',
    'more_receptors',
    'fewer_receptors',
    'strong_diversity',
    'very_strong_diversity',
    'gelu_more_receptors',
    'minimal_gelu',
    'baseline',
    'olfactory_full',
    'olfactory_no_glomeruli'
]

experiment_results = {}

for exp_name in all_experiments:
    results_path = f'results/{exp_name}/results.json'
    
    if os.path.exists(results_path):
        with open(results_path, 'r') as f:
            experiment_results[exp_name] = json.load(f)
        print(f"✓ Loaded results for: {exp_name}")
    else:
        print(f"⚠️  Results not found for: {exp_name}")

print(f"\n✓ Loaded results for {len(experiment_results)} experiments")
# Out:
# ✓ Loaded results for: activation_gelu
# ⚠️  Results not found for: activation_swish
# ⚠️  Results not found for: activation_mish
# ✓ Loaded results for: more_receptors
# ⚠️  Results not found for: fewer_receptors
# ✓ Loaded results for: strong_diversity
# ⚠️  Results not found for: very_strong_diversity
# ✓ Loaded results for: gelu_more_receptors
# ⚠️  Results not found for: minimal_gelu
# ⚠️  Results not found for: baseline
# ⚠️  Results not found for: olfactory_full
# ⚠️  Results not found for: olfactory_no_glomeruli
#
# ✓ Loaded results for 4 experiments

# %% [markdown]
# ### 4.2 Comprehensive Metrics Table

# %%
# Create comprehensive metrics table
metrics_data = []

for exp_name, results in experiment_results.items():
    test_metrics = results.get('test', {})
    per_entity = test_metrics.get('per_entity', {})
    
    # Extract metrics
    row = {
        'Experiment': exp_name,
        'F1': test_metrics.get('f1', 0),
        'Precision': test_metrics.get('precision', 0),
        'Recall': test_metrics.get('recall', 0),
        'LOC_F1': per_entity.get('LOC', 0),
        'MISC_F1': per_entity.get('MISC', 0),
        'ORG_F1': per_entity.get('ORG', 0),
        'PER_F1': per_entity.get('PER', 0),
        'Micro_Avg': per_entity.get('micro avg', test_metrics.get('f1', 0)),
        'Macro_Avg': per_entity.get('macro avg', 0),
        'Weighted_Avg': per_entity.get('weighted avg', 0)
    }
    
    metrics_data.append(row)

# Create DataFrame
metrics_df = pd.DataFrame(metrics_data)

# Sort by F1 score descending
metrics_df = metrics_df.sort_values('F1', ascending=False)

print("\n" + "="*120)
print("COMPREHENSIVE METRICS TABLE")
print("="*120)
print(metrics_df.to_string(index=False))
print("="*120)
# Out:
# ========================================================================================================================
# COMPREHENSIVE METRICS TABLE
# ========================================================================================================================
#          Experiment       F1  Precision   Recall   LOC_F1  MISC_F1   ORG_F1   PER_F1  Micro_Avg  Macro_Avg  Weighted_Avg
# gelu_more_receptors 0.761301   0.817093 0.712642 0.832085 0.680334 0.717606 0.767170   0.761301   0.749299      0.760972
#      more_receptors 0.752835   0.799841 0.711048 0.842929 0.674681 0.701348 0.746188   0.752835   0.741286      0.752683
#     activation_gelu 0.730568   0.787278 0.681480 0.808215 0.676119 0.706658 0.691445   0.730568   0.720609      0.728499
#    strong_diversity 0.716894   0.748075 0.688208 0.823529 0.601562 0.656863 0.718179   0.716894   0.700033      0.716765
# ========================================================================================================================

# %% [markdown]
# ### 4.3 Best Performing Models

# %%
# Show top 5 models
print("\n" + "="*80)
print("TOP 5 MODELS BY F1 SCORE")
print("="*80)

top5 = metrics_df.head(5)[['Experiment', 'F1', 'Precision', 'Recall', 'Micro_Avg', 'Macro_Avg']]
print(top5.to_string(index=False))

# Best per entity type
print("\n" + "="*80)
print("BEST MODEL PER ENTITY TYPE")
print("="*80)

entity_types = ['LOC_F1', 'MISC_F1', 'ORG_F1', 'PER_F1']
for entity in entity_types:
    best_idx = metrics_df[entity].idxmax()
    best_exp = metrics_df.loc[best_idx, 'Experiment']
    best_score = metrics_df.loc[best_idx, entity]
    entity_name = entity.replace('_F1', '')
    print(f"{entity_name:8} : {best_exp:30} (F1 = {best_score:.4f})")

print("="*80)

# %% [markdown]
# ### 4.4 Statistical Summary

# %%
# Statistical summary
print("\n" + "="*80)
print("STATISTICAL SUMMARY")
print("="*80)

summary_cols = ['F1', 'Precision', 'Recall', 'Macro_Avg', 'Micro_Avg']
summary_stats = metrics_df[summary_cols].describe()

print(summary_stats)
print("="*80)

# %% [markdown]
# ---
# ## 📈 Section 5: Visualizations

# %% [markdown]
# ### 5.1 Overall F1 Score Comparison

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set style
sns.set_style('whitegrid')
plt.figure(figsize=(14, 6))

# Sort by F1
sorted_df = metrics_df.sort_values('F1', ascending=True)

# Create horizontal bar chart
colors = ['#FF6B6B' if 'baseline' in exp.lower() else '#4ECDC4' for exp in sorted_df['Experiment']]

plt.barh(sorted_df['Experiment'], sorted_df['F1'], color=colors, edgecolor='black', linewidth=1.5)
plt.xlabel('F1 Score', fontsize=12, fontweight='bold')
plt.ylabel('Experiment', fontsize=12, fontweight='bold')
plt.title('Overall F1 Score Comparison Across All Experiments', fontsize=14, fontweight='bold', pad=20)
plt.xlim([sorted_df['F1'].min() - 0.02, sorted_df['F1'].max() + 0.02])

# Add value labels
for i, (idx, row) in enumerate(sorted_df.iterrows()):
    plt.text(row['F1'] + 0.003, i, f"{row['F1']:.4f}", va='center', fontsize=9)

plt.tight_layout()
plt.savefig('visualizations/f1_comparison.png', dpi=300, bbox_inches='tight')
plt.show()

print("✓ Saved: visualizations/f1_comparison.png")

# %% [markdown]
# ### 5.2 Per-Entity Performance Comparison

# %%
import numpy as np

# Per-entity comparison
fig, ax = plt.subplots(figsize=(14, 8))

entity_cols = ['LOC_F1', 'MISC_F1', 'ORG_F1', 'PER_F1']
entity_names = ['LOC', 'MISC', 'ORG', 'PER']

# Take top 8 experiments by overall F1
top_experiments = metrics_df.head(8)

x = np.arange(len(entity_names))
width = 0.1

colors = plt.cm.tab10(np.linspace(0, 1, 8))

for i, (idx, row) in enumerate(top_experiments.iterrows()):
    scores = [row[col] for col in entity_cols]
    ax.bar(x + i * width, scores, width, label=row['Experiment'], color=colors[i], edgecolor='black', linewidth=0.8)

ax.set_xlabel('Entity Type', fontsize=12, fontweight='bold')
ax.set_ylabel('F1 Score', fontsize=12, fontweight='bold')
ax.set_title('Per-Entity F1 Score Comparison (Top 8 Models)', fontsize=14, fontweight='bold', pad=20)
ax.set_xticks(x + width * 3.5)
ax.set_xticklabels(entity_names)
ax.legend(loc='upper left', bbox_to_anchor=(1, 1), fontsize=9)
ax.grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig('visualizations/per_entity_comparison.png', dpi=300, bbox_inches='tight')
plt.show()

print("✓ Saved: visualizations/per_entity_comparison.png")

# %% [markdown]
# ### 5.3 Precision vs Recall Scatter Plot

# %%
# Precision vs Recall
fig, ax = plt.subplots(figsize=(10, 8))

# Color by model type
colors_map = {
    'baseline': '#FF6B6B',
    'olfactory': '#4ECDC4',
    'activation': '#95E1D3',
    'receptors': '#F38181'
}

def get_color(exp_name):
    if 'baseline' in exp_name:
        return colors_map['baseline']
    elif 'activation' in exp_name:
        return colors_map['activation']
    elif 'receptor' in exp_name:
        return colors_map['receptors']
    else:
        return colors_map['olfactory']

for idx, row in metrics_df.iterrows():
    ax.scatter(row['Recall'], row['Precision'], 
              s=row['F1'] * 500,  # Size proportional to F1
              c=get_color(row['Experiment']),
              alpha=0.6,
              edgecolors='black',
              linewidth=1.5)
    
    # Add labels for top 5
    if idx in metrics_df.head(5).index:
        ax.annotate(row['Experiment'], 
                   (row['Recall'], row['Precision']),
                   xytext=(5, 5), textcoords='offset points',
                   fontsize=8, alpha=0.8)

ax.set_xlabel('Recall', fontsize=12, fontweight='bold')
ax.set_ylabel('Precision', fontsize=12, fontweight='bold')
ax.set_title('Precision vs Recall (bubble size = F1 score)', fontsize=14, fontweight='bold', pad=20)
ax.grid(alpha=0.3)

plt.tight_layout()
plt.savefig('visualizations/precision_recall_scatter.png', dpi=300, bbox_inches='tight')
plt.show()

print("✓ Saved: visualizations/precision_recall_scatter.png")

# %% [markdown]
# ### 5.4 Micro vs Macro Average Comparison

# %%
# Micro vs Macro
fig, ax = plt.subplots(figsize=(12, 6))

x = np.arange(len(metrics_df))
width = 0.35

ax.bar(x - width/2, metrics_df['Micro_Avg'], width, label='Micro Average', 
       color='#4ECDC4', edgecolor='black', linewidth=1.2)
ax.bar(x + width/2, metrics_df['Macro_Avg'], width, label='Macro Average',
       color='#F38181', edgecolor='black', linewidth=1.2)

ax.set_xlabel('Experiment', fontsize=12, fontweight='bold')
ax.set_ylabel('F1 Score', fontsize=12, fontweight='bold')
ax.set_title('Micro vs Macro Average F1 Comparison', fontsize=14, fontweight='bold', pad=20)
ax.set_xticks(x)
ax.set_xticklabels(metrics_df['Experiment'], rotation=45, ha='right', fontsize=9)
ax.legend(fontsize=10)
ax.grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig('visualizations/micro_macro_comparison.png', dpi=300, bbox_inches='tight')
plt.show()

print("✓ Saved: visualizations/micro_macro_comparison.png")

# %% [markdown]
# ---
# ## 💾 Section 6: Export Results

# %% [markdown]
# ### 6.1 Save Comprehensive Results Summary

# %%
# Save metrics table as CSV
metrics_df.to_csv('visualizations/comprehensive_metrics.csv', index=False)
print("✓ Saved: visualizations/comprehensive_metrics.csv")

# Save as JSON
summary_data = {
    'experiments': metrics_df.to_dict('records'),
    'best_overall': {
        'experiment': metrics_df.iloc[0]['Experiment'],
        'f1': float(metrics_df.iloc[0]['F1']),
        'precision': float(metrics_df.iloc[0]['Precision']),
        'recall': float(metrics_df.iloc[0]['Recall'])
    },
    'best_per_entity': {
        'LOC': {
            'experiment': metrics_df.loc[metrics_df['LOC_F1'].idxmax(), 'Experiment'],
            'f1': float(metrics_df['LOC_F1'].max())
        },
        'MISC': {
            'experiment': metrics_df.loc[metrics_df['MISC_F1'].idxmax(), 'Experiment'],
            'f1': float(metrics_df['MISC_F1'].max())
        },
        'ORG': {
            'experiment': metrics_df.loc[metrics_df['ORG_F1'].idxmax(), 'Experiment'],
            'f1': float(metrics_df['ORG_F1'].max())
        },
        'PER': {
            'experiment': metrics_df.loc[metrics_df['PER_F1'].idxmax(), 'Experiment'],
            'f1': float(metrics_df['PER_F1'].max())
        }
    },
    'statistics': {
        'mean_f1': float(metrics_df['F1'].mean()),
        'std_f1': float(metrics_df['F1'].std()),
        'min_f1': float(metrics_df['F1'].min()),
        'max_f1': float(metrics_df['F1'].max())
    }
}

with open('visualizations/comprehensive_summary.json', 'w') as f:
    json.dump(summary_data, f, indent=2)

print("✓ Saved: visualizations/comprehensive_summary.json")

# %% [markdown]
# ### 6.2 Create Results Archive (for Download)

# %%
# Create zip of all results and visualizations
# !zip -r olfaction_ner_comprehensive_results.zip \
    results/ \
    visualizations/ \
    -x "results/*/checkpoints/*" \
    -x "*.git/*"

print("✓ Created archive: olfaction_ner_comprehensive_results.zip")

# For Google Colab - download
try:
    from google.colab import files
    files.download('olfaction_ner_comprehensive_results.zip')
    print("✓ Download started")
except ImportError:
    print("ℹ️  Not in Colab - archive saved locally")

# %% [markdown]
# ### 6.3 Final Summary Report

# %%
print("\n" + "="*80)
print("FINAL SUMMARY REPORT")
print("="*80)

print(f"\n✅ Experiments Completed: {len(experiment_results)}/12")
print(f"✅ Heatmaps Generated: {len(heatmap_results)}")
print(f"✅ Visualizations Created: 5")

print("\n" + "-"*80)
print("BEST MODEL")
print("-"*80)
best_exp = metrics_df.iloc[0]
print(f"Experiment    : {best_exp['Experiment']}")
print(f"F1 Score      : {best_exp['F1']:.4f}")
print(f"Precision     : {best_exp['Precision']:.4f}")
print(f"Recall        : {best_exp['Recall']:.4f}")
print(f"Micro Average : {best_exp['Micro_Avg']:.4f}")
print(f"Macro Average : {best_exp['Macro_Avg']:.4f}")

print("\n" + "-"*80)
print("SAVED FILES")
print("-"*80)
print("📁 results/                  - All model checkpoints and training results")
print("📁 visualizations/           - All heatmaps and comparison charts")
print("📄 comprehensive_metrics.csv - Metrics table")
print("📄 comprehensive_summary.json - Summary statistics")
print("📦 olfaction_ner_comprehensive_results.zip - Complete archive")

print("\n" + "="*80)
print("ALL EXPERIMENTS COMPLETE! 🎉")
print("="*80)
